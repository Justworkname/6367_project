# %% [markdown]
# <a href="https://colab.research.google.com/github/Justworkname/6367_project/blob/main/Final_Testing_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression Model V2_smaller_deltas_testing_save_failed

# %% [markdown]
# ## Import

# %%
# !pip install -q torchinfo

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torch.optim as optim
from torchvision import datasets, transforms
from torchinfo import summary
import numpy as np
import pandas as pd
import os
from PIL import Image
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import torch.optim.lr_scheduler as lr_scheduler

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# this creates a link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# '10 19 2023 meeting.gslides'
# '6 16 2023 Meeting.gslides'
#  6367
#  6367_project
# '6367 Project presentation.gslides'
# '7 12 2023 meeting.gslides'
#  7340
# '8 17 2023 meeting.gslides'
# '8 30 2023 meeting.gslides'
# '9 06 2023 meeting - Bar chart 1.gsheet'
# '9 06 2023 meeting - Column chart 1 (1).gsheet'
# '9 06 2023 meeting - Column chart 1 (2).gsheet'
# '9 06 2023 meeting - Column chart 1.gsheet'
# '9 06 2023 meeting.gslides'
# '9 20 2023 meeting.gslides'
# '9 28 2023 meeting.gslides'
# 'AI in Breast Cancer in Medical Imaging.gslides'
#  AI_MB
#  AI_MB_3D
# 'Cluster Testing.gsheet'
# 'Colab Notebooks'
#  customTF2
#  Data_Vision_Transformer
#  fakeImages
#  Grad_documents
# 'Invited Lecture 2.gdoc'
# 'Invited Lecture 5.gdoc'
# 'Invited lecture 6.gdoc'
# 'Invited Lecture 7.gdoc'
#  Invited_lecture_oct_10.gdoc
# 'Invited Lecture October 3rd.gdoc'
# 'Invited Lecture September 19th.gdoc'
# 'Multiple Deltas.gsheet'
# 'My Drive'
# 'Presentation Evaluation sep 19.gdoc'
# 'QE Key points.gdoc'
# 'Regression testing.gdoc'
# 'Regression testing multiple deltas.gdoc'
#  Seminar
#  Ultrasound_Images
#  Undergrad_documents
# 'Veterinary Clinic Tumor Estimation Conclusion.gslides'
# 'Wild Magic.gsheet'

# %% [markdown]
# ## Hyperparameters

# %%
num_epochs=5000
input_dim = 54
output_dim = 1
hidden_dim = 1385
dropout=0.01

# %% [markdown]
# ## Load

# %%
# Load the CSV file into a DataFrame
csv_file_path = '/content/gdrive/MyDrive/6367_project/data_v2.csv'
df = pd.read_csv(csv_file_path)
df.fillna(0,inplace=True)
df = df.loc[(df != 0).all(axis=1)] # filter if want

train_patients = ['8', '4', '5', '6', '9','10', '11','13','14','16','19','20','21','23','25']
test_patients = ['3']

df['Patient #'] = df['Patient #'].astype(str)

df_train=df[df['Patient #'].isin(train_patients)]
df_test=df[df['Patient #'].isin(test_patients)]

# Convert to desired data shape
y_train = df_train['Delta Plq Area'] #change with desired prediction
X_train = df_train.drop(columns=['Delta Plq Area','Patient #','Total FU Plq Area','VHIVUS FU img ind','CC FU Area','CC FU Circum Cov.','CC FU max thick',
                     'NC FU Area','NC FU max thick','FI FU Area','FI FU Circum Cov.','FI FU max thick','FF FU Area','FF FU Circum Cov.','FF FU max thick',
                     'VHIVUS BL img ind','BL Pat FRS','BL Pat LDL','BL Pat FFR','BL Pat EEMV','BL Pat BMI','BL Pat BUR']) #data to exclude

y_test = df_test['Delta Plq Area'] #change with desired prediction
X_test = df_test.drop(columns=['Delta Plq Area','Patient #','Total FU Plq Area','VHIVUS FU img ind','CC FU Area','CC FU Circum Cov.','CC FU max thick',
                     'NC FU Area','NC FU max thick','FI FU Area','FI FU Circum Cov.','FI FU max thick','FF FU Area','FF FU Circum Cov.','FF FU max thick',
                     'VHIVUS BL img ind','BL Pat FRS','BL Pat LDL','BL Pat FFR','BL Pat EEMV','BL Pat BMI','BL Pat BUR'])

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.float32)
y_train = y_train.view(-1)
y_test = y_test.view(-1)
# Out:
# <ipython-input-5-b759974aef94>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Patient #'] = df['Patient #'].astype(str)

# %% [markdown]
# ## Model

# %%
class RegressionModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout):
        super(RegressionModel, self).__init__()

        # Define the layers
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, 100)
        self.relu = nn.ReLU()
        self.fc3 = nn.Linear(100, output_dim)
        #self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        # Forward pass
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        #x = self.dropout(x)
        x = self.fc3(x)
        return x

# %%
model = RegressionModel(input_dim, hidden_dim, output_dim,dropout)

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# RegressionModel                          --
# ├─Linear: 1-1                            76,175
# ├─ReLU: 1-2                              --
# ├─Linear: 1-3                            138,600
# ├─Linear: 1-4                            101
# =================================================================
# Total params: 214,876
# Trainable params: 214,876
# Non-trainable params: 0
# =================================================================

# %%
# Mean Squared Error loss
criterion = nn.SmoothL1Loss()
# Apply optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)
# Learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)

# %% [markdown]
# ## Training

# %%
# List for Loss and R squared
losses = []
val_losses = []
r2_values = []
r2_validation = []

# Training loop
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_train)
    outputs = outputs.squeeze(dim=1)

    # Compute the loss
    ## Could consider Huber Loss
    loss = criterion(outputs, y_train)

    # Backpropagation and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Learning rate annealing
    scheduler.step()

    # Calculate R-squared
    y_pred = outputs.detach().numpy()
    r2 = r2_score(y_train.numpy(), y_pred)

    # Store loss and R-squared values for this epoch
    losses.append(loss.item())
    r2_values.append(r2)

    # Testing predictions
    y_pred = model(X_test).detach().numpy()
    # Calculate R-squared accuracy on the test data
    r2_test = r2_score(y_test.numpy(), y_pred)
    r2_validation.append(r2_test)
    val_out = model(X_test)
    val_out = val_out.squeeze(dim=1)
    val_loss = criterion(val_out,y_test)
    val_losses.append(val_loss.item())

    print('Epoch [{}/{}], Loss: {:.4f}, R-squared: {:.4f},Validation_loss:{:,.4f}, Validation R_squared:{:,.4f}'.format(epoch+1, num_epochs, loss.item(), r2,val_loss.item(),r2_test))
# Out:
# Epoch [1/5000], Loss: 0.2630, R-squared: -0.0071,Validation_loss:0.2027, Validation R_squared:-0.1041
# Epoch [2/5000], Loss: 0.2619, R-squared: -0.0025,Validation_loss:0.2020, Validation R_squared:-0.0993
# Epoch [3/5000], Loss: 0.2609, R-squared: 0.0018,Validation_loss:0.2013, Validation R_squared:-0.0950
# Epoch [4/5000], Loss: 0.2599, R-squared: 0.0058,Validation_loss:0.2007, Validation R_squared:-0.0910
# Epoch [5/5000], Loss: 0.2590, R-squared: 0.0094,Validation_loss:0.2001, Validation R_squared:-0.0872
# Epoch [6/5000], Loss: 0.2581, R-squared: 0.0129,Validation_loss:0.1996, Validation R_squared:-0.0837
# Epoch [7/5000], Loss: 0.2573, R-squared: 0.0161,Validation_loss:0.1991, Validation R_squared:-0.0805
# Epoch [8/5000], Loss: 0.2566, R-squared: 0.0192,Validation_loss:0.1987, Validation R_squared:-0.0776
# Epoch [9/5000], Loss: 0.2559, R-squared: 0.0221,Validation_loss:0.1982, Validation R_squared:-0.0748
# Epoch [10/5000], Loss: 0.2552, R-squared: 0.0248,Validation_loss:0.1978, Validation R_squared:-0.0722
# Epoch [11/5000], Loss: 0.2545, R-squared: 0.0275,Validation_loss:0.1975, Validation R_squared:-0.0697
# Epoch [12/5000], Loss: 0.2539, R-squared: 0.0300,Validation_loss:0.1971, Validation R_squared:-0.0674
# Epoch [13/5000], Loss: 0.2533, R-squared: 0.0324,Validation_loss:0.1968, Validation R_squared:-0.0653
# Epoch [14/5000], Loss: 0.2527, R-squared: 0.0347,Validation_loss:0.1965, Validation R_squared:-0.0632
# Epoch [15/5000], Loss: 0.2522, R-squared: 0.0369,Validation_loss:0.1962, Validation R_squared:-0.0612
# Epoch [16/5000], Loss: 0.2516, R-squared: 0.0391,Validation_loss:0.1959, Validation R_squared:-0.0594
# Epoch [17/5000], Loss: 0.2511, R-squared: 0.0411,Validation_loss:0.1956, Validation R_squared:-0.0577
# Epoch [18/5000], Loss: 0.2506, R-squared: 0.0431,Validation_loss:0.1953, Validation R_squared:-0.0560
# Epoch [19/5000], Loss: 0.2501, R-squared: 0.0450,Validation_loss:0.1951, Validation R_squared:-0.0544
# Epoch [20/5000], Loss: 0.2497, R-squared: 0.0469,Validation_loss:0.1948, Validation R_squared:-0.0529
# Epoch [21/5000], Loss: 0.2492, R-squared: 0.0487,Validation_loss:0.1946, Validation R_squared:-0.0514
# Epoch [22/5000], Loss: 0.2488, R-squared: 0.0505,Validation_loss:0.1944, Validation R_squared:-0.0501
# Epoch [23/5000], Loss: 0.2484, R-squared: 0.0522,Validation_loss:0.1942, Validation R_squared:-0.0487
# Epoch [24/5000], Loss: 0.2479, R-squared: 0.0539,Validation_loss:0.1940, Validation R_squared:-0.0475
# Epoch [25/5000], Loss: 0.2475, R-squared: 0.0555,Validation_loss:0.1938, Validation R_squared:-0.0462
# Epoch [26/5000], Loss: 0.2471, R-squared: 0.0571,Validation_loss:0.1936, Validation R_squared:-0.0450
# Epoch [27/5000], Loss: 0.2467, R-squared: 0.0586,Validation_loss:0.1934, Validation R_squared:-0.0439
# Epoch [28/5000], Loss: 0.2463, R-squared: 0.0602,Validation_loss:0.1932, Validation R_squared:-0.0428
# Epoch [29/5000], Loss: 0.2460, R-squared: 0.0617,Validation_loss:0.1930, Validation R_squared:-0.0417
# Epoch [30/5000], Loss: 0.2456, R-squared: 0.0631,Validation_loss:0.1929, Validation R_squared:-0.0406
# Epoch [31/5000], Loss: 0.2452, R-squared: 0.0645,Validation_loss:0.1927, Validation R_squared:-0.0396
# Epoch [32/5000], Loss: 0.2449, R-squared: 0.0659,Validation_loss:0.1925, Validation R_squared:-0.0386
# Epoch [33/5000], Loss: 0.2445, R-squared: 0.0673,Validation_loss:0.1924, Validation R_squared:-0.0377
# Epoch [34/5000], Loss: 0.2442, R-squared: 0.0687,Validation_loss:0.1922, Validation R_squared:-0.0367
# Epoch [35/5000], Loss: 0.2439, R-squared: 0.0700,Validation_loss:0.1921, Validation R_squared:-0.0358
# Epoch [36/5000], Loss: 0.2435, R-squared: 0.0713,Validation_loss:0.1919, Validation R_squared:-0.0350
# Epoch [37/5000], Loss: 0.2432, R-squared: 0.0725,Validation_loss:0.1918, Validation R_squared:-0.0341
# Epoch [38/5000], Loss: 0.2429, R-squared: 0.0738,Validation_loss:0.1917, Validation R_squared:-0.0333
# Epoch [39/5000], Loss: 0.2426, R-squared: 0.0750,Validation_loss:0.1915, Validation R_squared:-0.0325
# Epoch [40/5000], Loss: 0.2423, R-squared: 0.0762,Validation_loss:0.1914, Validation R_squared:-0.0317
# Epoch [41/5000], Loss: 0.2420, R-squared: 0.0774,Validation_loss:0.1913, Validation R_squared:-0.0310
# Epoch [42/5000], Loss: 0.2417, R-squared: 0.0786,Validation_loss:0.1912, Validation R_squared:-0.0302
# Epoch [43/5000], Loss: 0.2414, R-squared: 0.0798,Validation_loss:0.1910, Validation R_squared:-0.0295
# Epoch [44/5000], Loss: 0.2411, R-squared: 0.0809,Validation_loss:0.1909, Validation R_squared:-0.0288
# Epoch [45/5000], Loss: 0.2408, R-squared: 0.0820,Validation_loss:0.1908, Validation R_squared:-0.0281
# Epoch [46/5000], Loss: 0.2405, R-squared: 0.0832,Validation_loss:0.1907, Validation R_squared:-0.0274
# Epoch [47/5000], Loss: 0.2403, R-squared: 0.0842,Validation_loss:0.1906, Validation R_squared:-0.0268
# Epoch [48/5000], Loss: 0.2400, R-squared: 0.0853,Validation_loss:0.1905, Validation R_squared:-0.0261
# Epoch [49/5000], Loss: 0.2397, R-squared: 0.0864,Validation_loss:0.1904, Validation R_squared:-0.0255
# Epoch [50/5000], Loss: 0.2395, R-squared: 0.0874,Validation_loss:0.1903, Validation R_squared:-0.0249
# Epoch [51/5000], Loss: 0.2392, R-squared: 0.0885,Validation_loss:0.1902, Validation R_squared:-0.0243
# Epoch [52/5000], Loss: 0.2389, R-squared: 0.0895,Validation_loss:0.1901, Validation R_squared:-0.0238
# Epoch [53/5000], Loss: 0.2387, R-squared: 0.0905,Validation_loss:0.1900, Validation R_squared:-0.0232
# Epoch [54/5000], Loss: 0.2384, R-squared: 0.0916,Validation_loss:0.1899, Validation R_squared:-0.0227
# Epoch [55/5000], Loss: 0.2382, R-squared: 0.0926,Validation_loss:0.1898, Validation R_squared:-0.0221
# Epoch [56/5000], Loss: 0.2379, R-squared: 0.0936,Validation_loss:0.1898, Validation R_squared:-0.0216
# Epoch [57/5000], Loss: 0.2377, R-squared: 0.0945,Validation_loss:0.1897, Validation R_squared:-0.0210
# Epoch [58/5000], Loss: 0.2374, R-squared: 0.0955,Validation_loss:0.1896, Validation R_squared:-0.0205
# Epoch [59/5000], Loss: 0.2372, R-squared: 0.0965,Validation_loss:0.1895, Validation R_squared:-0.0200
# Epoch [60/5000], Loss: 0.2369, R-squared: 0.0974,Validation_loss:0.1894, Validation R_squared:-0.0195
# Epoch [61/5000], Loss: 0.2367, R-squared: 0.0984,Validation_loss:0.1893, Validation R_squared:-0.0190
# Epoch [62/5000], Loss: 0.2365, R-squared: 0.0993,Validation_loss:0.1893, Validation R_squared:-0.0185
# Epoch [63/5000], Loss: 0.2362, R-squared: 0.1002,Validation_loss:0.1892, Validation R_squared:-0.0180
# Epoch [64/5000], Loss: 0.2360, R-squared: 0.1011,Validation_loss:0.1891, Validation R_squared:-0.0175
# Epoch [65/5000], Loss: 0.2358, R-squared: 0.1021,Validation_loss:0.1890, Validation R_squared:-0.0171
# Epoch [66/5000], Loss: 0.2355, R-squared: 0.1030,Validation_loss:0.1890, Validation R_squared:-0.0166
# Epoch [67/5000], Loss: 0.2353, R-squared: 0.1039,Validation_loss:0.1889, Validation R_squared:-0.0162
# Epoch [68/5000], Loss: 0.2351, R-squared: 0.1048,Validation_loss:0.1888, Validation R_squared:-0.0157
# Epoch [69/5000], Loss: 0.2348, R-squared: 0.1057,Validation_loss:0.1888, Validation R_squared:-0.0153
# Epoch [70/5000], Loss: 0.2346, R-squared: 0.1066,Validation_loss:0.1887, Validation R_squared:-0.0148
# Epoch [71/5000], Loss: 0.2344, R-squared: 0.1075,Validation_loss:0.1886, Validation R_squared:-0.0144
# Epoch [72/5000], Loss: 0.2342, R-squared: 0.1084,Validation_loss:0.1885, Validation R_squared:-0.0139
# Epoch [73/5000], Loss: 0.2339, R-squared: 0.1093,Validation_loss:0.1885, Validation R_squared:-0.0134
# Epoch [74/5000], Loss: 0.2337, R-squared: 0.1102,Validation_loss:0.1884, Validation R_squared:-0.0130
# Epoch [75/5000], Loss: 0.2335, R-squared: 0.1111,Validation_loss:0.1883, Validation R_squared:-0.0125
# Epoch [76/5000], Loss: 0.2333, R-squared: 0.1119,Validation_loss:0.1882, Validation R_squared:-0.0121
# Epoch [77/5000], Loss: 0.2331, R-squared: 0.1128,Validation_loss:0.1882, Validation R_squared:-0.0116
# Epoch [78/5000], Loss: 0.2328, R-squared: 0.1136,Validation_loss:0.1881, Validation R_squared:-0.0111
# Epoch [79/5000], Loss: 0.2326, R-squared: 0.1145,Validation_loss:0.1880, Validation R_squared:-0.0106
# Epoch [80/5000], Loss: 0.2324, R-squared: 0.1153,Validation_loss:0.1879, Validation R_squared:-0.0101
# Epoch [81/5000], Loss: 0.2322, R-squared: 0.1162,Validation_loss:0.1879, Validation R_squared:-0.0096
# Epoch [82/5000], Loss: 0.2320, R-squared: 0.1170,Validation_loss:0.1878, Validation R_squared:-0.0091
# Epoch [83/5000], Loss: 0.2318, R-squared: 0.1178,Validation_loss:0.1877, Validation R_squared:-0.0086
# Epoch [84/5000], Loss: 0.2316, R-squared: 0.1186,Validation_loss:0.1876, Validation R_squared:-0.0081
# Epoch [85/5000], Loss: 0.2314, R-squared: 0.1194,Validation_loss:0.1876, Validation R_squared:-0.0077
# Epoch [86/5000], Loss: 0.2312, R-squared: 0.1202,Validation_loss:0.1875, Validation R_squared:-0.0072
# Epoch [87/5000], Loss: 0.2310, R-squared: 0.1210,Validation_loss:0.1874, Validation R_squared:-0.0067
# Epoch [88/5000], Loss: 0.2308, R-squared: 0.1218,Validation_loss:0.1874, Validation R_squared:-0.0062
# Epoch [89/5000], Loss: 0.2306, R-squared: 0.1226,Validation_loss:0.1873, Validation R_squared:-0.0057
# Epoch [90/5000], Loss: 0.2304, R-squared: 0.1234,Validation_loss:0.1872, Validation R_squared:-0.0052
# Epoch [91/5000], Loss: 0.2302, R-squared: 0.1242,Validation_loss:0.1871, Validation R_squared:-0.0047
# Epoch [92/5000], Loss: 0.2300, R-squared: 0.1250,Validation_loss:0.1870, Validation R_squared:-0.0042
# Epoch [93/5000], Loss: 0.2298, R-squared: 0.1258,Validation_loss:0.1870, Validation R_squared:-0.0037
# Epoch [94/5000], Loss: 0.2296, R-squared: 0.1265,Validation_loss:0.1869, Validation R_squared:-0.0032
# Epoch [95/5000], Loss: 0.2294, R-squared: 0.1273,Validation_loss:0.1868, Validation R_squared:-0.0027
# Epoch [96/5000], Loss: 0.2292, R-squared: 0.1281,Validation_loss:0.1867, Validation R_squared:-0.0022
# Epoch [97/5000], Loss: 0.2290, R-squared: 0.1289,Validation_loss:0.1867, Validation R_squared:-0.0017
# Epoch [98/5000], Loss: 0.2288, R-squared: 0.1296,Validation_loss:0.1866, Validation R_squared:-0.0012
# Epoch [99/5000], Loss: 0.2286, R-squared: 0.1304,Validation_loss:0.1865, Validation R_squared:-0.0007
# Epoch [100/5000], Loss: 0.2284, R-squared: 0.1312,Validation_loss:0.1864, Validation R_squared:-0.0002
# Epoch [101/5000], Loss: 0.2282, R-squared: 0.1319,Validation_loss:0.1864, Validation R_squared:0.0003
# Epoch [102/5000], Loss: 0.2281, R-squared: 0.1327,Validation_loss:0.1863, Validation R_squared:0.0009
# Epoch [103/5000], Loss: 0.2279, R-squared: 0.1334,Validation_loss:0.1862, Validation R_squared:0.0014
# Epoch [104/5000], Loss: 0.2277, R-squared: 0.1342,Validation_loss:0.1861, Validation R_squared:0.0019
# Epoch [105/5000], Loss: 0.2275, R-squared: 0.1349,Validation_loss:0.1860, Validation R_squared:0.0025
# Epoch [106/5000], Loss: 0.2273, R-squared: 0.1357,Validation_loss:0.1859, Validation R_squared:0.0031
# Epoch [107/5000], Loss: 0.2271, R-squared: 0.1364,Validation_loss:0.1859, Validation R_squared:0.0036
# Epoch [108/5000], Loss: 0.2269, R-squared: 0.1371,Validation_loss:0.1858, Validation R_squared:0.0042
# Epoch [109/5000], Loss: 0.2268, R-squared: 0.1379,Validation_loss:0.1857, Validation R_squared:0.0048
# Epoch [110/5000], Loss: 0.2266, R-squared: 0.1386,Validation_loss:0.1856, Validation R_squared:0.0054
# Epoch [111/5000], Loss: 0.2264, R-squared: 0.1393,Validation_loss:0.1855, Validation R_squared:0.0060
# Epoch [112/5000], Loss: 0.2262, R-squared: 0.1401,Validation_loss:0.1854, Validation R_squared:0.0067
# Epoch [113/5000], Loss: 0.2260, R-squared: 0.1408,Validation_loss:0.1853, Validation R_squared:0.0073
# Epoch [114/5000], Loss: 0.2258, R-squared: 0.1415,Validation_loss:0.1852, Validation R_squared:0.0080
# Epoch [115/5000], Loss: 0.2257, R-squared: 0.1423,Validation_loss:0.1851, Validation R_squared:0.0086
# Epoch [116/5000], Loss: 0.2255, R-squared: 0.1430,Validation_loss:0.1850, Validation R_squared:0.0093
# Epoch [117/5000], Loss: 0.2253, R-squared: 0.1437,Validation_loss:0.1849, Validation R_squared:0.0099
# Epoch [118/5000], Loss: 0.2251, R-squared: 0.1444,Validation_loss:0.1848, Validation R_squared:0.0106
# Epoch [119/5000], Loss: 0.2249, R-squared: 0.1452,Validation_loss:0.1847, Validation R_squared:0.0112
# Epoch [120/5000], Loss: 0.2248, R-squared: 0.1459,Validation_loss:0.1846, Validation R_squared:0.0118
# Epoch [121/5000], Loss: 0.2246, R-squared: 0.1466,Validation_loss:0.1845, Validation R_squared:0.0125
# Epoch [122/5000], Loss: 0.2244, R-squared: 0.1473,Validation_loss:0.1844, Validation R_squared:0.0132
# Epoch [123/5000], Loss: 0.2242, R-squared: 0.1480,Validation_loss:0.1843, Validation R_squared:0.0139
# Epoch [124/5000], Loss: 0.2240, R-squared: 0.1487,Validation_loss:0.1842, Validation R_squared:0.0146
# Epoch [125/5000], Loss: 0.2239, R-squared: 0.1495,Validation_loss:0.1841, Validation R_squared:0.0154
# Epoch [126/5000], Loss: 0.2237, R-squared: 0.1502,Validation_loss:0.1840, Validation R_squared:0.0162
# Epoch [127/5000], Loss: 0.2235, R-squared: 0.1509,Validation_loss:0.1838, Validation R_squared:0.0169
# Epoch [128/5000], Loss: 0.2233, R-squared: 0.1516,Validation_loss:0.1837, Validation R_squared:0.0177
# Epoch [129/5000], Loss: 0.2232, R-squared: 0.1523,Validation_loss:0.1836, Validation R_squared:0.0185
# Epoch [130/5000], Loss: 0.2230, R-squared: 0.1530,Validation_loss:0.1835, Validation R_squared:0.0193
# Epoch [131/5000], Loss: 0.2228, R-squared: 0.1537,Validation_loss:0.1834, Validation R_squared:0.0201
# Epoch [132/5000], Loss: 0.2226, R-squared: 0.1544,Validation_loss:0.1832, Validation R_squared:0.0209
# Epoch [133/5000], Loss: 0.2225, R-squared: 0.1551,Validation_loss:0.1831, Validation R_squared:0.0217
# Epoch [134/5000], Loss: 0.2223, R-squared: 0.1558,Validation_loss:0.1830, Validation R_squared:0.0225
# Epoch [135/5000], Loss: 0.2221, R-squared: 0.1565,Validation_loss:0.1829, Validation R_squared:0.0234
# Epoch [136/5000], Loss: 0.2219, R-squared: 0.1572,Validation_loss:0.1827, Validation R_squared:0.0242
# Epoch [137/5000], Loss: 0.2218, R-squared: 0.1579,Validation_loss:0.1826, Validation R_squared:0.0250
# Epoch [138/5000], Loss: 0.2216, R-squared: 0.1586,Validation_loss:0.1825, Validation R_squared:0.0259
# Epoch [139/5000], Loss: 0.2214, R-squared: 0.1593,Validation_loss:0.1823, Validation R_squared:0.0267
# Epoch [140/5000], Loss: 0.2213, R-squared: 0.1600,Validation_loss:0.1822, Validation R_squared:0.0275
# Epoch [141/5000], Loss: 0.2211, R-squared: 0.1607,Validation_loss:0.1821, Validation R_squared:0.0284
# Epoch [142/5000], Loss: 0.2209, R-squared: 0.1614,Validation_loss:0.1819, Validation R_squared:0.0292
# Epoch [143/5000], Loss: 0.2208, R-squared: 0.1620,Validation_loss:0.1818, Validation R_squared:0.0301
# Epoch [144/5000], Loss: 0.2206, R-squared: 0.1627,Validation_loss:0.1817, Validation R_squared:0.0309
# Epoch [145/5000], Loss: 0.2204, R-squared: 0.1634,Validation_loss:0.1816, Validation R_squared:0.0318
# Epoch [146/5000], Loss: 0.2203, R-squared: 0.1641,Validation_loss:0.1814, Validation R_squared:0.0326
# Epoch [147/5000], Loss: 0.2201, R-squared: 0.1647,Validation_loss:0.1813, Validation R_squared:0.0335
# Epoch [148/5000], Loss: 0.2199, R-squared: 0.1654,Validation_loss:0.1811, Validation R_squared:0.0344
# Epoch [149/5000], Loss: 0.2198, R-squared: 0.1661,Validation_loss:0.1810, Validation R_squared:0.0353
# Epoch [150/5000], Loss: 0.2196, R-squared: 0.1667,Validation_loss:0.1809, Validation R_squared:0.0362
# Epoch [151/5000], Loss: 0.2194, R-squared: 0.1674,Validation_loss:0.1807, Validation R_squared:0.0371
# Epoch [152/5000], Loss: 0.2193, R-squared: 0.1681,Validation_loss:0.1806, Validation R_squared:0.0379
# Epoch [153/5000], Loss: 0.2191, R-squared: 0.1688,Validation_loss:0.1805, Validation R_squared:0.0388
# Epoch [154/5000], Loss: 0.2189, R-squared: 0.1694,Validation_loss:0.1803, Validation R_squared:0.0397
# Epoch [155/5000], Loss: 0.2188, R-squared: 0.1701,Validation_loss:0.1802, Validation R_squared:0.0406
# Epoch [156/5000], Loss: 0.2186, R-squared: 0.1708,Validation_loss:0.1800, Validation R_squared:0.0415
# Epoch [157/5000], Loss: 0.2184, R-squared: 0.1714,Validation_loss:0.1799, Validation R_squared:0.0424
# Epoch [158/5000], Loss: 0.2183, R-squared: 0.1721,Validation_loss:0.1798, Validation R_squared:0.0432
# Epoch [159/5000], Loss: 0.2181, R-squared: 0.1727,Validation_loss:0.1796, Validation R_squared:0.0441
# Epoch [160/5000], Loss: 0.2179, R-squared: 0.1734,Validation_loss:0.1795, Validation R_squared:0.0450
# Epoch [161/5000], Loss: 0.2178, R-squared: 0.1741,Validation_loss:0.1793, Validation R_squared:0.0459
# Epoch [162/5000], Loss: 0.2176, R-squared: 0.1747,Validation_loss:0.1792, Validation R_squared:0.0468
# Epoch [163/5000], Loss: 0.2175, R-squared: 0.1754,Validation_loss:0.1791, Validation R_squared:0.0477
# Epoch [164/5000], Loss: 0.2173, R-squared: 0.1761,Validation_loss:0.1789, Validation R_squared:0.0486
# Epoch [165/5000], Loss: 0.2171, R-squared: 0.1767,Validation_loss:0.1788, Validation R_squared:0.0496
# Epoch [166/5000], Loss: 0.2170, R-squared: 0.1774,Validation_loss:0.1786, Validation R_squared:0.0505
# Epoch [167/5000], Loss: 0.2168, R-squared: 0.1780,Validation_loss:0.1785, Validation R_squared:0.0514
# Epoch [168/5000], Loss: 0.2166, R-squared: 0.1787,Validation_loss:0.1783, Validation R_squared:0.0523
# Epoch [169/5000], Loss: 0.2165, R-squared: 0.1793,Validation_loss:0.1782, Validation R_squared:0.0533
# Epoch [170/5000], Loss: 0.2163, R-squared: 0.1800,Validation_loss:0.1781, Validation R_squared:0.0542
# Epoch [171/5000], Loss: 0.2162, R-squared: 0.1806,Validation_loss:0.1779, Validation R_squared:0.0551
# Epoch [172/5000], Loss: 0.2160, R-squared: 0.1813,Validation_loss:0.1778, Validation R_squared:0.0560
# Epoch [173/5000], Loss: 0.2158, R-squared: 0.1819,Validation_loss:0.1776, Validation R_squared:0.0569
# Epoch [174/5000], Loss: 0.2157, R-squared: 0.1826,Validation_loss:0.1775, Validation R_squared:0.0578
# Epoch [175/5000], Loss: 0.2155, R-squared: 0.1832,Validation_loss:0.1773, Validation R_squared:0.0588
# Epoch [176/5000], Loss: 0.2154, R-squared: 0.1838,Validation_loss:0.1772, Validation R_squared:0.0597
# Epoch [177/5000], Loss: 0.2152, R-squared: 0.1845,Validation_loss:0.1770, Validation R_squared:0.0607
# Epoch [178/5000], Loss: 0.2151, R-squared: 0.1851,Validation_loss:0.1769, Validation R_squared:0.0616
# Epoch [179/5000], Loss: 0.2149, R-squared: 0.1858,Validation_loss:0.1767, Validation R_squared:0.0626
# Epoch [180/5000], Loss: 0.2147, R-squared: 0.1864,Validation_loss:0.1766, Validation R_squared:0.0635
# Epoch [181/5000], Loss: 0.2146, R-squared: 0.1871,Validation_loss:0.1764, Validation R_squared:0.0645
# Epoch [182/5000], Loss: 0.2144, R-squared: 0.1877,Validation_loss:0.1763, Validation R_squared:0.0655
# Epoch [183/5000], Loss: 0.2143, R-squared: 0.1883,Validation_loss:0.1761, Validation R_squared:0.0665
# Epoch [184/5000], Loss: 0.2141, R-squared: 0.1890,Validation_loss:0.1760, Validation R_squared:0.0675
# Epoch [185/5000], Loss: 0.2140, R-squared: 0.1896,Validation_loss:0.1758, Validation R_squared:0.0685
# Epoch [186/5000], Loss: 0.2138, R-squared: 0.1903,Validation_loss:0.1756, Validation R_squared:0.0695
# Epoch [187/5000], Loss: 0.2136, R-squared: 0.1909,Validation_loss:0.1755, Validation R_squared:0.0704
# Epoch [188/5000], Loss: 0.2135, R-squared: 0.1915,Validation_loss:0.1753, Validation R_squared:0.0714
# Epoch [189/5000], Loss: 0.2133, R-squared: 0.1922,Validation_loss:0.1752, Validation R_squared:0.0724
# Epoch [190/5000], Loss: 0.2132, R-squared: 0.1928,Validation_loss:0.1750, Validation R_squared:0.0734
# Epoch [191/5000], Loss: 0.2130, R-squared: 0.1935,Validation_loss:0.1749, Validation R_squared:0.0744
# Epoch [192/5000], Loss: 0.2129, R-squared: 0.1941,Validation_loss:0.1747, Validation R_squared:0.0754
# Epoch [193/5000], Loss: 0.2127, R-squared: 0.1947,Validation_loss:0.1745, Validation R_squared:0.0764
# Epoch [194/5000], Loss: 0.2125, R-squared: 0.1954,Validation_loss:0.1744, Validation R_squared:0.0775
# Epoch [195/5000], Loss: 0.2124, R-squared: 0.1960,Validation_loss:0.1742, Validation R_squared:0.0785
# Epoch [196/5000], Loss: 0.2122, R-squared: 0.1966,Validation_loss:0.1740, Validation R_squared:0.0795
# Epoch [197/5000], Loss: 0.2121, R-squared: 0.1973,Validation_loss:0.1739, Validation R_squared:0.0806
# Epoch [198/5000], Loss: 0.2119, R-squared: 0.1979,Validation_loss:0.1737, Validation R_squared:0.0816
# Epoch [199/5000], Loss: 0.2118, R-squared: 0.1986,Validation_loss:0.1735, Validation R_squared:0.0826
# Epoch [200/5000], Loss: 0.2116, R-squared: 0.1992,Validation_loss:0.1734, Validation R_squared:0.0837
# Epoch [201/5000], Loss: 0.2115, R-squared: 0.1998,Validation_loss:0.1732, Validation R_squared:0.0847
# Epoch [202/5000], Loss: 0.2113, R-squared: 0.2005,Validation_loss:0.1731, Validation R_squared:0.0857
# Epoch [203/5000], Loss: 0.2111, R-squared: 0.2011,Validation_loss:0.1729, Validation R_squared:0.0867
# Epoch [204/5000], Loss: 0.2110, R-squared: 0.2018,Validation_loss:0.1727, Validation R_squared:0.0878
# Epoch [205/5000], Loss: 0.2108, R-squared: 0.2024,Validation_loss:0.1726, Validation R_squared:0.0888
# Epoch [206/5000], Loss: 0.2107, R-squared: 0.2030,Validation_loss:0.1724, Validation R_squared:0.0898
# Epoch [207/5000], Loss: 0.2105, R-squared: 0.2037,Validation_loss:0.1722, Validation R_squared:0.0909
# Epoch [208/5000], Loss: 0.2104, R-squared: 0.2043,Validation_loss:0.1720, Validation R_squared:0.0919
# Epoch [209/5000], Loss: 0.2102, R-squared: 0.2050,Validation_loss:0.1719, Validation R_squared:0.0930
# Epoch [210/5000], Loss: 0.2100, R-squared: 0.2056,Validation_loss:0.1717, Validation R_squared:0.0940
# Epoch [211/5000], Loss: 0.2099, R-squared: 0.2063,Validation_loss:0.1715, Validation R_squared:0.0951
# Epoch [212/5000], Loss: 0.2097, R-squared: 0.2069,Validation_loss:0.1714, Validation R_squared:0.0961
# Epoch [213/5000], Loss: 0.2096, R-squared: 0.2075,Validation_loss:0.1712, Validation R_squared:0.0972
# Epoch [214/5000], Loss: 0.2094, R-squared: 0.2082,Validation_loss:0.1710, Validation R_squared:0.0983
# Epoch [215/5000], Loss: 0.2093, R-squared: 0.2088,Validation_loss:0.1709, Validation R_squared:0.0993
# Epoch [216/5000], Loss: 0.2091, R-squared: 0.2095,Validation_loss:0.1707, Validation R_squared:0.1004
# Epoch [217/5000], Loss: 0.2090, R-squared: 0.2101,Validation_loss:0.1705, Validation R_squared:0.1015
# Epoch [218/5000], Loss: 0.2088, R-squared: 0.2107,Validation_loss:0.1703, Validation R_squared:0.1025
# Epoch [219/5000], Loss: 0.2086, R-squared: 0.2114,Validation_loss:0.1702, Validation R_squared:0.1036
# Epoch [220/5000], Loss: 0.2085, R-squared: 0.2120,Validation_loss:0.1700, Validation R_squared:0.1047
# Epoch [221/5000], Loss: 0.2083, R-squared: 0.2126,Validation_loss:0.1698, Validation R_squared:0.1057
# Epoch [222/5000], Loss: 0.2082, R-squared: 0.2133,Validation_loss:0.1697, Validation R_squared:0.1068
# Epoch [223/5000], Loss: 0.2080, R-squared: 0.2139,Validation_loss:0.1695, Validation R_squared:0.1078
# Epoch [224/5000], Loss: 0.2079, R-squared: 0.2145,Validation_loss:0.1693, Validation R_squared:0.1088
# Epoch [225/5000], Loss: 0.2077, R-squared: 0.2152,Validation_loss:0.1692, Validation R_squared:0.1098
# Epoch [226/5000], Loss: 0.2076, R-squared: 0.2158,Validation_loss:0.1690, Validation R_squared:0.1109
# Epoch [227/5000], Loss: 0.2074, R-squared: 0.2164,Validation_loss:0.1688, Validation R_squared:0.1119
# Epoch [228/5000], Loss: 0.2073, R-squared: 0.2170,Validation_loss:0.1687, Validation R_squared:0.1129
# Epoch [229/5000], Loss: 0.2071, R-squared: 0.2177,Validation_loss:0.1685, Validation R_squared:0.1139
# Epoch [230/5000], Loss: 0.2070, R-squared: 0.2183,Validation_loss:0.1683, Validation R_squared:0.1149
# Epoch [231/5000], Loss: 0.2068, R-squared: 0.2189,Validation_loss:0.1682, Validation R_squared:0.1160
# Epoch [232/5000], Loss: 0.2067, R-squared: 0.2195,Validation_loss:0.1680, Validation R_squared:0.1170
# Epoch [233/5000], Loss: 0.2065, R-squared: 0.2202,Validation_loss:0.1678, Validation R_squared:0.1181
# Epoch [234/5000], Loss: 0.2064, R-squared: 0.2208,Validation_loss:0.1677, Validation R_squared:0.1191
# Epoch [235/5000], Loss: 0.2062, R-squared: 0.2214,Validation_loss:0.1675, Validation R_squared:0.1201
# Epoch [236/5000], Loss: 0.2061, R-squared: 0.2220,Validation_loss:0.1673, Validation R_squared:0.1212
# Epoch [237/5000], Loss: 0.2059, R-squared: 0.2226,Validation_loss:0.1671, Validation R_squared:0.1222
# Epoch [238/5000], Loss: 0.2058, R-squared: 0.2232,Validation_loss:0.1670, Validation R_squared:0.1232
# Epoch [239/5000], Loss: 0.2056, R-squared: 0.2238,Validation_loss:0.1668, Validation R_squared:0.1243
# Epoch [240/5000], Loss: 0.2055, R-squared: 0.2244,Validation_loss:0.1666, Validation R_squared:0.1253
# Epoch [241/5000], Loss: 0.2053, R-squared: 0.2251,Validation_loss:0.1665, Validation R_squared:0.1263
# Epoch [242/5000], Loss: 0.2052, R-squared: 0.2257,Validation_loss:0.1663, Validation R_squared:0.1274
# Epoch [243/5000], Loss: 0.2050, R-squared: 0.2263,Validation_loss:0.1661, Validation R_squared:0.1284
# Epoch [244/5000], Loss: 0.2049, R-squared: 0.2269,Validation_loss:0.1660, Validation R_squared:0.1294
# Epoch [245/5000], Loss: 0.2047, R-squared: 0.2275,Validation_loss:0.1658, Validation R_squared:0.1305
# Epoch [246/5000], Loss: 0.2046, R-squared: 0.2280,Validation_loss:0.1656, Validation R_squared:0.1315
# Epoch [247/5000], Loss: 0.2044, R-squared: 0.2286,Validation_loss:0.1655, Validation R_squared:0.1325
# Epoch [248/5000], Loss: 0.2043, R-squared: 0.2292,Validation_loss:0.1653, Validation R_squared:0.1336
# Epoch [249/5000], Loss: 0.2041, R-squared: 0.2298,Validation_loss:0.1651, Validation R_squared:0.1346
# Epoch [250/5000], Loss: 0.2040, R-squared: 0.2304,Validation_loss:0.1649, Validation R_squared:0.1357
# Epoch [251/5000], Loss: 0.2038, R-squared: 0.2310,Validation_loss:0.1648, Validation R_squared:0.1367
# Epoch [252/5000], Loss: 0.2037, R-squared: 0.2316,Validation_loss:0.1646, Validation R_squared:0.1378
# Epoch [253/5000], Loss: 0.2036, R-squared: 0.2322,Validation_loss:0.1644, Validation R_squared:0.1388
# Epoch [254/5000], Loss: 0.2034, R-squared: 0.2328,Validation_loss:0.1643, Validation R_squared:0.1399
# Epoch [255/5000], Loss: 0.2033, R-squared: 0.2334,Validation_loss:0.1641, Validation R_squared:0.1409
# Epoch [256/5000], Loss: 0.2031, R-squared: 0.2340,Validation_loss:0.1639, Validation R_squared:0.1420
# Epoch [257/5000], Loss: 0.2030, R-squared: 0.2346,Validation_loss:0.1637, Validation R_squared:0.1430
# Epoch [258/5000], Loss: 0.2028, R-squared: 0.2352,Validation_loss:0.1636, Validation R_squared:0.1441
# Epoch [259/5000], Loss: 0.2027, R-squared: 0.2358,Validation_loss:0.1634, Validation R_squared:0.1452
# Epoch [260/5000], Loss: 0.2025, R-squared: 0.2364,Validation_loss:0.1632, Validation R_squared:0.1462
# Epoch [261/5000], Loss: 0.2024, R-squared: 0.2369,Validation_loss:0.1630, Validation R_squared:0.1473
# Epoch [262/5000], Loss: 0.2023, R-squared: 0.2375,Validation_loss:0.1629, Validation R_squared:0.1483
# Epoch [263/5000], Loss: 0.2021, R-squared: 0.2381,Validation_loss:0.1627, Validation R_squared:0.1494
# Epoch [264/5000], Loss: 0.2020, R-squared: 0.2387,Validation_loss:0.1625, Validation R_squared:0.1505
# Epoch [265/5000], Loss: 0.2018, R-squared: 0.2393,Validation_loss:0.1623, Validation R_squared:0.1516
# Epoch [266/5000], Loss: 0.2017, R-squared: 0.2399,Validation_loss:0.1621, Validation R_squared:0.1526
# Epoch [267/5000], Loss: 0.2015, R-squared: 0.2405,Validation_loss:0.1620, Validation R_squared:0.1537
# Epoch [268/5000], Loss: 0.2014, R-squared: 0.2410,Validation_loss:0.1618, Validation R_squared:0.1548
# Epoch [269/5000], Loss: 0.2013, R-squared: 0.2416,Validation_loss:0.1616, Validation R_squared:0.1558
# Epoch [270/5000], Loss: 0.2011, R-squared: 0.2422,Validation_loss:0.1614, Validation R_squared:0.1569
# Epoch [271/5000], Loss: 0.2010, R-squared: 0.2428,Validation_loss:0.1613, Validation R_squared:0.1580
# Epoch [272/5000], Loss: 0.2008, R-squared: 0.2434,Validation_loss:0.1611, Validation R_squared:0.1590
# Epoch [273/5000], Loss: 0.2007, R-squared: 0.2439,Validation_loss:0.1609, Validation R_squared:0.1601
# Epoch [274/5000], Loss: 0.2006, R-squared: 0.2445,Validation_loss:0.1607, Validation R_squared:0.1612
# Epoch [275/5000], Loss: 0.2004, R-squared: 0.2451,Validation_loss:0.1605, Validation R_squared:0.1622
# Epoch [276/5000], Loss: 0.2003, R-squared: 0.2457,Validation_loss:0.1604, Validation R_squared:0.1633
# Epoch [277/5000], Loss: 0.2001, R-squared: 0.2463,Validation_loss:0.1602, Validation R_squared:0.1643
# Epoch [278/5000], Loss: 0.2000, R-squared: 0.2468,Validation_loss:0.1600, Validation R_squared:0.1654
# Epoch [279/5000], Loss: 0.1999, R-squared: 0.2474,Validation_loss:0.1598, Validation R_squared:0.1664
# Epoch [280/5000], Loss: 0.1997, R-squared: 0.2480,Validation_loss:0.1597, Validation R_squared:0.1674
# Epoch [281/5000], Loss: 0.1996, R-squared: 0.2486,Validation_loss:0.1595, Validation R_squared:0.1685
# Epoch [282/5000], Loss: 0.1994, R-squared: 0.2491,Validation_loss:0.1593, Validation R_squared:0.1695
# Epoch [283/5000], Loss: 0.1993, R-squared: 0.2497,Validation_loss:0.1591, Validation R_squared:0.1705
# Epoch [284/5000], Loss: 0.1992, R-squared: 0.2503,Validation_loss:0.1590, Validation R_squared:0.1716
# Epoch [285/5000], Loss: 0.1990, R-squared: 0.2509,Validation_loss:0.1588, Validation R_squared:0.1726
# Epoch [286/5000], Loss: 0.1989, R-squared: 0.2514,Validation_loss:0.1586, Validation R_squared:0.1736
# Epoch [287/5000], Loss: 0.1987, R-squared: 0.2520,Validation_loss:0.1585, Validation R_squared:0.1746
# Epoch [288/5000], Loss: 0.1986, R-squared: 0.2526,Validation_loss:0.1583, Validation R_squared:0.1757
# Epoch [289/5000], Loss: 0.1985, R-squared: 0.2531,Validation_loss:0.1581, Validation R_squared:0.1767
# Epoch [290/5000], Loss: 0.1983, R-squared: 0.2537,Validation_loss:0.1579, Validation R_squared:0.1777
# Epoch [291/5000], Loss: 0.1982, R-squared: 0.2543,Validation_loss:0.1578, Validation R_squared:0.1788
# Epoch [292/5000], Loss: 0.1981, R-squared: 0.2548,Validation_loss:0.1576, Validation R_squared:0.1798
# Epoch [293/5000], Loss: 0.1979, R-squared: 0.2554,Validation_loss:0.1574, Validation R_squared:0.1808
# Epoch [294/5000], Loss: 0.1978, R-squared: 0.2560,Validation_loss:0.1572, Validation R_squared:0.1819
# Epoch [295/5000], Loss: 0.1977, R-squared: 0.2565,Validation_loss:0.1571, Validation R_squared:0.1829
# Epoch [296/5000], Loss: 0.1975, R-squared: 0.2571,Validation_loss:0.1569, Validation R_squared:0.1840
# Epoch [297/5000], Loss: 0.1974, R-squared: 0.2576,Validation_loss:0.1567, Validation R_squared:0.1850
# Epoch [298/5000], Loss: 0.1972, R-squared: 0.2582,Validation_loss:0.1565, Validation R_squared:0.1860
# Epoch [299/5000], Loss: 0.1971, R-squared: 0.2587,Validation_loss:0.1563, Validation R_squared:0.1871
# Epoch [300/5000], Loss: 0.1970, R-squared: 0.2593,Validation_loss:0.1562, Validation R_squared:0.1881
# Epoch [301/5000], Loss: 0.1968, R-squared: 0.2598,Validation_loss:0.1560, Validation R_squared:0.1891
# Epoch [302/5000], Loss: 0.1967, R-squared: 0.2604,Validation_loss:0.1558, Validation R_squared:0.1902
# Epoch [303/5000], Loss: 0.1966, R-squared: 0.2610,Validation_loss:0.1556, Validation R_squared:0.1912
# Epoch [304/5000], Loss: 0.1964, R-squared: 0.2615,Validation_loss:0.1555, Validation R_squared:0.1922
# Epoch [305/5000], Loss: 0.1963, R-squared: 0.2621,Validation_loss:0.1553, Validation R_squared:0.1933
# Epoch [306/5000], Loss: 0.1962, R-squared: 0.2626,Validation_loss:0.1551, Validation R_squared:0.1943
# Epoch [307/5000], Loss: 0.1960, R-squared: 0.2631,Validation_loss:0.1549, Validation R_squared:0.1953
# Epoch [308/5000], Loss: 0.1959, R-squared: 0.2637,Validation_loss:0.1548, Validation R_squared:0.1963
# Epoch [309/5000], Loss: 0.1958, R-squared: 0.2642,Validation_loss:0.1546, Validation R_squared:0.1973
# Epoch [310/5000], Loss: 0.1956, R-squared: 0.2648,Validation_loss:0.1544, Validation R_squared:0.1984
# Epoch [311/5000], Loss: 0.1955, R-squared: 0.2653,Validation_loss:0.1542, Validation R_squared:0.1994
# Epoch [312/5000], Loss: 0.1954, R-squared: 0.2659,Validation_loss:0.1541, Validation R_squared:0.2004
# Epoch [313/5000], Loss: 0.1952, R-squared: 0.2664,Validation_loss:0.1539, Validation R_squared:0.2014
# Epoch [314/5000], Loss: 0.1951, R-squared: 0.2670,Validation_loss:0.1537, Validation R_squared:0.2025
# Epoch [315/5000], Loss: 0.1950, R-squared: 0.2675,Validation_loss:0.1535, Validation R_squared:0.2035
# Epoch [316/5000], Loss: 0.1949, R-squared: 0.2681,Validation_loss:0.1534, Validation R_squared:0.2045
# Epoch [317/5000], Loss: 0.1947, R-squared: 0.2686,Validation_loss:0.1532, Validation R_squared:0.2056
# Epoch [318/5000], Loss: 0.1946, R-squared: 0.2692,Validation_loss:0.1530, Validation R_squared:0.2066
# Epoch [319/5000], Loss: 0.1945, R-squared: 0.2697,Validation_loss:0.1528, Validation R_squared:0.2076
# Epoch [320/5000], Loss: 0.1943, R-squared: 0.2702,Validation_loss:0.1526, Validation R_squared:0.2087
# Epoch [321/5000], Loss: 0.1942, R-squared: 0.2708,Validation_loss:0.1525, Validation R_squared:0.2097
# Epoch [322/5000], Loss: 0.1941, R-squared: 0.2713,Validation_loss:0.1523, Validation R_squared:0.2107
# Epoch [323/5000], Loss: 0.1939, R-squared: 0.2719,Validation_loss:0.1521, Validation R_squared:0.2118
# Epoch [324/5000], Loss: 0.1938, R-squared: 0.2724,Validation_loss:0.1519, Validation R_squared:0.2128
# Epoch [325/5000], Loss: 0.1937, R-squared: 0.2729,Validation_loss:0.1517, Validation R_squared:0.2138
# Epoch [326/5000], Loss: 0.1936, R-squared: 0.2735,Validation_loss:0.1516, Validation R_squared:0.2149
# Epoch [327/5000], Loss: 0.1934, R-squared: 0.2740,Validation_loss:0.1514, Validation R_squared:0.2159
# Epoch [328/5000], Loss: 0.1933, R-squared: 0.2745,Validation_loss:0.1512, Validation R_squared:0.2170
# Epoch [329/5000], Loss: 0.1932, R-squared: 0.2751,Validation_loss:0.1510, Validation R_squared:0.2180
# Epoch [330/5000], Loss: 0.1930, R-squared: 0.2756,Validation_loss:0.1508, Validation R_squared:0.2191
# Epoch [331/5000], Loss: 0.1929, R-squared: 0.2761,Validation_loss:0.1507, Validation R_squared:0.2201
# Epoch [332/5000], Loss: 0.1928, R-squared: 0.2767,Validation_loss:0.1505, Validation R_squared:0.2212
# Epoch [333/5000], Loss: 0.1927, R-squared: 0.2772,Validation_loss:0.1503, Validation R_squared:0.2222
# Epoch [334/5000], Loss: 0.1925, R-squared: 0.2777,Validation_loss:0.1501, Validation R_squared:0.2232
# Epoch [335/5000], Loss: 0.1924, R-squared: 0.2782,Validation_loss:0.1499, Validation R_squared:0.2243
# Epoch [336/5000], Loss: 0.1923, R-squared: 0.2788,Validation_loss:0.1497, Validation R_squared:0.2253
# Epoch [337/5000], Loss: 0.1922, R-squared: 0.2793,Validation_loss:0.1496, Validation R_squared:0.2264
# Epoch [338/5000], Loss: 0.1920, R-squared: 0.2798,Validation_loss:0.1494, Validation R_squared:0.2274
# Epoch [339/5000], Loss: 0.1919, R-squared: 0.2803,Validation_loss:0.1492, Validation R_squared:0.2284
# Epoch [340/5000], Loss: 0.1918, R-squared: 0.2808,Validation_loss:0.1490, Validation R_squared:0.2294
# Epoch [341/5000], Loss: 0.1917, R-squared: 0.2814,Validation_loss:0.1489, Validation R_squared:0.2304
# Epoch [342/5000], Loss: 0.1915, R-squared: 0.2819,Validation_loss:0.1487, Validation R_squared:0.2315
# Epoch [343/5000], Loss: 0.1914, R-squared: 0.2824,Validation_loss:0.1485, Validation R_squared:0.2325
# Epoch [344/5000], Loss: 0.1913, R-squared: 0.2829,Validation_loss:0.1483, Validation R_squared:0.2335
# Epoch [345/5000], Loss: 0.1912, R-squared: 0.2835,Validation_loss:0.1481, Validation R_squared:0.2345
# Epoch [346/5000], Loss: 0.1910, R-squared: 0.2840,Validation_loss:0.1480, Validation R_squared:0.2355
# Epoch [347/5000], Loss: 0.1909, R-squared: 0.2845,Validation_loss:0.1478, Validation R_squared:0.2365
# Epoch [348/5000], Loss: 0.1908, R-squared: 0.2850,Validation_loss:0.1476, Validation R_squared:0.2375
# Epoch [349/5000], Loss: 0.1907, R-squared: 0.2855,Validation_loss:0.1474, Validation R_squared:0.2385
# Epoch [350/5000], Loss: 0.1905, R-squared: 0.2860,Validation_loss:0.1473, Validation R_squared:0.2396
# Epoch [351/5000], Loss: 0.1904, R-squared: 0.2866,Validation_loss:0.1471, Validation R_squared:0.2406
# Epoch [352/5000], Loss: 0.1903, R-squared: 0.2871,Validation_loss:0.1469, Validation R_squared:0.2416
# Epoch [353/5000], Loss: 0.1902, R-squared: 0.2876,Validation_loss:0.1467, Validation R_squared:0.2426
# Epoch [354/5000], Loss: 0.1900, R-squared: 0.2881,Validation_loss:0.1465, Validation R_squared:0.2436
# Epoch [355/5000], Loss: 0.1899, R-squared: 0.2886,Validation_loss:0.1464, Validation R_squared:0.2446
# Epoch [356/5000], Loss: 0.1898, R-squared: 0.2891,Validation_loss:0.1462, Validation R_squared:0.2455
# Epoch [357/5000], Loss: 0.1897, R-squared: 0.2896,Validation_loss:0.1460, Validation R_squared:0.2465
# Epoch [358/5000], Loss: 0.1895, R-squared: 0.2901,Validation_loss:0.1459, Validation R_squared:0.2475
# Epoch [359/5000], Loss: 0.1894, R-squared: 0.2906,Validation_loss:0.1457, Validation R_squared:0.2485
# Epoch [360/5000], Loss: 0.1893, R-squared: 0.2912,Validation_loss:0.1455, Validation R_squared:0.2495
# Epoch [361/5000], Loss: 0.1892, R-squared: 0.2917,Validation_loss:0.1453, Validation R_squared:0.2505
# Epoch [362/5000], Loss: 0.1891, R-squared: 0.2922,Validation_loss:0.1452, Validation R_squared:0.2514
# Epoch [363/5000], Loss: 0.1889, R-squared: 0.2927,Validation_loss:0.1450, Validation R_squared:0.2524
# Epoch [364/5000], Loss: 0.1888, R-squared: 0.2932,Validation_loss:0.1448, Validation R_squared:0.2534
# Epoch [365/5000], Loss: 0.1887, R-squared: 0.2937,Validation_loss:0.1446, Validation R_squared:0.2544
# Epoch [366/5000], Loss: 0.1886, R-squared: 0.2942,Validation_loss:0.1445, Validation R_squared:0.2554
# Epoch [367/5000], Loss: 0.1885, R-squared: 0.2947,Validation_loss:0.1443, Validation R_squared:0.2564
# Epoch [368/5000], Loss: 0.1883, R-squared: 0.2952,Validation_loss:0.1441, Validation R_squared:0.2574
# Epoch [369/5000], Loss: 0.1882, R-squared: 0.2956,Validation_loss:0.1439, Validation R_squared:0.2584
# Epoch [370/5000], Loss: 0.1881, R-squared: 0.2961,Validation_loss:0.1438, Validation R_squared:0.2593
# Epoch [371/5000], Loss: 0.1880, R-squared: 0.2966,Validation_loss:0.1436, Validation R_squared:0.2603
# Epoch [372/5000], Loss: 0.1879, R-squared: 0.2971,Validation_loss:0.1434, Validation R_squared:0.2613
# Epoch [373/5000], Loss: 0.1878, R-squared: 0.2976,Validation_loss:0.1432, Validation R_squared:0.2623
# Epoch [374/5000], Loss: 0.1876, R-squared: 0.2981,Validation_loss:0.1431, Validation R_squared:0.2633
# Epoch [375/5000], Loss: 0.1875, R-squared: 0.2986,Validation_loss:0.1429, Validation R_squared:0.2642
# Epoch [376/5000], Loss: 0.1874, R-squared: 0.2991,Validation_loss:0.1427, Validation R_squared:0.2652
# Epoch [377/5000], Loss: 0.1873, R-squared: 0.2996,Validation_loss:0.1425, Validation R_squared:0.2662
# Epoch [378/5000], Loss: 0.1872, R-squared: 0.3001,Validation_loss:0.1424, Validation R_squared:0.2672
# Epoch [379/5000], Loss: 0.1871, R-squared: 0.3005,Validation_loss:0.1422, Validation R_squared:0.2681
# Epoch [380/5000], Loss: 0.1869, R-squared: 0.3010,Validation_loss:0.1420, Validation R_squared:0.2691
# Epoch [381/5000], Loss: 0.1868, R-squared: 0.3015,Validation_loss:0.1418, Validation R_squared:0.2700
# Epoch [382/5000], Loss: 0.1867, R-squared: 0.3020,Validation_loss:0.1417, Validation R_squared:0.2710
# Epoch [383/5000], Loss: 0.1866, R-squared: 0.3025,Validation_loss:0.1415, Validation R_squared:0.2720
# Epoch [384/5000], Loss: 0.1865, R-squared: 0.3029,Validation_loss:0.1413, Validation R_squared:0.2729
# Epoch [385/5000], Loss: 0.1864, R-squared: 0.3034,Validation_loss:0.1412, Validation R_squared:0.2738
# Epoch [386/5000], Loss: 0.1863, R-squared: 0.3039,Validation_loss:0.1410, Validation R_squared:0.2748
# Epoch [387/5000], Loss: 0.1861, R-squared: 0.3044,Validation_loss:0.1408, Validation R_squared:0.2757
# Epoch [388/5000], Loss: 0.1860, R-squared: 0.3049,Validation_loss:0.1407, Validation R_squared:0.2767
# Epoch [389/5000], Loss: 0.1859, R-squared: 0.3053,Validation_loss:0.1405, Validation R_squared:0.2776
# Epoch [390/5000], Loss: 0.1858, R-squared: 0.3058,Validation_loss:0.1403, Validation R_squared:0.2785
# Epoch [391/5000], Loss: 0.1857, R-squared: 0.3063,Validation_loss:0.1402, Validation R_squared:0.2795
# Epoch [392/5000], Loss: 0.1856, R-squared: 0.3067,Validation_loss:0.1400, Validation R_squared:0.2804
# Epoch [393/5000], Loss: 0.1855, R-squared: 0.3072,Validation_loss:0.1398, Validation R_squared:0.2813
# Epoch [394/5000], Loss: 0.1854, R-squared: 0.3077,Validation_loss:0.1397, Validation R_squared:0.2823
# Epoch [395/5000], Loss: 0.1852, R-squared: 0.3081,Validation_loss:0.1395, Validation R_squared:0.2832
# Epoch [396/5000], Loss: 0.1851, R-squared: 0.3086,Validation_loss:0.1393, Validation R_squared:0.2841
# Epoch [397/5000], Loss: 0.1850, R-squared: 0.3091,Validation_loss:0.1392, Validation R_squared:0.2850
# Epoch [398/5000], Loss: 0.1849, R-squared: 0.3095,Validation_loss:0.1390, Validation R_squared:0.2859
# Epoch [399/5000], Loss: 0.1848, R-squared: 0.3100,Validation_loss:0.1388, Validation R_squared:0.2869
# Epoch [400/5000], Loss: 0.1847, R-squared: 0.3105,Validation_loss:0.1387, Validation R_squared:0.2878
# Epoch [401/5000], Loss: 0.1846, R-squared: 0.3109,Validation_loss:0.1385, Validation R_squared:0.2887
# Epoch [402/5000], Loss: 0.1845, R-squared: 0.3114,Validation_loss:0.1383, Validation R_squared:0.2896
# Epoch [403/5000], Loss: 0.1844, R-squared: 0.3118,Validation_loss:0.1382, Validation R_squared:0.2905
# Epoch [404/5000], Loss: 0.1843, R-squared: 0.3123,Validation_loss:0.1380, Validation R_squared:0.2914
# Epoch [405/5000], Loss: 0.1842, R-squared: 0.3127,Validation_loss:0.1379, Validation R_squared:0.2922
# Epoch [406/5000], Loss: 0.1840, R-squared: 0.3132,Validation_loss:0.1377, Validation R_squared:0.2931
# Epoch [407/5000], Loss: 0.1839, R-squared: 0.3137,Validation_loss:0.1375, Validation R_squared:0.2940
# Epoch [408/5000], Loss: 0.1838, R-squared: 0.3141,Validation_loss:0.1374, Validation R_squared:0.2949
# Epoch [409/5000], Loss: 0.1837, R-squared: 0.3145,Validation_loss:0.1372, Validation R_squared:0.2958
# Epoch [410/5000], Loss: 0.1836, R-squared: 0.3150,Validation_loss:0.1370, Validation R_squared:0.2967
# Epoch [411/5000], Loss: 0.1835, R-squared: 0.3154,Validation_loss:0.1369, Validation R_squared:0.2976
# Epoch [412/5000], Loss: 0.1834, R-squared: 0.3159,Validation_loss:0.1367, Validation R_squared:0.2984
# Epoch [413/5000], Loss: 0.1833, R-squared: 0.3163,Validation_loss:0.1366, Validation R_squared:0.2993
# Epoch [414/5000], Loss: 0.1832, R-squared: 0.3168,Validation_loss:0.1364, Validation R_squared:0.3002
# Epoch [415/5000], Loss: 0.1831, R-squared: 0.3172,Validation_loss:0.1362, Validation R_squared:0.3011
# Epoch [416/5000], Loss: 0.1830, R-squared: 0.3177,Validation_loss:0.1361, Validation R_squared:0.3019
# Epoch [417/5000], Loss: 0.1829, R-squared: 0.3181,Validation_loss:0.1359, Validation R_squared:0.3028
# Epoch [418/5000], Loss: 0.1828, R-squared: 0.3185,Validation_loss:0.1358, Validation R_squared:0.3037
# Epoch [419/5000], Loss: 0.1827, R-squared: 0.3190,Validation_loss:0.1356, Validation R_squared:0.3045
# Epoch [420/5000], Loss: 0.1826, R-squared: 0.3194,Validation_loss:0.1355, Validation R_squared:0.3054
# Epoch [421/5000], Loss: 0.1825, R-squared: 0.3199,Validation_loss:0.1353, Validation R_squared:0.3063
# Epoch [422/5000], Loss: 0.1824, R-squared: 0.3203,Validation_loss:0.1351, Validation R_squared:0.3072
# Epoch [423/5000], Loss: 0.1823, R-squared: 0.3207,Validation_loss:0.1350, Validation R_squared:0.3080
# Epoch [424/5000], Loss: 0.1822, R-squared: 0.3212,Validation_loss:0.1348, Validation R_squared:0.3089
# Epoch [425/5000], Loss: 0.1821, R-squared: 0.3216,Validation_loss:0.1347, Validation R_squared:0.3098
# Epoch [426/5000], Loss: 0.1820, R-squared: 0.3220,Validation_loss:0.1345, Validation R_squared:0.3106
# Epoch [427/5000], Loss: 0.1818, R-squared: 0.3225,Validation_loss:0.1343, Validation R_squared:0.3115
# Epoch [428/5000], Loss: 0.1817, R-squared: 0.3229,Validation_loss:0.1342, Validation R_squared:0.3124
# Epoch [429/5000], Loss: 0.1816, R-squared: 0.3233,Validation_loss:0.1340, Validation R_squared:0.3132
# Epoch [430/5000], Loss: 0.1815, R-squared: 0.3238,Validation_loss:0.1339, Validation R_squared:0.3141
# Epoch [431/5000], Loss: 0.1814, R-squared: 0.3242,Validation_loss:0.1337, Validation R_squared:0.3149
# Epoch [432/5000], Loss: 0.1813, R-squared: 0.3246,Validation_loss:0.1336, Validation R_squared:0.3157
# Epoch [433/5000], Loss: 0.1812, R-squared: 0.3250,Validation_loss:0.1334, Validation R_squared:0.3166
# Epoch [434/5000], Loss: 0.1811, R-squared: 0.3255,Validation_loss:0.1333, Validation R_squared:0.3174
# Epoch [435/5000], Loss: 0.1810, R-squared: 0.3259,Validation_loss:0.1331, Validation R_squared:0.3183
# Epoch [436/5000], Loss: 0.1809, R-squared: 0.3263,Validation_loss:0.1329, Validation R_squared:0.3191
# Epoch [437/5000], Loss: 0.1808, R-squared: 0.3267,Validation_loss:0.1328, Validation R_squared:0.3200
# Epoch [438/5000], Loss: 0.1807, R-squared: 0.3272,Validation_loss:0.1326, Validation R_squared:0.3208
# Epoch [439/5000], Loss: 0.1806, R-squared: 0.3276,Validation_loss:0.1325, Validation R_squared:0.3216
# Epoch [440/5000], Loss: 0.1805, R-squared: 0.3280,Validation_loss:0.1323, Validation R_squared:0.3225
# Epoch [441/5000], Loss: 0.1804, R-squared: 0.3284,Validation_loss:0.1322, Validation R_squared:0.3233
# Epoch [442/5000], Loss: 0.1803, R-squared: 0.3288,Validation_loss:0.1320, Validation R_squared:0.3242
# Epoch [443/5000], Loss: 0.1802, R-squared: 0.3293,Validation_loss:0.1319, Validation R_squared:0.3250
# Epoch [444/5000], Loss: 0.1801, R-squared: 0.3297,Validation_loss:0.1317, Validation R_squared:0.3258
# Epoch [445/5000], Loss: 0.1800, R-squared: 0.3301,Validation_loss:0.1316, Validation R_squared:0.3266
# Epoch [446/5000], Loss: 0.1799, R-squared: 0.3305,Validation_loss:0.1314, Validation R_squared:0.3274
# Epoch [447/5000], Loss: 0.1799, R-squared: 0.3309,Validation_loss:0.1313, Validation R_squared:0.3283
# Epoch [448/5000], Loss: 0.1798, R-squared: 0.3313,Validation_loss:0.1311, Validation R_squared:0.3291
# Epoch [449/5000], Loss: 0.1797, R-squared: 0.3317,Validation_loss:0.1310, Validation R_squared:0.3299
# Epoch [450/5000], Loss: 0.1796, R-squared: 0.3321,Validation_loss:0.1308, Validation R_squared:0.3307
# Epoch [451/5000], Loss: 0.1795, R-squared: 0.3325,Validation_loss:0.1306, Validation R_squared:0.3315
# Epoch [452/5000], Loss: 0.1794, R-squared: 0.3329,Validation_loss:0.1305, Validation R_squared:0.3323
# Epoch [453/5000], Loss: 0.1793, R-squared: 0.3334,Validation_loss:0.1303, Validation R_squared:0.3332
# Epoch [454/5000], Loss: 0.1792, R-squared: 0.3338,Validation_loss:0.1302, Validation R_squared:0.3340
# Epoch [455/5000], Loss: 0.1791, R-squared: 0.3342,Validation_loss:0.1300, Validation R_squared:0.3348
# Epoch [456/5000], Loss: 0.1790, R-squared: 0.3346,Validation_loss:0.1299, Validation R_squared:0.3356
# Epoch [457/5000], Loss: 0.1789, R-squared: 0.3350,Validation_loss:0.1297, Validation R_squared:0.3364
# Epoch [458/5000], Loss: 0.1788, R-squared: 0.3354,Validation_loss:0.1296, Validation R_squared:0.3372
# Epoch [459/5000], Loss: 0.1787, R-squared: 0.3358,Validation_loss:0.1294, Validation R_squared:0.3380
# Epoch [460/5000], Loss: 0.1786, R-squared: 0.3362,Validation_loss:0.1293, Validation R_squared:0.3389
# Epoch [461/5000], Loss: 0.1785, R-squared: 0.3366,Validation_loss:0.1291, Validation R_squared:0.3397
# Epoch [462/5000], Loss: 0.1784, R-squared: 0.3370,Validation_loss:0.1290, Validation R_squared:0.3405
# Epoch [463/5000], Loss: 0.1783, R-squared: 0.3374,Validation_loss:0.1288, Validation R_squared:0.3413
# Epoch [464/5000], Loss: 0.1782, R-squared: 0.3378,Validation_loss:0.1287, Validation R_squared:0.3421
# Epoch [465/5000], Loss: 0.1781, R-squared: 0.3381,Validation_loss:0.1285, Validation R_squared:0.3429
# Epoch [466/5000], Loss: 0.1780, R-squared: 0.3385,Validation_loss:0.1284, Validation R_squared:0.3437
# Epoch [467/5000], Loss: 0.1779, R-squared: 0.3389,Validation_loss:0.1282, Validation R_squared:0.3445
# Epoch [468/5000], Loss: 0.1779, R-squared: 0.3393,Validation_loss:0.1281, Validation R_squared:0.3452
# Epoch [469/5000], Loss: 0.1778, R-squared: 0.3397,Validation_loss:0.1279, Validation R_squared:0.3460
# Epoch [470/5000], Loss: 0.1777, R-squared: 0.3401,Validation_loss:0.1278, Validation R_squared:0.3468
# ...
# Epoch [4846/5000], Loss: 0.1194, R-squared: 0.5753,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4847/5000], Loss: 0.1194, R-squared: 0.5753,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4848/5000], Loss: 0.1194, R-squared: 0.5753,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4849/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4850/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4851/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4852/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4853/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4854/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4855/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4856/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4857/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4858/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4859/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4860/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4861/5000], Loss: 0.1194, R-squared: 0.5754,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4862/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4863/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4864/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4865/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4866/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4867/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4868/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4869/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4870/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4871/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4872/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4873/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4874/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4875/5000], Loss: 0.1194, R-squared: 0.5755,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4876/5000], Loss: 0.1194, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4877/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4878/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4879/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4880/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4881/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4882/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4883/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4884/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4885/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4886/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4887/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4888/5000], Loss: 0.1193, R-squared: 0.5756,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4889/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4890/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4891/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4892/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4893/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4894/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4895/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4896/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4897/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4898/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4899/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4900/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4901/5000], Loss: 0.1193, R-squared: 0.5757,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4902/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4903/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4904/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4905/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4906/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4907/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4908/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4909/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4910/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4911/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4912/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4913/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4914/5000], Loss: 0.1193, R-squared: 0.5758,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4915/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5671
# Epoch [4916/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4917/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4918/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4919/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4920/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4921/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4922/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4923/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4924/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4925/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4926/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4927/5000], Loss: 0.1193, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4928/5000], Loss: 0.1192, R-squared: 0.5759,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4929/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4930/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4931/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4932/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4933/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4934/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4935/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4936/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4937/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4938/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4939/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4940/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4941/5000], Loss: 0.1192, R-squared: 0.5760,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4942/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4943/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4944/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4945/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4946/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4947/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4948/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4949/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4950/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4951/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4952/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4953/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4954/5000], Loss: 0.1192, R-squared: 0.5761,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4955/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4956/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4957/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4958/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4959/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4960/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4961/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4962/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4963/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4964/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4965/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4966/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4967/5000], Loss: 0.1192, R-squared: 0.5762,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4968/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4969/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4970/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4971/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4972/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4973/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4974/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4975/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4976/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4977/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4978/5000], Loss: 0.1192, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4979/5000], Loss: 0.1191, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4980/5000], Loss: 0.1191, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4981/5000], Loss: 0.1191, R-squared: 0.5763,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4982/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4983/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4984/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4985/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4986/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4987/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4988/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4989/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4990/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4991/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4992/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4993/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4994/5000], Loss: 0.1191, R-squared: 0.5764,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4995/5000], Loss: 0.1191, R-squared: 0.5765,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4996/5000], Loss: 0.1191, R-squared: 0.5765,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4997/5000], Loss: 0.1191, R-squared: 0.5765,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4998/5000], Loss: 0.1191, R-squared: 0.5765,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [4999/5000], Loss: 0.1191, R-squared: 0.5765,Validation_loss:0.0837, Validation R_squared:0.5670
# Epoch [5000/5000], Loss: 0.1191, R-squared: 0.5765,Validation_loss:0.0837, Validation R_squared:0.5670

# %% [markdown]
# ## Plots

# %%
# Create a scatter plot of actual vs. predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', label='Actual vs. Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.grid(True)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', label='Perfect Prediction')
plt.legend()

# Display the plot
plt.show()

# %%
# Create a plot for the loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(num_epochs), losses, label='Test', color='green')
plt.plot(range(num_epochs), val_losses, label='Validation', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.grid(True)

# Create a plot for R-squared
plt.subplot(1, 2, 2)
plt.plot(range(num_epochs), r2_values, label='Test', color='green')
plt.plot(range(num_epochs), r2_validation, label='Validation', color='orange')
plt.xlabel('Epoch')
plt.ylabel('R-squared')
plt.title('R-squared Over Epochs')
plt.legend()
plt.grid(True)

# Display Plot
plt.show()

# %% [markdown]
# ## Gradient

# %%
#extract grad
parameter_importance = model.fc1.weight.grad

# %%
# Convert the parameter_importance tensor to a NumPy array
parameter_importance_img = parameter_importance.detach().numpy()
# Normalize the values to [0, 1]
min_val = parameter_importance_img.min()
max_val = parameter_importance_img.max()

parameter_importance_img = (parameter_importance_img - min_val) / (max_val - min_val)
parameter_importance_img = np.floor(parameter_importance_img*255)

# %% [markdown]
# Display

# %%
# Create a heatmap
plt.figure(figsize=(10, 2))
plt.imshow(parameter_importance_img, cmap='viridis', aspect='auto')
plt.colorbar()
plt.title('Parameter Importance Heatmap')
plt.xlabel('Input Dimension')
plt.ylabel('Gradients')
plt.show()

# %%
data_row=0
# Plot heatmap
plt.figure(figsize=(10, 2))
plt.imshow(parameter_importance_img[0+data_row:3+data_row,:], cmap='viridis', aspect='auto')
plt.colorbar()
plt.title('Parameter Importance Heatmap')
plt.xlabel('Input Dimension')
plt.ylabel('Gradients')
plt.show()
