# %% [markdown]
# <a href="https://colab.research.google.com/github/Justworkname/6367_project/blob/main/Regression_V2_smaller_deltas_saving_failing_%233.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression Model V2_smaller_deltas_testing_save_failed

# %% [markdown]
# ## Import

# %%
# !pip install -q torchinfo

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torch.optim as optim
from torchvision import datasets, transforms
from torchinfo import summary
import numpy as np
import pandas as pd
import os
from PIL import Image
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import torch.optim.lr_scheduler as lr_scheduler

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# this creates a link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# '10 19 2023 meeting.gslides'
# '6 16 2023 Meeting.gslides'
#  6367
#  6367_project
# '6367 Project presentation.gslides'
# '7 12 2023 meeting.gslides'
#  7340
# '8 17 2023 meeting.gslides'
# '8 30 2023 meeting.gslides'
# '9 06 2023 meeting - Bar chart 1.gsheet'
# '9 06 2023 meeting - Column chart 1 (1).gsheet'
# '9 06 2023 meeting - Column chart 1 (2).gsheet'
# '9 06 2023 meeting - Column chart 1.gsheet'
# '9 06 2023 meeting.gslides'
# '9 20 2023 meeting.gslides'
# '9 28 2023 meeting.gslides'
# 'AI in Breast Cancer in Medical Imaging.gslides'
#  AI_MB
#  AI_MB_3D
# 'Colab Notebooks'
#  customTF2
#  Data_Vision_Transformer
#  fakeImages
#  Grad_documents
# 'Invited Lecture 2.gdoc'
# 'Invited Lecture 5.gdoc'
# 'Invited lecture 6.gdoc'
# 'Invited Lecture 7.gdoc'
#  Invited_lecture_oct_10.gdoc
# 'Invited Lecture October 3rd.gdoc'
# 'Invited Lecture September 19th.gdoc'
# 'My Drive'
# 'Presentation Evaluation sep 19.gdoc'
# 'QE Key points.gdoc'
# 'Regression testing.gdoc'
# 'Regression testing multiple deltas.gdoc'
#  Seminar
#  Ultrasound_Images
#  Undergrad_documents
# 'Veterinary Clinic Tumor Estimation Conclusion.gslides'
# 'Wild Magic.gsheet'

# %% [markdown]
# ## Hyperparameters

# %%
num_epochs=5000
input_dim = 54
output_dim = 1
hidden_dim = 3721
dropout=0.01

# %% [markdown]
# ## Load

# %%
# Load the CSV file into a DataFrame
csv_file_path = '/content/gdrive/MyDrive/6367_project/data_v2.csv'
df = pd.read_csv(csv_file_path)
df.fillna(0,inplace=True)
df = df.loc[(df != 0).all(axis=1)] # filter if want

train_patients = ['8', '4', '5', '6', '9','10', '11','13','14','16','19','20','21','23','25']
test_patients = ['3']

df['Patient #'] = df['Patient #'].astype(str)

df_train=df[df['Patient #'].isin(train_patients)]
df_test=df[df['Patient #'].isin(test_patients)]

# Convert to desired data shape
y_train = df_train['Delta Plq Area'] #change with desired prediction
X_train = df_train.drop(columns=['Delta Plq Area','Patient #','Total FU Plq Area','VHIVUS FU img ind','CC FU Area','CC FU Circum Cov.','CC FU max thick',
                     'NC FU Area','NC FU max thick','FI FU Area','FI FU Circum Cov.','FI FU max thick','FF FU Area','FF FU Circum Cov.','FF FU max thick',
                     'VHIVUS BL img ind','BL Pat FRS','BL Pat LDL','BL Pat FFR','BL Pat EEMV','BL Pat BMI','BL Pat BUR']) #data to exclude

y_test = df_test['Delta Plq Area'] #change with desired prediction
X_test = df_test.drop(columns=['Delta Plq Area','Patient #','Total FU Plq Area','VHIVUS FU img ind','CC FU Area','CC FU Circum Cov.','CC FU max thick',
                     'NC FU Area','NC FU max thick','FI FU Area','FI FU Circum Cov.','FI FU max thick','FF FU Area','FF FU Circum Cov.','FF FU max thick',
                     'VHIVUS BL img ind','BL Pat FRS','BL Pat LDL','BL Pat FFR','BL Pat EEMV','BL Pat BMI','BL Pat BUR'])

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.float32)
y_train = y_train.view(-1)
y_test = y_test.view(-1)

# %% [markdown]
# ## Model

# %%
class RegressionModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout):
        super(RegressionModel, self).__init__()

        # Define the layers
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, 100)
        self.relu = nn.ReLU()
        self.fc3 = nn.Linear(100, output_dim)
        #self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        # Forward pass
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        #x = self.dropout(x)
        x = self.fc3(x)
        return x

# %%
model = RegressionModel(input_dim, hidden_dim, output_dim,dropout)

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# RegressionModel                          --
# ├─Linear: 1-1                            204,655
# ├─ReLU: 1-2                              --
# ├─Linear: 1-3                            372,200
# ├─Linear: 1-4                            101
# =================================================================
# Total params: 576,956
# Trainable params: 576,956
# Non-trainable params: 0
# =================================================================

# %%
# Mean Squared Error loss
criterion = nn.SmoothL1Loss()
# Apply optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)
# Learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)

# %% [markdown]
# ## Training

# %%
# List for Loss and R squared
losses = []
val_losses = []
r2_values = []
r2_validation = []

# Training loop
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_train)
    outputs = outputs.squeeze(dim=1)

    # Compute the loss
    ## Could consider Huber Loss
    loss = criterion(outputs, y_train)

    # Backpropagation and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Learning rate annealing
    scheduler.step()

    # Calculate R-squared
    y_pred = outputs.detach().numpy()
    r2 = r2_score(y_train.numpy(), y_pred)

    # Store loss and R-squared values for this epoch
    losses.append(loss.item())
    r2_values.append(r2)

    # Testing predictions
    y_pred = model(X_test).detach().numpy()
    # Calculate R-squared accuracy on the test data
    r2_test = r2_score(y_test.numpy(), y_pred)
    r2_validation.append(r2_test)
    val_out = model(X_test)
    val_out = val_out.squeeze(dim=1)
    val_loss = criterion(val_out,y_test)
    val_losses.append(val_loss.item())

    print('Epoch [{}/{}], Loss: {:.4f}, R-squared: {:.4f},Validation_loss:{:,.4f}, Validation R_squared:{:,.4f}'.format(epoch+1, num_epochs, loss.item(), r2,val_loss.item(),r2_test))
# Out:
# Epoch [1/5000], Loss: 0.2767, R-squared: -0.0660,Validation_loss:0.2317, Validation R_squared:-0.2947
# Epoch [2/5000], Loss: 0.2684, R-squared: -0.0317,Validation_loss:0.2262, Validation R_squared:-0.2593
# Epoch [3/5000], Loss: 0.2625, R-squared: -0.0075,Validation_loss:0.2220, Validation R_squared:-0.2324
# Epoch [4/5000], Loss: 0.2581, R-squared: 0.0106,Validation_loss:0.2188, Validation R_squared:-0.2112
# Epoch [5/5000], Loss: 0.2547, R-squared: 0.0245,Validation_loss:0.2162, Validation R_squared:-0.1941
# Epoch [6/5000], Loss: 0.2520, R-squared: 0.0355,Validation_loss:0.2141, Validation R_squared:-0.1798
# Epoch [7/5000], Loss: 0.2498, R-squared: 0.0445,Validation_loss:0.2123, Validation R_squared:-0.1679
# Epoch [8/5000], Loss: 0.2480, R-squared: 0.0519,Validation_loss:0.2107, Validation R_squared:-0.1575
# Epoch [9/5000], Loss: 0.2464, R-squared: 0.0582,Validation_loss:0.2094, Validation R_squared:-0.1485
# Epoch [10/5000], Loss: 0.2451, R-squared: 0.0636,Validation_loss:0.2082, Validation R_squared:-0.1406
# Epoch [11/5000], Loss: 0.2439, R-squared: 0.0684,Validation_loss:0.2072, Validation R_squared:-0.1338
# Epoch [12/5000], Loss: 0.2429, R-squared: 0.0725,Validation_loss:0.2063, Validation R_squared:-0.1277
# Epoch [13/5000], Loss: 0.2420, R-squared: 0.0763,Validation_loss:0.2054, Validation R_squared:-0.1223
# Epoch [14/5000], Loss: 0.2411, R-squared: 0.0797,Validation_loss:0.2047, Validation R_squared:-0.1174
# Epoch [15/5000], Loss: 0.2404, R-squared: 0.0829,Validation_loss:0.2040, Validation R_squared:-0.1130
# Epoch [16/5000], Loss: 0.2396, R-squared: 0.0859,Validation_loss:0.2034, Validation R_squared:-0.1088
# Epoch [17/5000], Loss: 0.2389, R-squared: 0.0887,Validation_loss:0.2028, Validation R_squared:-0.1049
# Epoch [18/5000], Loss: 0.2383, R-squared: 0.0914,Validation_loss:0.2022, Validation R_squared:-0.1014
# Epoch [19/5000], Loss: 0.2376, R-squared: 0.0939,Validation_loss:0.2017, Validation R_squared:-0.0981
# Epoch [20/5000], Loss: 0.2370, R-squared: 0.0963,Validation_loss:0.2012, Validation R_squared:-0.0950
# Epoch [21/5000], Loss: 0.2365, R-squared: 0.0986,Validation_loss:0.2008, Validation R_squared:-0.0920
# Epoch [22/5000], Loss: 0.2359, R-squared: 0.1009,Validation_loss:0.2003, Validation R_squared:-0.0892
# Epoch [23/5000], Loss: 0.2354, R-squared: 0.1031,Validation_loss:0.1999, Validation R_squared:-0.0866
# Epoch [24/5000], Loss: 0.2348, R-squared: 0.1052,Validation_loss:0.1995, Validation R_squared:-0.0840
# Epoch [25/5000], Loss: 0.2343, R-squared: 0.1073,Validation_loss:0.1991, Validation R_squared:-0.0816
# Epoch [26/5000], Loss: 0.2338, R-squared: 0.1094,Validation_loss:0.1988, Validation R_squared:-0.0792
# Epoch [27/5000], Loss: 0.2333, R-squared: 0.1113,Validation_loss:0.1984, Validation R_squared:-0.0770
# Epoch [28/5000], Loss: 0.2329, R-squared: 0.1132,Validation_loss:0.1981, Validation R_squared:-0.0748
# Epoch [29/5000], Loss: 0.2324, R-squared: 0.1151,Validation_loss:0.1977, Validation R_squared:-0.0727
# Epoch [30/5000], Loss: 0.2320, R-squared: 0.1169,Validation_loss:0.1974, Validation R_squared:-0.0706
# Epoch [31/5000], Loss: 0.2315, R-squared: 0.1187,Validation_loss:0.1971, Validation R_squared:-0.0686
# Epoch [32/5000], Loss: 0.2311, R-squared: 0.1204,Validation_loss:0.1968, Validation R_squared:-0.0666
# Epoch [33/5000], Loss: 0.2307, R-squared: 0.1221,Validation_loss:0.1965, Validation R_squared:-0.0647
# Epoch [34/5000], Loss: 0.2303, R-squared: 0.1237,Validation_loss:0.1962, Validation R_squared:-0.0627
# Epoch [35/5000], Loss: 0.2299, R-squared: 0.1254,Validation_loss:0.1959, Validation R_squared:-0.0608
# Epoch [36/5000], Loss: 0.2295, R-squared: 0.1270,Validation_loss:0.1956, Validation R_squared:-0.0590
# Epoch [37/5000], Loss: 0.2291, R-squared: 0.1286,Validation_loss:0.1953, Validation R_squared:-0.0571
# Epoch [38/5000], Loss: 0.2287, R-squared: 0.1302,Validation_loss:0.1950, Validation R_squared:-0.0552
# Epoch [39/5000], Loss: 0.2283, R-squared: 0.1318,Validation_loss:0.1948, Validation R_squared:-0.0534
# Epoch [40/5000], Loss: 0.2279, R-squared: 0.1333,Validation_loss:0.1945, Validation R_squared:-0.0515
# Epoch [41/5000], Loss: 0.2275, R-squared: 0.1349,Validation_loss:0.1942, Validation R_squared:-0.0496
# Epoch [42/5000], Loss: 0.2271, R-squared: 0.1364,Validation_loss:0.1939, Validation R_squared:-0.0477
# Epoch [43/5000], Loss: 0.2268, R-squared: 0.1379,Validation_loss:0.1936, Validation R_squared:-0.0458
# Epoch [44/5000], Loss: 0.2264, R-squared: 0.1395,Validation_loss:0.1933, Validation R_squared:-0.0440
# Epoch [45/5000], Loss: 0.2260, R-squared: 0.1409,Validation_loss:0.1930, Validation R_squared:-0.0421
# Epoch [46/5000], Loss: 0.2257, R-squared: 0.1424,Validation_loss:0.1927, Validation R_squared:-0.0401
# Epoch [47/5000], Loss: 0.2253, R-squared: 0.1439,Validation_loss:0.1924, Validation R_squared:-0.0382
# Epoch [48/5000], Loss: 0.2249, R-squared: 0.1453,Validation_loss:0.1921, Validation R_squared:-0.0362
# Epoch [49/5000], Loss: 0.2246, R-squared: 0.1468,Validation_loss:0.1918, Validation R_squared:-0.0342
# Epoch [50/5000], Loss: 0.2242, R-squared: 0.1482,Validation_loss:0.1915, Validation R_squared:-0.0322
# Epoch [51/5000], Loss: 0.2239, R-squared: 0.1497,Validation_loss:0.1912, Validation R_squared:-0.0302
# Epoch [52/5000], Loss: 0.2235, R-squared: 0.1511,Validation_loss:0.1909, Validation R_squared:-0.0282
# Epoch [53/5000], Loss: 0.2232, R-squared: 0.1525,Validation_loss:0.1906, Validation R_squared:-0.0262
# Epoch [54/5000], Loss: 0.2228, R-squared: 0.1539,Validation_loss:0.1903, Validation R_squared:-0.0242
# Epoch [55/5000], Loss: 0.2225, R-squared: 0.1554,Validation_loss:0.1900, Validation R_squared:-0.0221
# Epoch [56/5000], Loss: 0.2221, R-squared: 0.1568,Validation_loss:0.1897, Validation R_squared:-0.0201
# Epoch [57/5000], Loss: 0.2218, R-squared: 0.1582,Validation_loss:0.1894, Validation R_squared:-0.0181
# Epoch [58/5000], Loss: 0.2214, R-squared: 0.1596,Validation_loss:0.1890, Validation R_squared:-0.0160
# Epoch [59/5000], Loss: 0.2211, R-squared: 0.1610,Validation_loss:0.1887, Validation R_squared:-0.0139
# Epoch [60/5000], Loss: 0.2208, R-squared: 0.1623,Validation_loss:0.1884, Validation R_squared:-0.0118
# Epoch [61/5000], Loss: 0.2204, R-squared: 0.1637,Validation_loss:0.1881, Validation R_squared:-0.0098
# Epoch [62/5000], Loss: 0.2201, R-squared: 0.1650,Validation_loss:0.1878, Validation R_squared:-0.0077
# Epoch [63/5000], Loss: 0.2198, R-squared: 0.1664,Validation_loss:0.1874, Validation R_squared:-0.0056
# Epoch [64/5000], Loss: 0.2194, R-squared: 0.1677,Validation_loss:0.1871, Validation R_squared:-0.0034
# Epoch [65/5000], Loss: 0.2191, R-squared: 0.1690,Validation_loss:0.1868, Validation R_squared:-0.0013
# Epoch [66/5000], Loss: 0.2188, R-squared: 0.1704,Validation_loss:0.1864, Validation R_squared:0.0009
# Epoch [67/5000], Loss: 0.2185, R-squared: 0.1717,Validation_loss:0.1861, Validation R_squared:0.0030
# Epoch [68/5000], Loss: 0.2182, R-squared: 0.1730,Validation_loss:0.1858, Validation R_squared:0.0051
# Epoch [69/5000], Loss: 0.2178, R-squared: 0.1743,Validation_loss:0.1854, Validation R_squared:0.0072
# Epoch [70/5000], Loss: 0.2175, R-squared: 0.1756,Validation_loss:0.1851, Validation R_squared:0.0093
# Epoch [71/5000], Loss: 0.2172, R-squared: 0.1769,Validation_loss:0.1848, Validation R_squared:0.0113
# Epoch [72/5000], Loss: 0.2169, R-squared: 0.1781,Validation_loss:0.1845, Validation R_squared:0.0134
# Epoch [73/5000], Loss: 0.2166, R-squared: 0.1794,Validation_loss:0.1842, Validation R_squared:0.0155
# Epoch [74/5000], Loss: 0.2163, R-squared: 0.1807,Validation_loss:0.1838, Validation R_squared:0.0176
# Epoch [75/5000], Loss: 0.2159, R-squared: 0.1820,Validation_loss:0.1835, Validation R_squared:0.0198
# Epoch [76/5000], Loss: 0.2156, R-squared: 0.1832,Validation_loss:0.1831, Validation R_squared:0.0220
# Epoch [77/5000], Loss: 0.2153, R-squared: 0.1845,Validation_loss:0.1828, Validation R_squared:0.0241
# Epoch [78/5000], Loss: 0.2150, R-squared: 0.1858,Validation_loss:0.1825, Validation R_squared:0.0262
# Epoch [79/5000], Loss: 0.2147, R-squared: 0.1870,Validation_loss:0.1821, Validation R_squared:0.0284
# Epoch [80/5000], Loss: 0.2144, R-squared: 0.1883,Validation_loss:0.1818, Validation R_squared:0.0306
# Epoch [81/5000], Loss: 0.2141, R-squared: 0.1896,Validation_loss:0.1814, Validation R_squared:0.0328
# Epoch [82/5000], Loss: 0.2138, R-squared: 0.1908,Validation_loss:0.1811, Validation R_squared:0.0351
# Epoch [83/5000], Loss: 0.2135, R-squared: 0.1921,Validation_loss:0.1807, Validation R_squared:0.0373
# Epoch [84/5000], Loss: 0.2132, R-squared: 0.1933,Validation_loss:0.1804, Validation R_squared:0.0395
# Epoch [85/5000], Loss: 0.2128, R-squared: 0.1946,Validation_loss:0.1800, Validation R_squared:0.0417
# Epoch [86/5000], Loss: 0.2125, R-squared: 0.1958,Validation_loss:0.1797, Validation R_squared:0.0440
# Epoch [87/5000], Loss: 0.2122, R-squared: 0.1971,Validation_loss:0.1793, Validation R_squared:0.0463
# Epoch [88/5000], Loss: 0.2119, R-squared: 0.1983,Validation_loss:0.1790, Validation R_squared:0.0485
# Epoch [89/5000], Loss: 0.2116, R-squared: 0.1996,Validation_loss:0.1786, Validation R_squared:0.0508
# Epoch [90/5000], Loss: 0.2113, R-squared: 0.2008,Validation_loss:0.1782, Validation R_squared:0.0531
# Epoch [91/5000], Loss: 0.2110, R-squared: 0.2021,Validation_loss:0.1779, Validation R_squared:0.0553
# Epoch [92/5000], Loss: 0.2107, R-squared: 0.2033,Validation_loss:0.1775, Validation R_squared:0.0576
# Epoch [93/5000], Loss: 0.2104, R-squared: 0.2045,Validation_loss:0.1772, Validation R_squared:0.0598
# Epoch [94/5000], Loss: 0.2101, R-squared: 0.2058,Validation_loss:0.1768, Validation R_squared:0.0621
# Epoch [95/5000], Loss: 0.2098, R-squared: 0.2070,Validation_loss:0.1764, Validation R_squared:0.0643
# Epoch [96/5000], Loss: 0.2095, R-squared: 0.2082,Validation_loss:0.1761, Validation R_squared:0.0665
# Epoch [97/5000], Loss: 0.2092, R-squared: 0.2094,Validation_loss:0.1757, Validation R_squared:0.0687
# Epoch [98/5000], Loss: 0.2089, R-squared: 0.2106,Validation_loss:0.1754, Validation R_squared:0.0709
# Epoch [99/5000], Loss: 0.2086, R-squared: 0.2118,Validation_loss:0.1750, Validation R_squared:0.0731
# Epoch [100/5000], Loss: 0.2083, R-squared: 0.2131,Validation_loss:0.1747, Validation R_squared:0.0752
# Epoch [101/5000], Loss: 0.2080, R-squared: 0.2143,Validation_loss:0.1743, Validation R_squared:0.0774
# Epoch [102/5000], Loss: 0.2077, R-squared: 0.2155,Validation_loss:0.1740, Validation R_squared:0.0795
# Epoch [103/5000], Loss: 0.2074, R-squared: 0.2167,Validation_loss:0.1737, Validation R_squared:0.0817
# Epoch [104/5000], Loss: 0.2071, R-squared: 0.2179,Validation_loss:0.1733, Validation R_squared:0.0839
# Epoch [105/5000], Loss: 0.2068, R-squared: 0.2191,Validation_loss:0.1729, Validation R_squared:0.0861
# Epoch [106/5000], Loss: 0.2065, R-squared: 0.2203,Validation_loss:0.1726, Validation R_squared:0.0884
# Epoch [107/5000], Loss: 0.2063, R-squared: 0.2214,Validation_loss:0.1722, Validation R_squared:0.0906
# Epoch [108/5000], Loss: 0.2060, R-squared: 0.2226,Validation_loss:0.1718, Validation R_squared:0.0929
# Epoch [109/5000], Loss: 0.2057, R-squared: 0.2238,Validation_loss:0.1715, Validation R_squared:0.0951
# Epoch [110/5000], Loss: 0.2054, R-squared: 0.2250,Validation_loss:0.1711, Validation R_squared:0.0973
# Epoch [111/5000], Loss: 0.2051, R-squared: 0.2262,Validation_loss:0.1708, Validation R_squared:0.0994
# Epoch [112/5000], Loss: 0.2048, R-squared: 0.2273,Validation_loss:0.1704, Validation R_squared:0.1016
# Epoch [113/5000], Loss: 0.2045, R-squared: 0.2285,Validation_loss:0.1701, Validation R_squared:0.1038
# Epoch [114/5000], Loss: 0.2042, R-squared: 0.2297,Validation_loss:0.1697, Validation R_squared:0.1060
# Epoch [115/5000], Loss: 0.2040, R-squared: 0.2308,Validation_loss:0.1693, Validation R_squared:0.1082
# Epoch [116/5000], Loss: 0.2037, R-squared: 0.2320,Validation_loss:0.1690, Validation R_squared:0.1104
# Epoch [117/5000], Loss: 0.2034, R-squared: 0.2331,Validation_loss:0.1686, Validation R_squared:0.1126
# Epoch [118/5000], Loss: 0.2031, R-squared: 0.2343,Validation_loss:0.1683, Validation R_squared:0.1148
# Epoch [119/5000], Loss: 0.2028, R-squared: 0.2354,Validation_loss:0.1679, Validation R_squared:0.1171
# Epoch [120/5000], Loss: 0.2026, R-squared: 0.2366,Validation_loss:0.1675, Validation R_squared:0.1193
# Epoch [121/5000], Loss: 0.2023, R-squared: 0.2377,Validation_loss:0.1672, Validation R_squared:0.1214
# Epoch [122/5000], Loss: 0.2020, R-squared: 0.2389,Validation_loss:0.1668, Validation R_squared:0.1237
# Epoch [123/5000], Loss: 0.2017, R-squared: 0.2400,Validation_loss:0.1664, Validation R_squared:0.1259
# Epoch [124/5000], Loss: 0.2014, R-squared: 0.2412,Validation_loss:0.1661, Validation R_squared:0.1281
# Epoch [125/5000], Loss: 0.2012, R-squared: 0.2423,Validation_loss:0.1657, Validation R_squared:0.1303
# Epoch [126/5000], Loss: 0.2009, R-squared: 0.2434,Validation_loss:0.1653, Validation R_squared:0.1325
# Epoch [127/5000], Loss: 0.2006, R-squared: 0.2445,Validation_loss:0.1650, Validation R_squared:0.1347
# Epoch [128/5000], Loss: 0.2003, R-squared: 0.2456,Validation_loss:0.1646, Validation R_squared:0.1369
# Epoch [129/5000], Loss: 0.2001, R-squared: 0.2467,Validation_loss:0.1642, Validation R_squared:0.1390
# Epoch [130/5000], Loss: 0.1998, R-squared: 0.2478,Validation_loss:0.1639, Validation R_squared:0.1412
# Epoch [131/5000], Loss: 0.1995, R-squared: 0.2489,Validation_loss:0.1635, Validation R_squared:0.1434
# Epoch [132/5000], Loss: 0.1993, R-squared: 0.2500,Validation_loss:0.1631, Validation R_squared:0.1456
# Epoch [133/5000], Loss: 0.1990, R-squared: 0.2511,Validation_loss:0.1628, Validation R_squared:0.1479
# Epoch [134/5000], Loss: 0.1988, R-squared: 0.2521,Validation_loss:0.1624, Validation R_squared:0.1501
# Epoch [135/5000], Loss: 0.1985, R-squared: 0.2532,Validation_loss:0.1620, Validation R_squared:0.1523
# Epoch [136/5000], Loss: 0.1982, R-squared: 0.2542,Validation_loss:0.1617, Validation R_squared:0.1544
# Epoch [137/5000], Loss: 0.1980, R-squared: 0.2553,Validation_loss:0.1613, Validation R_squared:0.1566
# Epoch [138/5000], Loss: 0.1977, R-squared: 0.2564,Validation_loss:0.1609, Validation R_squared:0.1587
# Epoch [139/5000], Loss: 0.1975, R-squared: 0.2574,Validation_loss:0.1606, Validation R_squared:0.1609
# Epoch [140/5000], Loss: 0.1972, R-squared: 0.2585,Validation_loss:0.1602, Validation R_squared:0.1630
# Epoch [141/5000], Loss: 0.1970, R-squared: 0.2595,Validation_loss:0.1599, Validation R_squared:0.1652
# Epoch [142/5000], Loss: 0.1967, R-squared: 0.2605,Validation_loss:0.1595, Validation R_squared:0.1673
# Epoch [143/5000], Loss: 0.1965, R-squared: 0.2615,Validation_loss:0.1591, Validation R_squared:0.1695
# Epoch [144/5000], Loss: 0.1962, R-squared: 0.2626,Validation_loss:0.1588, Validation R_squared:0.1716
# Epoch [145/5000], Loss: 0.1960, R-squared: 0.2636,Validation_loss:0.1584, Validation R_squared:0.1737
# Epoch [146/5000], Loss: 0.1957, R-squared: 0.2646,Validation_loss:0.1580, Validation R_squared:0.1759
# Epoch [147/5000], Loss: 0.1955, R-squared: 0.2656,Validation_loss:0.1577, Validation R_squared:0.1780
# Epoch [148/5000], Loss: 0.1952, R-squared: 0.2666,Validation_loss:0.1573, Validation R_squared:0.1801
# Epoch [149/5000], Loss: 0.1950, R-squared: 0.2676,Validation_loss:0.1569, Validation R_squared:0.1822
# Epoch [150/5000], Loss: 0.1948, R-squared: 0.2685,Validation_loss:0.1566, Validation R_squared:0.1843
# Epoch [151/5000], Loss: 0.1945, R-squared: 0.2695,Validation_loss:0.1562, Validation R_squared:0.1864
# Epoch [152/5000], Loss: 0.1943, R-squared: 0.2705,Validation_loss:0.1559, Validation R_squared:0.1885
# Epoch [153/5000], Loss: 0.1941, R-squared: 0.2715,Validation_loss:0.1555, Validation R_squared:0.1905
# Epoch [154/5000], Loss: 0.1938, R-squared: 0.2724,Validation_loss:0.1552, Validation R_squared:0.1925
# Epoch [155/5000], Loss: 0.1936, R-squared: 0.2734,Validation_loss:0.1548, Validation R_squared:0.1945
# Epoch [156/5000], Loss: 0.1934, R-squared: 0.2744,Validation_loss:0.1545, Validation R_squared:0.1966
# Epoch [157/5000], Loss: 0.1931, R-squared: 0.2753,Validation_loss:0.1541, Validation R_squared:0.1986
# Epoch [158/5000], Loss: 0.1929, R-squared: 0.2763,Validation_loss:0.1538, Validation R_squared:0.2006
# Epoch [159/5000], Loss: 0.1927, R-squared: 0.2772,Validation_loss:0.1534, Validation R_squared:0.2026
# Epoch [160/5000], Loss: 0.1924, R-squared: 0.2782,Validation_loss:0.1531, Validation R_squared:0.2046
# Epoch [161/5000], Loss: 0.1922, R-squared: 0.2791,Validation_loss:0.1528, Validation R_squared:0.2066
# Epoch [162/5000], Loss: 0.1920, R-squared: 0.2800,Validation_loss:0.1524, Validation R_squared:0.2086
# Epoch [163/5000], Loss: 0.1917, R-squared: 0.2810,Validation_loss:0.1521, Validation R_squared:0.2105
# Epoch [164/5000], Loss: 0.1915, R-squared: 0.2819,Validation_loss:0.1517, Validation R_squared:0.2125
# Epoch [165/5000], Loss: 0.1913, R-squared: 0.2828,Validation_loss:0.1514, Validation R_squared:0.2145
# Epoch [166/5000], Loss: 0.1911, R-squared: 0.2838,Validation_loss:0.1510, Validation R_squared:0.2165
# Epoch [167/5000], Loss: 0.1909, R-squared: 0.2847,Validation_loss:0.1507, Validation R_squared:0.2185
# Epoch [168/5000], Loss: 0.1906, R-squared: 0.2856,Validation_loss:0.1503, Validation R_squared:0.2205
# Epoch [169/5000], Loss: 0.1904, R-squared: 0.2865,Validation_loss:0.1500, Validation R_squared:0.2226
# Epoch [170/5000], Loss: 0.1902, R-squared: 0.2874,Validation_loss:0.1496, Validation R_squared:0.2246
# Epoch [171/5000], Loss: 0.1900, R-squared: 0.2883,Validation_loss:0.1493, Validation R_squared:0.2266
# Epoch [172/5000], Loss: 0.1898, R-squared: 0.2892,Validation_loss:0.1489, Validation R_squared:0.2286
# Epoch [173/5000], Loss: 0.1895, R-squared: 0.2901,Validation_loss:0.1486, Validation R_squared:0.2306
# Epoch [174/5000], Loss: 0.1893, R-squared: 0.2910,Validation_loss:0.1482, Validation R_squared:0.2326
# Epoch [175/5000], Loss: 0.1891, R-squared: 0.2918,Validation_loss:0.1479, Validation R_squared:0.2345
# Epoch [176/5000], Loss: 0.1889, R-squared: 0.2927,Validation_loss:0.1475, Validation R_squared:0.2365
# Epoch [177/5000], Loss: 0.1887, R-squared: 0.2936,Validation_loss:0.1472, Validation R_squared:0.2384
# Epoch [178/5000], Loss: 0.1885, R-squared: 0.2945,Validation_loss:0.1468, Validation R_squared:0.2404
# Epoch [179/5000], Loss: 0.1883, R-squared: 0.2954,Validation_loss:0.1465, Validation R_squared:0.2423
# Epoch [180/5000], Loss: 0.1881, R-squared: 0.2962,Validation_loss:0.1462, Validation R_squared:0.2443
# Epoch [181/5000], Loss: 0.1878, R-squared: 0.2971,Validation_loss:0.1458, Validation R_squared:0.2462
# Epoch [182/5000], Loss: 0.1876, R-squared: 0.2980,Validation_loss:0.1455, Validation R_squared:0.2481
# Epoch [183/5000], Loss: 0.1874, R-squared: 0.2988,Validation_loss:0.1452, Validation R_squared:0.2500
# Epoch [184/5000], Loss: 0.1872, R-squared: 0.2997,Validation_loss:0.1448, Validation R_squared:0.2518
# Epoch [185/5000], Loss: 0.1870, R-squared: 0.3006,Validation_loss:0.1445, Validation R_squared:0.2538
# Epoch [186/5000], Loss: 0.1868, R-squared: 0.3014,Validation_loss:0.1442, Validation R_squared:0.2557
# Epoch [187/5000], Loss: 0.1866, R-squared: 0.3023,Validation_loss:0.1438, Validation R_squared:0.2575
# Epoch [188/5000], Loss: 0.1864, R-squared: 0.3032,Validation_loss:0.1435, Validation R_squared:0.2593
# Epoch [189/5000], Loss: 0.1862, R-squared: 0.3040,Validation_loss:0.1432, Validation R_squared:0.2612
# Epoch [190/5000], Loss: 0.1860, R-squared: 0.3048,Validation_loss:0.1429, Validation R_squared:0.2630
# Epoch [191/5000], Loss: 0.1858, R-squared: 0.3057,Validation_loss:0.1425, Validation R_squared:0.2648
# Epoch [192/5000], Loss: 0.1856, R-squared: 0.3065,Validation_loss:0.1422, Validation R_squared:0.2666
# Epoch [193/5000], Loss: 0.1854, R-squared: 0.3074,Validation_loss:0.1419, Validation R_squared:0.2684
# Epoch [194/5000], Loss: 0.1852, R-squared: 0.3082,Validation_loss:0.1416, Validation R_squared:0.2703
# Epoch [195/5000], Loss: 0.1849, R-squared: 0.3090,Validation_loss:0.1412, Validation R_squared:0.2721
# Epoch [196/5000], Loss: 0.1847, R-squared: 0.3098,Validation_loss:0.1409, Validation R_squared:0.2739
# Epoch [197/5000], Loss: 0.1846, R-squared: 0.3107,Validation_loss:0.1406, Validation R_squared:0.2757
# Epoch [198/5000], Loss: 0.1844, R-squared: 0.3115,Validation_loss:0.1403, Validation R_squared:0.2774
# Epoch [199/5000], Loss: 0.1842, R-squared: 0.3123,Validation_loss:0.1399, Validation R_squared:0.2793
# Epoch [200/5000], Loss: 0.1840, R-squared: 0.3131,Validation_loss:0.1396, Validation R_squared:0.2810
# Epoch [201/5000], Loss: 0.1838, R-squared: 0.3139,Validation_loss:0.1393, Validation R_squared:0.2828
# Epoch [202/5000], Loss: 0.1836, R-squared: 0.3147,Validation_loss:0.1390, Validation R_squared:0.2846
# Epoch [203/5000], Loss: 0.1834, R-squared: 0.3155,Validation_loss:0.1387, Validation R_squared:0.2863
# Epoch [204/5000], Loss: 0.1832, R-squared: 0.3163,Validation_loss:0.1384, Validation R_squared:0.2881
# Epoch [205/5000], Loss: 0.1830, R-squared: 0.3170,Validation_loss:0.1381, Validation R_squared:0.2898
# Epoch [206/5000], Loss: 0.1828, R-squared: 0.3178,Validation_loss:0.1377, Validation R_squared:0.2916
# Epoch [207/5000], Loss: 0.1826, R-squared: 0.3186,Validation_loss:0.1374, Validation R_squared:0.2934
# Epoch [208/5000], Loss: 0.1824, R-squared: 0.3194,Validation_loss:0.1371, Validation R_squared:0.2950
# Epoch [209/5000], Loss: 0.1823, R-squared: 0.3201,Validation_loss:0.1368, Validation R_squared:0.2968
# Epoch [210/5000], Loss: 0.1821, R-squared: 0.3209,Validation_loss:0.1365, Validation R_squared:0.2985
# Epoch [211/5000], Loss: 0.1819, R-squared: 0.3217,Validation_loss:0.1362, Validation R_squared:0.3002
# Epoch [212/5000], Loss: 0.1817, R-squared: 0.3224,Validation_loss:0.1359, Validation R_squared:0.3019
# Epoch [213/5000], Loss: 0.1815, R-squared: 0.3232,Validation_loss:0.1356, Validation R_squared:0.3036
# Epoch [214/5000], Loss: 0.1813, R-squared: 0.3240,Validation_loss:0.1353, Validation R_squared:0.3053
# Epoch [215/5000], Loss: 0.1811, R-squared: 0.3247,Validation_loss:0.1350, Validation R_squared:0.3069
# Epoch [216/5000], Loss: 0.1810, R-squared: 0.3255,Validation_loss:0.1347, Validation R_squared:0.3086
# Epoch [217/5000], Loss: 0.1808, R-squared: 0.3262,Validation_loss:0.1344, Validation R_squared:0.3102
# Epoch [218/5000], Loss: 0.1806, R-squared: 0.3269,Validation_loss:0.1341, Validation R_squared:0.3119
# Epoch [219/5000], Loss: 0.1804, R-squared: 0.3277,Validation_loss:0.1338, Validation R_squared:0.3135
# Epoch [220/5000], Loss: 0.1802, R-squared: 0.3284,Validation_loss:0.1335, Validation R_squared:0.3151
# Epoch [221/5000], Loss: 0.1801, R-squared: 0.3291,Validation_loss:0.1332, Validation R_squared:0.3167
# Epoch [222/5000], Loss: 0.1799, R-squared: 0.3299,Validation_loss:0.1329, Validation R_squared:0.3183
# Epoch [223/5000], Loss: 0.1797, R-squared: 0.3306,Validation_loss:0.1326, Validation R_squared:0.3198
# Epoch [224/5000], Loss: 0.1795, R-squared: 0.3313,Validation_loss:0.1323, Validation R_squared:0.3214
# Epoch [225/5000], Loss: 0.1794, R-squared: 0.3321,Validation_loss:0.1320, Validation R_squared:0.3230
# Epoch [226/5000], Loss: 0.1792, R-squared: 0.3328,Validation_loss:0.1318, Validation R_squared:0.3245
# Epoch [227/5000], Loss: 0.1790, R-squared: 0.3335,Validation_loss:0.1315, Validation R_squared:0.3260
# Epoch [228/5000], Loss: 0.1789, R-squared: 0.3342,Validation_loss:0.1312, Validation R_squared:0.3276
# Epoch [229/5000], Loss: 0.1787, R-squared: 0.3349,Validation_loss:0.1309, Validation R_squared:0.3291
# Epoch [230/5000], Loss: 0.1785, R-squared: 0.3356,Validation_loss:0.1306, Validation R_squared:0.3306
# Epoch [231/5000], Loss: 0.1783, R-squared: 0.3363,Validation_loss:0.1303, Validation R_squared:0.3322
# Epoch [232/5000], Loss: 0.1782, R-squared: 0.3370,Validation_loss:0.1301, Validation R_squared:0.3336
# Epoch [233/5000], Loss: 0.1780, R-squared: 0.3377,Validation_loss:0.1298, Validation R_squared:0.3352
# Epoch [234/5000], Loss: 0.1779, R-squared: 0.3384,Validation_loss:0.1295, Validation R_squared:0.3366
# Epoch [235/5000], Loss: 0.1777, R-squared: 0.3390,Validation_loss:0.1292, Validation R_squared:0.3381
# Epoch [236/5000], Loss: 0.1775, R-squared: 0.3397,Validation_loss:0.1290, Validation R_squared:0.3395
# Epoch [237/5000], Loss: 0.1774, R-squared: 0.3404,Validation_loss:0.1287, Validation R_squared:0.3410
# Epoch [238/5000], Loss: 0.1772, R-squared: 0.3411,Validation_loss:0.1284, Validation R_squared:0.3424
# Epoch [239/5000], Loss: 0.1770, R-squared: 0.3417,Validation_loss:0.1282, Validation R_squared:0.3439
# Epoch [240/5000], Loss: 0.1769, R-squared: 0.3424,Validation_loss:0.1279, Validation R_squared:0.3453
# Epoch [241/5000], Loss: 0.1767, R-squared: 0.3430,Validation_loss:0.1276, Validation R_squared:0.3467
# Epoch [242/5000], Loss: 0.1766, R-squared: 0.3437,Validation_loss:0.1274, Validation R_squared:0.3481
# Epoch [243/5000], Loss: 0.1764, R-squared: 0.3443,Validation_loss:0.1271, Validation R_squared:0.3495
# Epoch [244/5000], Loss: 0.1763, R-squared: 0.3450,Validation_loss:0.1269, Validation R_squared:0.3509
# Epoch [245/5000], Loss: 0.1761, R-squared: 0.3456,Validation_loss:0.1266, Validation R_squared:0.3523
# Epoch [246/5000], Loss: 0.1760, R-squared: 0.3462,Validation_loss:0.1263, Validation R_squared:0.3537
# Epoch [247/5000], Loss: 0.1758, R-squared: 0.3469,Validation_loss:0.1261, Validation R_squared:0.3550
# Epoch [248/5000], Loss: 0.1757, R-squared: 0.3475,Validation_loss:0.1258, Validation R_squared:0.3564
# Epoch [249/5000], Loss: 0.1755, R-squared: 0.3481,Validation_loss:0.1256, Validation R_squared:0.3578
# Epoch [250/5000], Loss: 0.1754, R-squared: 0.3487,Validation_loss:0.1253, Validation R_squared:0.3591
# Epoch [251/5000], Loss: 0.1752, R-squared: 0.3494,Validation_loss:0.1251, Validation R_squared:0.3604
# Epoch [252/5000], Loss: 0.1751, R-squared: 0.3500,Validation_loss:0.1248, Validation R_squared:0.3618
# Epoch [253/5000], Loss: 0.1749, R-squared: 0.3506,Validation_loss:0.1246, Validation R_squared:0.3631
# Epoch [254/5000], Loss: 0.1748, R-squared: 0.3512,Validation_loss:0.1243, Validation R_squared:0.3644
# Epoch [255/5000], Loss: 0.1746, R-squared: 0.3518,Validation_loss:0.1241, Validation R_squared:0.3657
# Epoch [256/5000], Loss: 0.1745, R-squared: 0.3524,Validation_loss:0.1238, Validation R_squared:0.3670
# Epoch [257/5000], Loss: 0.1743, R-squared: 0.3530,Validation_loss:0.1236, Validation R_squared:0.3683
# Epoch [258/5000], Loss: 0.1742, R-squared: 0.3536,Validation_loss:0.1234, Validation R_squared:0.3695
# Epoch [259/5000], Loss: 0.1740, R-squared: 0.3542,Validation_loss:0.1231, Validation R_squared:0.3708
# Epoch [260/5000], Loss: 0.1739, R-squared: 0.3548,Validation_loss:0.1229, Validation R_squared:0.3720
# Epoch [261/5000], Loss: 0.1737, R-squared: 0.3554,Validation_loss:0.1226, Validation R_squared:0.3733
# Epoch [262/5000], Loss: 0.1736, R-squared: 0.3560,Validation_loss:0.1224, Validation R_squared:0.3746
# Epoch [263/5000], Loss: 0.1735, R-squared: 0.3566,Validation_loss:0.1222, Validation R_squared:0.3758
# Epoch [264/5000], Loss: 0.1733, R-squared: 0.3572,Validation_loss:0.1219, Validation R_squared:0.3770
# Epoch [265/5000], Loss: 0.1732, R-squared: 0.3577,Validation_loss:0.1217, Validation R_squared:0.3783
# Epoch [266/5000], Loss: 0.1730, R-squared: 0.3583,Validation_loss:0.1215, Validation R_squared:0.3795
# Epoch [267/5000], Loss: 0.1729, R-squared: 0.3589,Validation_loss:0.1212, Validation R_squared:0.3807
# Epoch [268/5000], Loss: 0.1728, R-squared: 0.3595,Validation_loss:0.1210, Validation R_squared:0.3819
# Epoch [269/5000], Loss: 0.1726, R-squared: 0.3600,Validation_loss:0.1208, Validation R_squared:0.3831
# Epoch [270/5000], Loss: 0.1725, R-squared: 0.3606,Validation_loss:0.1205, Validation R_squared:0.3843
# Epoch [271/5000], Loss: 0.1724, R-squared: 0.3612,Validation_loss:0.1203, Validation R_squared:0.3854
# Epoch [272/5000], Loss: 0.1722, R-squared: 0.3617,Validation_loss:0.1201, Validation R_squared:0.3866
# Epoch [273/5000], Loss: 0.1721, R-squared: 0.3623,Validation_loss:0.1199, Validation R_squared:0.3878
# Epoch [274/5000], Loss: 0.1719, R-squared: 0.3628,Validation_loss:0.1196, Validation R_squared:0.3890
# Epoch [275/5000], Loss: 0.1718, R-squared: 0.3634,Validation_loss:0.1194, Validation R_squared:0.3902
# Epoch [276/5000], Loss: 0.1717, R-squared: 0.3639,Validation_loss:0.1192, Validation R_squared:0.3913
# Epoch [277/5000], Loss: 0.1716, R-squared: 0.3645,Validation_loss:0.1190, Validation R_squared:0.3925
# Epoch [278/5000], Loss: 0.1714, R-squared: 0.3650,Validation_loss:0.1187, Validation R_squared:0.3936
# Epoch [279/5000], Loss: 0.1713, R-squared: 0.3656,Validation_loss:0.1185, Validation R_squared:0.3947
# Epoch [280/5000], Loss: 0.1712, R-squared: 0.3661,Validation_loss:0.1183, Validation R_squared:0.3958
# Epoch [281/5000], Loss: 0.1710, R-squared: 0.3666,Validation_loss:0.1181, Validation R_squared:0.3970
# Epoch [282/5000], Loss: 0.1709, R-squared: 0.3672,Validation_loss:0.1179, Validation R_squared:0.3981
# Epoch [283/5000], Loss: 0.1708, R-squared: 0.3677,Validation_loss:0.1177, Validation R_squared:0.3992
# Epoch [284/5000], Loss: 0.1706, R-squared: 0.3682,Validation_loss:0.1174, Validation R_squared:0.4003
# Epoch [285/5000], Loss: 0.1705, R-squared: 0.3687,Validation_loss:0.1172, Validation R_squared:0.4014
# Epoch [286/5000], Loss: 0.1704, R-squared: 0.3693,Validation_loss:0.1170, Validation R_squared:0.4025
# Epoch [287/5000], Loss: 0.1703, R-squared: 0.3698,Validation_loss:0.1168, Validation R_squared:0.4035
# Epoch [288/5000], Loss: 0.1701, R-squared: 0.3703,Validation_loss:0.1166, Validation R_squared:0.4046
# Epoch [289/5000], Loss: 0.1700, R-squared: 0.3708,Validation_loss:0.1164, Validation R_squared:0.4057
# Epoch [290/5000], Loss: 0.1699, R-squared: 0.3713,Validation_loss:0.1162, Validation R_squared:0.4067
# Epoch [291/5000], Loss: 0.1698, R-squared: 0.3718,Validation_loss:0.1160, Validation R_squared:0.4078
# Epoch [292/5000], Loss: 0.1697, R-squared: 0.3723,Validation_loss:0.1158, Validation R_squared:0.4089
# Epoch [293/5000], Loss: 0.1695, R-squared: 0.3728,Validation_loss:0.1156, Validation R_squared:0.4099
# Epoch [294/5000], Loss: 0.1694, R-squared: 0.3733,Validation_loss:0.1154, Validation R_squared:0.4110
# Epoch [295/5000], Loss: 0.1693, R-squared: 0.3738,Validation_loss:0.1152, Validation R_squared:0.4120
# Epoch [296/5000], Loss: 0.1692, R-squared: 0.3743,Validation_loss:0.1150, Validation R_squared:0.4130
# Epoch [297/5000], Loss: 0.1690, R-squared: 0.3748,Validation_loss:0.1148, Validation R_squared:0.4140
# Epoch [298/5000], Loss: 0.1689, R-squared: 0.3753,Validation_loss:0.1146, Validation R_squared:0.4151
# Epoch [299/5000], Loss: 0.1688, R-squared: 0.3758,Validation_loss:0.1144, Validation R_squared:0.4160
# Epoch [300/5000], Loss: 0.1687, R-squared: 0.3763,Validation_loss:0.1142, Validation R_squared:0.4170
# Epoch [301/5000], Loss: 0.1686, R-squared: 0.3767,Validation_loss:0.1140, Validation R_squared:0.4180
# Epoch [302/5000], Loss: 0.1685, R-squared: 0.3772,Validation_loss:0.1138, Validation R_squared:0.4189
# Epoch [303/5000], Loss: 0.1683, R-squared: 0.3777,Validation_loss:0.1136, Validation R_squared:0.4199
# Epoch [304/5000], Loss: 0.1682, R-squared: 0.3782,Validation_loss:0.1134, Validation R_squared:0.4208
# Epoch [305/5000], Loss: 0.1681, R-squared: 0.3786,Validation_loss:0.1133, Validation R_squared:0.4218
# Epoch [306/5000], Loss: 0.1680, R-squared: 0.3791,Validation_loss:0.1131, Validation R_squared:0.4227
# Epoch [307/5000], Loss: 0.1679, R-squared: 0.3796,Validation_loss:0.1129, Validation R_squared:0.4236
# Epoch [308/5000], Loss: 0.1678, R-squared: 0.3800,Validation_loss:0.1127, Validation R_squared:0.4245
# Epoch [309/5000], Loss: 0.1677, R-squared: 0.3805,Validation_loss:0.1125, Validation R_squared:0.4254
# Epoch [310/5000], Loss: 0.1675, R-squared: 0.3810,Validation_loss:0.1124, Validation R_squared:0.4263
# Epoch [311/5000], Loss: 0.1674, R-squared: 0.3814,Validation_loss:0.1122, Validation R_squared:0.4271
# Epoch [312/5000], Loss: 0.1673, R-squared: 0.3819,Validation_loss:0.1120, Validation R_squared:0.4280
# Epoch [313/5000], Loss: 0.1672, R-squared: 0.3823,Validation_loss:0.1119, Validation R_squared:0.4288
# Epoch [314/5000], Loss: 0.1671, R-squared: 0.3828,Validation_loss:0.1117, Validation R_squared:0.4297
# Epoch [315/5000], Loss: 0.1670, R-squared: 0.3833,Validation_loss:0.1115, Validation R_squared:0.4306
# Epoch [316/5000], Loss: 0.1669, R-squared: 0.3837,Validation_loss:0.1114, Validation R_squared:0.4314
# Epoch [317/5000], Loss: 0.1668, R-squared: 0.3842,Validation_loss:0.1112, Validation R_squared:0.4323
# Epoch [318/5000], Loss: 0.1667, R-squared: 0.3846,Validation_loss:0.1110, Validation R_squared:0.4331
# Epoch [319/5000], Loss: 0.1666, R-squared: 0.3850,Validation_loss:0.1109, Validation R_squared:0.4339
# Epoch [320/5000], Loss: 0.1664, R-squared: 0.3855,Validation_loss:0.1107, Validation R_squared:0.4348
# Epoch [321/5000], Loss: 0.1663, R-squared: 0.3859,Validation_loss:0.1105, Validation R_squared:0.4356
# Epoch [322/5000], Loss: 0.1662, R-squared: 0.3864,Validation_loss:0.1104, Validation R_squared:0.4364
# Epoch [323/5000], Loss: 0.1661, R-squared: 0.3868,Validation_loss:0.1102, Validation R_squared:0.4372
# Epoch [324/5000], Loss: 0.1660, R-squared: 0.3872,Validation_loss:0.1100, Validation R_squared:0.4381
# Epoch [325/5000], Loss: 0.1659, R-squared: 0.3877,Validation_loss:0.1099, Validation R_squared:0.4389
# Epoch [326/5000], Loss: 0.1658, R-squared: 0.3881,Validation_loss:0.1097, Validation R_squared:0.4397
# Epoch [327/5000], Loss: 0.1657, R-squared: 0.3885,Validation_loss:0.1096, Validation R_squared:0.4404
# Epoch [328/5000], Loss: 0.1656, R-squared: 0.3890,Validation_loss:0.1094, Validation R_squared:0.4412
# Epoch [329/5000], Loss: 0.1655, R-squared: 0.3894,Validation_loss:0.1093, Validation R_squared:0.4420
# Epoch [330/5000], Loss: 0.1654, R-squared: 0.3898,Validation_loss:0.1091, Validation R_squared:0.4428
# Epoch [331/5000], Loss: 0.1653, R-squared: 0.3902,Validation_loss:0.1089, Validation R_squared:0.4435
# Epoch [332/5000], Loss: 0.1652, R-squared: 0.3907,Validation_loss:0.1088, Validation R_squared:0.4443
# Epoch [333/5000], Loss: 0.1651, R-squared: 0.3911,Validation_loss:0.1086, Validation R_squared:0.4451
# Epoch [334/5000], Loss: 0.1650, R-squared: 0.3915,Validation_loss:0.1085, Validation R_squared:0.4458
# Epoch [335/5000], Loss: 0.1649, R-squared: 0.3919,Validation_loss:0.1083, Validation R_squared:0.4466
# Epoch [336/5000], Loss: 0.1648, R-squared: 0.3923,Validation_loss:0.1082, Validation R_squared:0.4473
# Epoch [337/5000], Loss: 0.1647, R-squared: 0.3927,Validation_loss:0.1080, Validation R_squared:0.4481
# Epoch [338/5000], Loss: 0.1646, R-squared: 0.3932,Validation_loss:0.1079, Validation R_squared:0.4488
# Epoch [339/5000], Loss: 0.1645, R-squared: 0.3936,Validation_loss:0.1077, Validation R_squared:0.4495
# Epoch [340/5000], Loss: 0.1644, R-squared: 0.3940,Validation_loss:0.1076, Validation R_squared:0.4503
# Epoch [341/5000], Loss: 0.1643, R-squared: 0.3944,Validation_loss:0.1075, Validation R_squared:0.4510
# Epoch [342/5000], Loss: 0.1642, R-squared: 0.3948,Validation_loss:0.1073, Validation R_squared:0.4517
# Epoch [343/5000], Loss: 0.1641, R-squared: 0.3952,Validation_loss:0.1072, Validation R_squared:0.4524
# Epoch [344/5000], Loss: 0.1640, R-squared: 0.3956,Validation_loss:0.1070, Validation R_squared:0.4531
# Epoch [345/5000], Loss: 0.1639, R-squared: 0.3960,Validation_loss:0.1069, Validation R_squared:0.4538
# Epoch [346/5000], Loss: 0.1638, R-squared: 0.3964,Validation_loss:0.1068, Validation R_squared:0.4545
# Epoch [347/5000], Loss: 0.1637, R-squared: 0.3968,Validation_loss:0.1066, Validation R_squared:0.4551
# Epoch [348/5000], Loss: 0.1636, R-squared: 0.3972,Validation_loss:0.1065, Validation R_squared:0.4558
# Epoch [349/5000], Loss: 0.1635, R-squared: 0.3976,Validation_loss:0.1064, Validation R_squared:0.4565
# Epoch [350/5000], Loss: 0.1634, R-squared: 0.3980,Validation_loss:0.1062, Validation R_squared:0.4571
# Epoch [351/5000], Loss: 0.1633, R-squared: 0.3983,Validation_loss:0.1061, Validation R_squared:0.4578
# Epoch [352/5000], Loss: 0.1632, R-squared: 0.3987,Validation_loss:0.1060, Validation R_squared:0.4585
# Epoch [353/5000], Loss: 0.1631, R-squared: 0.3991,Validation_loss:0.1058, Validation R_squared:0.4591
# Epoch [354/5000], Loss: 0.1630, R-squared: 0.3995,Validation_loss:0.1057, Validation R_squared:0.4597
# Epoch [355/5000], Loss: 0.1629, R-squared: 0.3999,Validation_loss:0.1056, Validation R_squared:0.4604
# Epoch [356/5000], Loss: 0.1629, R-squared: 0.4003,Validation_loss:0.1054, Validation R_squared:0.4610
# Epoch [357/5000], Loss: 0.1628, R-squared: 0.4007,Validation_loss:0.1053, Validation R_squared:0.4617
# Epoch [358/5000], Loss: 0.1627, R-squared: 0.4010,Validation_loss:0.1052, Validation R_squared:0.4623
# Epoch [359/5000], Loss: 0.1626, R-squared: 0.4014,Validation_loss:0.1051, Validation R_squared:0.4629
# Epoch [360/5000], Loss: 0.1625, R-squared: 0.4018,Validation_loss:0.1050, Validation R_squared:0.4634
# Epoch [361/5000], Loss: 0.1624, R-squared: 0.4022,Validation_loss:0.1048, Validation R_squared:0.4640
# Epoch [362/5000], Loss: 0.1623, R-squared: 0.4025,Validation_loss:0.1047, Validation R_squared:0.4646
# Epoch [363/5000], Loss: 0.1622, R-squared: 0.4029,Validation_loss:0.1046, Validation R_squared:0.4652
# Epoch [364/5000], Loss: 0.1621, R-squared: 0.4033,Validation_loss:0.1045, Validation R_squared:0.4658
# Epoch [365/5000], Loss: 0.1620, R-squared: 0.4037,Validation_loss:0.1044, Validation R_squared:0.4664
# Epoch [366/5000], Loss: 0.1619, R-squared: 0.4040,Validation_loss:0.1043, Validation R_squared:0.4669
# Epoch [367/5000], Loss: 0.1618, R-squared: 0.4044,Validation_loss:0.1041, Validation R_squared:0.4675
# Epoch [368/5000], Loss: 0.1618, R-squared: 0.4048,Validation_loss:0.1040, Validation R_squared:0.4681
# Epoch [369/5000], Loss: 0.1617, R-squared: 0.4051,Validation_loss:0.1039, Validation R_squared:0.4686
# Epoch [370/5000], Loss: 0.1616, R-squared: 0.4055,Validation_loss:0.1038, Validation R_squared:0.4692
# Epoch [371/5000], Loss: 0.1615, R-squared: 0.4058,Validation_loss:0.1037, Validation R_squared:0.4698
# Epoch [372/5000], Loss: 0.1614, R-squared: 0.4062,Validation_loss:0.1036, Validation R_squared:0.4703
# Epoch [373/5000], Loss: 0.1613, R-squared: 0.4066,Validation_loss:0.1035, Validation R_squared:0.4708
# Epoch [374/5000], Loss: 0.1612, R-squared: 0.4069,Validation_loss:0.1034, Validation R_squared:0.4714
# Epoch [375/5000], Loss: 0.1611, R-squared: 0.4073,Validation_loss:0.1032, Validation R_squared:0.4719
# Epoch [376/5000], Loss: 0.1611, R-squared: 0.4076,Validation_loss:0.1031, Validation R_squared:0.4725
# Epoch [377/5000], Loss: 0.1610, R-squared: 0.4080,Validation_loss:0.1030, Validation R_squared:0.4730
# Epoch [378/5000], Loss: 0.1609, R-squared: 0.4083,Validation_loss:0.1029, Validation R_squared:0.4736
# Epoch [379/5000], Loss: 0.1608, R-squared: 0.4087,Validation_loss:0.1028, Validation R_squared:0.4741
# Epoch [380/5000], Loss: 0.1607, R-squared: 0.4090,Validation_loss:0.1027, Validation R_squared:0.4746
# Epoch [381/5000], Loss: 0.1606, R-squared: 0.4094,Validation_loss:0.1026, Validation R_squared:0.4751
# Epoch [382/5000], Loss: 0.1605, R-squared: 0.4097,Validation_loss:0.1025, Validation R_squared:0.4757
# Epoch [383/5000], Loss: 0.1605, R-squared: 0.4101,Validation_loss:0.1024, Validation R_squared:0.4762
# Epoch [384/5000], Loss: 0.1604, R-squared: 0.4104,Validation_loss:0.1023, Validation R_squared:0.4767
# Epoch [385/5000], Loss: 0.1603, R-squared: 0.4108,Validation_loss:0.1022, Validation R_squared:0.4772
# Epoch [386/5000], Loss: 0.1602, R-squared: 0.4111,Validation_loss:0.1021, Validation R_squared:0.4777
# Epoch [387/5000], Loss: 0.1601, R-squared: 0.4115,Validation_loss:0.1020, Validation R_squared:0.4782
# Epoch [388/5000], Loss: 0.1600, R-squared: 0.4118,Validation_loss:0.1019, Validation R_squared:0.4787
# Epoch [389/5000], Loss: 0.1600, R-squared: 0.4122,Validation_loss:0.1018, Validation R_squared:0.4792
# Epoch [390/5000], Loss: 0.1599, R-squared: 0.4125,Validation_loss:0.1017, Validation R_squared:0.4797
# Epoch [391/5000], Loss: 0.1598, R-squared: 0.4128,Validation_loss:0.1016, Validation R_squared:0.4802
# Epoch [392/5000], Loss: 0.1597, R-squared: 0.4131,Validation_loss:0.1015, Validation R_squared:0.4807
# Epoch [393/5000], Loss: 0.1596, R-squared: 0.4135,Validation_loss:0.1014, Validation R_squared:0.4812
# Epoch [394/5000], Loss: 0.1595, R-squared: 0.4138,Validation_loss:0.1013, Validation R_squared:0.4818
# Epoch [395/5000], Loss: 0.1595, R-squared: 0.4142,Validation_loss:0.1012, Validation R_squared:0.4822
# Epoch [396/5000], Loss: 0.1594, R-squared: 0.4145,Validation_loss:0.1011, Validation R_squared:0.4827
# Epoch [397/5000], Loss: 0.1593, R-squared: 0.4148,Validation_loss:0.1010, Validation R_squared:0.4832
# Epoch [398/5000], Loss: 0.1592, R-squared: 0.4151,Validation_loss:0.1009, Validation R_squared:0.4837
# Epoch [399/5000], Loss: 0.1591, R-squared: 0.4155,Validation_loss:0.1008, Validation R_squared:0.4842
# Epoch [400/5000], Loss: 0.1591, R-squared: 0.4158,Validation_loss:0.1007, Validation R_squared:0.4846
# Epoch [401/5000], Loss: 0.1590, R-squared: 0.4161,Validation_loss:0.1006, Validation R_squared:0.4851
# Epoch [402/5000], Loss: 0.1589, R-squared: 0.4165,Validation_loss:0.1005, Validation R_squared:0.4855
# Epoch [403/5000], Loss: 0.1588, R-squared: 0.4168,Validation_loss:0.1004, Validation R_squared:0.4860
# Epoch [404/5000], Loss: 0.1587, R-squared: 0.4171,Validation_loss:0.1003, Validation R_squared:0.4864
# Epoch [405/5000], Loss: 0.1587, R-squared: 0.4174,Validation_loss:0.1002, Validation R_squared:0.4869
# Epoch [406/5000], Loss: 0.1586, R-squared: 0.4178,Validation_loss:0.1001, Validation R_squared:0.4873
# Epoch [407/5000], Loss: 0.1585, R-squared: 0.4181,Validation_loss:0.1000, Validation R_squared:0.4877
# Epoch [408/5000], Loss: 0.1584, R-squared: 0.4184,Validation_loss:0.1000, Validation R_squared:0.4882
# Epoch [409/5000], Loss: 0.1584, R-squared: 0.4187,Validation_loss:0.0999, Validation R_squared:0.4886
# Epoch [410/5000], Loss: 0.1583, R-squared: 0.4190,Validation_loss:0.0998, Validation R_squared:0.4890
# Epoch [411/5000], Loss: 0.1582, R-squared: 0.4194,Validation_loss:0.0997, Validation R_squared:0.4894
# Epoch [412/5000], Loss: 0.1581, R-squared: 0.4197,Validation_loss:0.0996, Validation R_squared:0.4899
# Epoch [413/5000], Loss: 0.1580, R-squared: 0.4200,Validation_loss:0.0995, Validation R_squared:0.4903
# Epoch [414/5000], Loss: 0.1580, R-squared: 0.4203,Validation_loss:0.0994, Validation R_squared:0.4907
# Epoch [415/5000], Loss: 0.1579, R-squared: 0.4206,Validation_loss:0.0994, Validation R_squared:0.4911
# Epoch [416/5000], Loss: 0.1578, R-squared: 0.4209,Validation_loss:0.0993, Validation R_squared:0.4915
# Epoch [417/5000], Loss: 0.1577, R-squared: 0.4213,Validation_loss:0.0992, Validation R_squared:0.4919
# Epoch [418/5000], Loss: 0.1577, R-squared: 0.4216,Validation_loss:0.0991, Validation R_squared:0.4922
# Epoch [419/5000], Loss: 0.1576, R-squared: 0.4219,Validation_loss:0.0990, Validation R_squared:0.4927
# Epoch [420/5000], Loss: 0.1575, R-squared: 0.4222,Validation_loss:0.0990, Validation R_squared:0.4930
# Epoch [421/5000], Loss: 0.1574, R-squared: 0.4225,Validation_loss:0.0989, Validation R_squared:0.4934
# Epoch [422/5000], Loss: 0.1574, R-squared: 0.4228,Validation_loss:0.0988, Validation R_squared:0.4938
# Epoch [423/5000], Loss: 0.1573, R-squared: 0.4231,Validation_loss:0.0987, Validation R_squared:0.4942
# Epoch [424/5000], Loss: 0.1572, R-squared: 0.4234,Validation_loss:0.0987, Validation R_squared:0.4945
# Epoch [425/5000], Loss: 0.1571, R-squared: 0.4237,Validation_loss:0.0986, Validation R_squared:0.4949
# Epoch [426/5000], Loss: 0.1571, R-squared: 0.4240,Validation_loss:0.0985, Validation R_squared:0.4953
# Epoch [427/5000], Loss: 0.1570, R-squared: 0.4243,Validation_loss:0.0984, Validation R_squared:0.4957
# Epoch [428/5000], Loss: 0.1569, R-squared: 0.4246,Validation_loss:0.0984, Validation R_squared:0.4960
# Epoch [429/5000], Loss: 0.1568, R-squared: 0.4249,Validation_loss:0.0983, Validation R_squared:0.4964
# Epoch [430/5000], Loss: 0.1568, R-squared: 0.4252,Validation_loss:0.0982, Validation R_squared:0.4967
# Epoch [431/5000], Loss: 0.1567, R-squared: 0.4256,Validation_loss:0.0981, Validation R_squared:0.4971
# Epoch [432/5000], Loss: 0.1566, R-squared: 0.4258,Validation_loss:0.0981, Validation R_squared:0.4975
# Epoch [433/5000], Loss: 0.1565, R-squared: 0.4261,Validation_loss:0.0980, Validation R_squared:0.4978
# Epoch [434/5000], Loss: 0.1565, R-squared: 0.4264,Validation_loss:0.0979, Validation R_squared:0.4981
# Epoch [435/5000], Loss: 0.1564, R-squared: 0.4267,Validation_loss:0.0979, Validation R_squared:0.4985
# Epoch [436/5000], Loss: 0.1563, R-squared: 0.4270,Validation_loss:0.0978, Validation R_squared:0.4988
# Epoch [437/5000], Loss: 0.1562, R-squared: 0.4273,Validation_loss:0.0977, Validation R_squared:0.4991
# Epoch [438/5000], Loss: 0.1562, R-squared: 0.4276,Validation_loss:0.0976, Validation R_squared:0.4995
# Epoch [439/5000], Loss: 0.1561, R-squared: 0.4279,Validation_loss:0.0976, Validation R_squared:0.4998
# Epoch [440/5000], Loss: 0.1560, R-squared: 0.4282,Validation_loss:0.0975, Validation R_squared:0.5001
# Epoch [441/5000], Loss: 0.1560, R-squared: 0.4285,Validation_loss:0.0974, Validation R_squared:0.5005
# Epoch [442/5000], Loss: 0.1559, R-squared: 0.4288,Validation_loss:0.0974, Validation R_squared:0.5008
# Epoch [443/5000], Loss: 0.1558, R-squared: 0.4291,Validation_loss:0.0973, Validation R_squared:0.5011
# Epoch [444/5000], Loss: 0.1557, R-squared: 0.4294,Validation_loss:0.0972, Validation R_squared:0.5014
# Epoch [445/5000], Loss: 0.1557, R-squared: 0.4297,Validation_loss:0.0972, Validation R_squared:0.5017
# Epoch [446/5000], Loss: 0.1556, R-squared: 0.4300,Validation_loss:0.0971, Validation R_squared:0.5021
# Epoch [447/5000], Loss: 0.1555, R-squared: 0.4303,Validation_loss:0.0970, Validation R_squared:0.5024
# Epoch [448/5000], Loss: 0.1555, R-squared: 0.4306,Validation_loss:0.0970, Validation R_squared:0.5027
# Epoch [449/5000], Loss: 0.1554, R-squared: 0.4309,Validation_loss:0.0969, Validation R_squared:0.5030
# Epoch [450/5000], Loss: 0.1553, R-squared: 0.4312,Validation_loss:0.0968, Validation R_squared:0.5034
# Epoch [451/5000], Loss: 0.1552, R-squared: 0.4314,Validation_loss:0.0968, Validation R_squared:0.5037
# Epoch [452/5000], Loss: 0.1552, R-squared: 0.4317,Validation_loss:0.0967, Validation R_squared:0.5040
# Epoch [453/5000], Loss: 0.1551, R-squared: 0.4320,Validation_loss:0.0966, Validation R_squared:0.5043
# Epoch [454/5000], Loss: 0.1550, R-squared: 0.4323,Validation_loss:0.0966, Validation R_squared:0.5046
# Epoch [455/5000], Loss: 0.1550, R-squared: 0.4326,Validation_loss:0.0965, Validation R_squared:0.5049
# Epoch [456/5000], Loss: 0.1549, R-squared: 0.4329,Validation_loss:0.0965, Validation R_squared:0.5052
# Epoch [457/5000], Loss: 0.1548, R-squared: 0.4332,Validation_loss:0.0964, Validation R_squared:0.5055
# Epoch [458/5000], Loss: 0.1547, R-squared: 0.4335,Validation_loss:0.0963, Validation R_squared:0.5058
# Epoch [459/5000], Loss: 0.1547, R-squared: 0.4337,Validation_loss:0.0963, Validation R_squared:0.5061
# Epoch [460/5000], Loss: 0.1546, R-squared: 0.4340,Validation_loss:0.0962, Validation R_squared:0.5064
# Epoch [461/5000], Loss: 0.1545, R-squared: 0.4343,Validation_loss:0.0961, Validation R_squared:0.5067
# Epoch [462/5000], Loss: 0.1545, R-squared: 0.4346,Validation_loss:0.0961, Validation R_squared:0.5070
# Epoch [463/5000], Loss: 0.1544, R-squared: 0.4349,Validation_loss:0.0960, Validation R_squared:0.5073
# Epoch [464/5000], Loss: 0.1543, R-squared: 0.4352,Validation_loss:0.0960, Validation R_squared:0.5076
# Epoch [465/5000], Loss: 0.1543, R-squared: 0.4354,Validation_loss:0.0959, Validation R_squared:0.5078
# Epoch [466/5000], Loss: 0.1542, R-squared: 0.4357,Validation_loss:0.0958, Validation R_squared:0.5082
# Epoch [467/5000], Loss: 0.1541, R-squared: 0.4360,Validation_loss:0.0958, Validation R_squared:0.5084
# Epoch [468/5000], Loss: 0.1540, R-squared: 0.4363,Validation_loss:0.0957, Validation R_squared:0.5087
# Epoch [469/5000], Loss: 0.1540, R-squared: 0.4366,Validation_loss:0.0957, Validation R_squared:0.5090
# Epoch [470/5000], Loss: 0.1539, R-squared: 0.4369,Validation_loss:0.0956, Validation R_squared:0.5093
# ...
# Epoch [4846/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5095
# Epoch [4847/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5095
# Epoch [4848/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5095
# Epoch [4849/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5095
# Epoch [4850/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5095
# Epoch [4851/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5095
# Epoch [4852/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5095
# Epoch [4853/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4854/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4855/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4856/5000], Loss: 0.0840, R-squared: 0.7080,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4857/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4858/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4859/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4860/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4861/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4862/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4863/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4864/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4865/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4866/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4867/5000], Loss: 0.0840, R-squared: 0.7081,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4868/5000], Loss: 0.0840, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4869/5000], Loss: 0.0840, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4870/5000], Loss: 0.0840, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4871/5000], Loss: 0.0840, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4872/5000], Loss: 0.0840, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4873/5000], Loss: 0.0840, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4874/5000], Loss: 0.0840, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4875/5000], Loss: 0.0839, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4876/5000], Loss: 0.0839, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4877/5000], Loss: 0.0839, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4878/5000], Loss: 0.0839, R-squared: 0.7082,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4879/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4880/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4881/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4882/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4883/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5094
# Epoch [4884/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4885/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4886/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4887/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4888/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4889/5000], Loss: 0.0839, R-squared: 0.7083,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4890/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4891/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4892/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4893/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4894/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4895/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4896/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4897/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4898/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4899/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4900/5000], Loss: 0.0839, R-squared: 0.7084,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4901/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4902/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4903/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4904/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4905/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4906/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4907/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5093
# Epoch [4908/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4909/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4910/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4911/5000], Loss: 0.0839, R-squared: 0.7085,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4912/5000], Loss: 0.0839, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4913/5000], Loss: 0.0839, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4914/5000], Loss: 0.0839, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4915/5000], Loss: 0.0839, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4916/5000], Loss: 0.0838, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4917/5000], Loss: 0.0838, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4918/5000], Loss: 0.0838, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4919/5000], Loss: 0.0838, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4920/5000], Loss: 0.0838, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4921/5000], Loss: 0.0838, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4922/5000], Loss: 0.0838, R-squared: 0.7086,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4923/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4924/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4925/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4926/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4927/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4928/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4929/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4930/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4931/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4932/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4933/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4934/5000], Loss: 0.0838, R-squared: 0.7087,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4935/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4936/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4937/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4938/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4939/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5092
# Epoch [4940/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4941/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4942/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4943/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4944/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4945/5000], Loss: 0.0838, R-squared: 0.7088,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4946/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4947/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4948/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4949/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4950/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4951/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4952/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4953/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4954/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4955/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4956/5000], Loss: 0.0838, R-squared: 0.7089,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4957/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4958/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4959/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4960/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4961/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4962/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4963/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4964/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4965/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4966/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5091
# Epoch [4967/5000], Loss: 0.0837, R-squared: 0.7090,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4968/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4969/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4970/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4971/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4972/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4973/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4974/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4975/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4976/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0940, Validation R_squared:0.5090
# Epoch [4977/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4978/5000], Loss: 0.0837, R-squared: 0.7091,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4979/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4980/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4981/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4982/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4983/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4984/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4985/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4986/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4987/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4988/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [4989/5000], Loss: 0.0837, R-squared: 0.7092,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4990/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [4991/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4992/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [4993/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5090
# Epoch [4994/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [4995/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [4996/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [4997/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [4998/5000], Loss: 0.0837, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [4999/5000], Loss: 0.0836, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089
# Epoch [5000/5000], Loss: 0.0836, R-squared: 0.7093,Validation_loss:0.0941, Validation R_squared:0.5089

# %% [markdown]
# ## Plots

# %%
# Create a scatter plot of actual vs. predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', label='Actual vs. Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.grid(True)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', label='Perfect Prediction')
plt.legend()

# Display the plot
plt.show()

# %%
# Create a plot for the loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(num_epochs), losses, label='Test', color='green')
plt.plot(range(num_epochs), val_losses, label='Validation', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.grid(True)

# Create a plot for R-squared
plt.subplot(1, 2, 2)
plt.plot(range(num_epochs), r2_values, label='Test', color='green')
plt.plot(range(num_epochs), r2_validation, label='Validation', color='orange')
plt.xlabel('Epoch')
plt.ylabel('R-squared')
plt.title('R-squared Over Epochs')
plt.legend()
plt.grid(True)

# Display Plot
plt.show()

# %% [markdown]
# ## Gradient

# %%
#extract grad
parameter_importance = model.fc1.weight.grad

# %%
# Convert the parameter_importance tensor to a NumPy array
parameter_importance_img = parameter_importance.detach().numpy()
# Normalize the values to [0, 1]
min_val = parameter_importance_img.min()
max_val = parameter_importance_img.max()

parameter_importance_img = (parameter_importance_img - min_val) / (max_val - min_val)
parameter_importance_img = np.floor(parameter_importance_img*255)

# %% [markdown]
# Display

# %%
# Create a heatmap
plt.figure(figsize=(10, 2))
plt.imshow(parameter_importance_img, cmap='viridis', aspect='auto')
plt.colorbar()
plt.title('Parameter Importance Heatmap')
plt.xlabel('Input Dimension')
plt.ylabel('Gradients')
plt.show()

# %%
data_row=0
# Plot heatmap
plt.figure(figsize=(10, 2))
plt.imshow(parameter_importance_img[0+data_row:3+data_row,:], cmap='viridis', aspect='auto')
plt.colorbar()
plt.title('Parameter Importance Heatmap')
plt.xlabel('Input Dimension')
plt.ylabel('Gradients')
plt.show()
