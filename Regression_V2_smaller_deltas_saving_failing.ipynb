# %% [markdown]
# <a href="https://colab.research.google.com/github/Justworkname/6367_project/blob/main/Regression_V2_smaller_deltas_saving_failing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression Model V2_smaller_deltas_testing_save_failed

# %% [markdown]
# ## Import

# %%
# !pip install -q torchinfo

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torch.optim as optim
from torchvision import datasets, transforms
from torchinfo import summary
import numpy as np
import pandas as pd
import os
from PIL import Image
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import torch.optim.lr_scheduler as lr_scheduler

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# this creates a link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# '10 19 2023 meeting.gslides'
# '6 16 2023 Meeting.gslides'
#  6367
#  6367_project
# '6367 Project presentation.gslides'
# '7 12 2023 meeting.gslides'
#  7340
# '8 17 2023 meeting.gslides'
# '8 30 2023 meeting.gslides'
# '9 06 2023 meeting - Bar chart 1.gsheet'
# '9 06 2023 meeting - Column chart 1 (1).gsheet'
# '9 06 2023 meeting - Column chart 1 (2).gsheet'
# '9 06 2023 meeting - Column chart 1.gsheet'
# '9 06 2023 meeting.gslides'
# '9 20 2023 meeting.gslides'
# '9 28 2023 meeting.gslides'
# 'AI in Breast Cancer in Medical Imaging.gslides'
#  AI_MB
#  AI_MB_3D
# 'Colab Notebooks'
#  customTF2
#  Data_Vision_Transformer
#  fakeImages
#  Grad_documents
# 'Invited Lecture 2.gdoc'
# 'Invited Lecture 5.gdoc'
# 'Invited lecture 6.gdoc'
# 'Invited Lecture 7.gdoc'
#  Invited_lecture_oct_10.gdoc
# 'Invited Lecture October 3rd.gdoc'
# 'Invited Lecture September 19th.gdoc'
# 'My Drive'
# 'Presentation Evaluation sep 19.gdoc'
# 'QE Key points.gdoc'
# 'Regression testing.gdoc'
# 'Regression testing multiple deltas.gdoc'
#  Seminar
#  Ultrasound_Images
#  Undergrad_documents
# 'Veterinary Clinic Tumor Estimation Conclusion.gslides'
# 'Wild Magic.gsheet'

# %% [markdown]
# ## Hyperparameters

# %%
num_epochs=5000
input_dim = 54
output_dim = 1
hidden_dim = 3721
dropout=0.01

# %% [markdown]
# ## Load

# %%
# Load the CSV file into a DataFrame
csv_file_path = '/content/gdrive/MyDrive/6367_project/data_v2.csv'
df = pd.read_csv(csv_file_path)
df.fillna(0,inplace=True)
df = df.loc[(df != 0).all(axis=1)] # filter if want

train_patients = ['3', '4', '5', '6', '8', '9','10', '11','13','14','16','19','20','21','23']
test_patients = ['25']

df['Patient #'] = df['Patient #'].astype(str)

df_train=df[df['Patient #'].isin(train_patients)]
df_test=df[df['Patient #'].isin(test_patients)]

# Convert to desired data shape
y_train = df_train['Delta Plq Area'] #change with desired prediction
X_train = df_train.drop(columns=['Delta Plq Area','Patient #','Total FU Plq Area','VHIVUS FU img ind','CC FU Area','CC FU Circum Cov.','CC FU max thick',
                     'NC FU Area','NC FU max thick','FI FU Area','FI FU Circum Cov.','FI FU max thick','FF FU Area','FF FU Circum Cov.','FF FU max thick',
                     'VHIVUS BL img ind','BL Pat FRS','BL Pat LDL','BL Pat FFR','BL Pat EEMV','BL Pat BMI','BL Pat BUR']) #data to exclude

y_test = df_test['Delta Plq Area'] #change with desired prediction
X_test = df_test.drop(columns=['Delta Plq Area','Patient #','Total FU Plq Area','VHIVUS FU img ind','CC FU Area','CC FU Circum Cov.','CC FU max thick',
                     'NC FU Area','NC FU max thick','FI FU Area','FI FU Circum Cov.','FI FU max thick','FF FU Area','FF FU Circum Cov.','FF FU max thick',
                     'VHIVUS BL img ind','BL Pat FRS','BL Pat LDL','BL Pat FFR','BL Pat EEMV','BL Pat BMI','BL Pat BUR'])

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.float32)
y_train = y_train.view(-1)
y_test = y_test.view(-1)

# %% [markdown]
# ## Model

# %%
class RegressionModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout):
        super(RegressionModel, self).__init__()

        # Define the layers
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, 100)
        self.relu = nn.ReLU()
        self.fc3 = nn.Linear(100, output_dim)
        #self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        # Forward pass
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        #x = self.dropout(x)
        x = self.fc3(x)
        return x

# %%
model = RegressionModel(input_dim, hidden_dim, output_dim,dropout)

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# RegressionModel                          --
# ├─Linear: 1-1                            204,655
# ├─ReLU: 1-2                              --
# ├─Linear: 1-3                            372,200
# ├─Linear: 1-4                            101
# =================================================================
# Total params: 576,956
# Trainable params: 576,956
# Non-trainable params: 0
# =================================================================

# %%
# Mean Squared Error loss
criterion = nn.SmoothL1Loss()
# Apply optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)
# Learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)

# %% [markdown]
# ## Training

# %%
# List for Loss and R squared
losses = []
val_losses = []
r2_values = []
r2_validation = []

# Training loop
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_train)
    outputs = outputs.squeeze(dim=1)

    # Compute the loss
    ## Could consider Huber Loss
    loss = criterion(outputs, y_train)

    # Backpropagation and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Learning rate annealing
    scheduler.step()

    # Calculate R-squared
    y_pred = outputs.detach().numpy()
    r2 = r2_score(y_train.numpy(), y_pred)

    # Store loss and R-squared values for this epoch
    losses.append(loss.item())
    r2_values.append(r2)

    # Testing predictions
    y_pred = model(X_test).detach().numpy()
    # Calculate R-squared accuracy on the test data
    r2_test = r2_score(y_test.numpy(), y_pred)
    r2_validation.append(r2_test)
    val_out = model(X_test)
    val_out = val_out.squeeze(dim=1)
    val_loss = criterion(val_out,y_test)
    val_losses.append(val_loss.item())

    print('Epoch [{}/{}], Loss: {:.4f}, R-squared: {:.4f},Validation_loss:{:,.4f}, Validation R_squared:{:,.4f}'.format(epoch+1, num_epochs, loss.item(), r2,val_loss.item(),r2_test))
# Out:
# Epoch [1/5000], Loss: 0.2956, R-squared: -0.1438,Validation_loss:0.1842, Validation R_squared:-0.3281
# Epoch [2/5000], Loss: 0.2864, R-squared: -0.1059,Validation_loss:0.1838, Validation R_squared:-0.3264
# Epoch [3/5000], Loss: 0.2794, R-squared: -0.0770,Validation_loss:0.1829, Validation R_squared:-0.3208
# Epoch [4/5000], Loss: 0.2739, R-squared: -0.0543,Validation_loss:0.1817, Validation R_squared:-0.3129
# Epoch [5/5000], Loss: 0.2694, R-squared: -0.0360,Validation_loss:0.1804, Validation R_squared:-0.3037
# Epoch [6/5000], Loss: 0.2658, R-squared: -0.0212,Validation_loss:0.1789, Validation R_squared:-0.2933
# Epoch [7/5000], Loss: 0.2628, R-squared: -0.0090,Validation_loss:0.1775, Validation R_squared:-0.2835
# Epoch [8/5000], Loss: 0.2604, R-squared: 0.0009,Validation_loss:0.1760, Validation R_squared:-0.2734
# Epoch [9/5000], Loss: 0.2584, R-squared: 0.0092,Validation_loss:0.1747, Validation R_squared:-0.2638
# Epoch [10/5000], Loss: 0.2567, R-squared: 0.0162,Validation_loss:0.1733, Validation R_squared:-0.2543
# Epoch [11/5000], Loss: 0.2552, R-squared: 0.0224,Validation_loss:0.1720, Validation R_squared:-0.2453
# Epoch [12/5000], Loss: 0.2539, R-squared: 0.0277,Validation_loss:0.1708, Validation R_squared:-0.2368
# Epoch [13/5000], Loss: 0.2528, R-squared: 0.0324,Validation_loss:0.1696, Validation R_squared:-0.2286
# Epoch [14/5000], Loss: 0.2517, R-squared: 0.0367,Validation_loss:0.1685, Validation R_squared:-0.2205
# Epoch [15/5000], Loss: 0.2508, R-squared: 0.0406,Validation_loss:0.1674, Validation R_squared:-0.2126
# Epoch [16/5000], Loss: 0.2499, R-squared: 0.0442,Validation_loss:0.1664, Validation R_squared:-0.2055
# Epoch [17/5000], Loss: 0.2491, R-squared: 0.0476,Validation_loss:0.1655, Validation R_squared:-0.1989
# Epoch [18/5000], Loss: 0.2483, R-squared: 0.0508,Validation_loss:0.1646, Validation R_squared:-0.1928
# Epoch [19/5000], Loss: 0.2476, R-squared: 0.0538,Validation_loss:0.1639, Validation R_squared:-0.1871
# Epoch [20/5000], Loss: 0.2469, R-squared: 0.0567,Validation_loss:0.1631, Validation R_squared:-0.1816
# Epoch [21/5000], Loss: 0.2462, R-squared: 0.0595,Validation_loss:0.1624, Validation R_squared:-0.1764
# Epoch [22/5000], Loss: 0.2456, R-squared: 0.0622,Validation_loss:0.1617, Validation R_squared:-0.1713
# Epoch [23/5000], Loss: 0.2449, R-squared: 0.0648,Validation_loss:0.1610, Validation R_squared:-0.1667
# Epoch [24/5000], Loss: 0.2443, R-squared: 0.0674,Validation_loss:0.1604, Validation R_squared:-0.1620
# Epoch [25/5000], Loss: 0.2437, R-squared: 0.0699,Validation_loss:0.1598, Validation R_squared:-0.1576
# Epoch [26/5000], Loss: 0.2431, R-squared: 0.0723,Validation_loss:0.1592, Validation R_squared:-0.1531
# Epoch [27/5000], Loss: 0.2425, R-squared: 0.0746,Validation_loss:0.1586, Validation R_squared:-0.1491
# Epoch [28/5000], Loss: 0.2420, R-squared: 0.0770,Validation_loss:0.1581, Validation R_squared:-0.1451
# Epoch [29/5000], Loss: 0.2414, R-squared: 0.0792,Validation_loss:0.1575, Validation R_squared:-0.1408
# Epoch [30/5000], Loss: 0.2409, R-squared: 0.0814,Validation_loss:0.1570, Validation R_squared:-0.1367
# Epoch [31/5000], Loss: 0.2404, R-squared: 0.0836,Validation_loss:0.1564, Validation R_squared:-0.1327
# Epoch [32/5000], Loss: 0.2399, R-squared: 0.0857,Validation_loss:0.1559, Validation R_squared:-0.1288
# Epoch [33/5000], Loss: 0.2393, R-squared: 0.0878,Validation_loss:0.1554, Validation R_squared:-0.1251
# Epoch [34/5000], Loss: 0.2388, R-squared: 0.0899,Validation_loss:0.1549, Validation R_squared:-0.1218
# Epoch [35/5000], Loss: 0.2383, R-squared: 0.0920,Validation_loss:0.1545, Validation R_squared:-0.1185
# Epoch [36/5000], Loss: 0.2378, R-squared: 0.0941,Validation_loss:0.1540, Validation R_squared:-0.1150
# Epoch [37/5000], Loss: 0.2373, R-squared: 0.0961,Validation_loss:0.1536, Validation R_squared:-0.1117
# Epoch [38/5000], Loss: 0.2369, R-squared: 0.0981,Validation_loss:0.1531, Validation R_squared:-0.1084
# Epoch [39/5000], Loss: 0.2364, R-squared: 0.1001,Validation_loss:0.1527, Validation R_squared:-0.1050
# Epoch [40/5000], Loss: 0.2359, R-squared: 0.1021,Validation_loss:0.1522, Validation R_squared:-0.1018
# Epoch [41/5000], Loss: 0.2354, R-squared: 0.1041,Validation_loss:0.1518, Validation R_squared:-0.0988
# Epoch [42/5000], Loss: 0.2349, R-squared: 0.1060,Validation_loss:0.1514, Validation R_squared:-0.0959
# Epoch [43/5000], Loss: 0.2345, R-squared: 0.1080,Validation_loss:0.1510, Validation R_squared:-0.0931
# Epoch [44/5000], Loss: 0.2340, R-squared: 0.1099,Validation_loss:0.1507, Validation R_squared:-0.0902
# Epoch [45/5000], Loss: 0.2335, R-squared: 0.1118,Validation_loss:0.1502, Validation R_squared:-0.0870
# Epoch [46/5000], Loss: 0.2331, R-squared: 0.1138,Validation_loss:0.1498, Validation R_squared:-0.0839
# Epoch [47/5000], Loss: 0.2326, R-squared: 0.1157,Validation_loss:0.1494, Validation R_squared:-0.0808
# Epoch [48/5000], Loss: 0.2322, R-squared: 0.1175,Validation_loss:0.1490, Validation R_squared:-0.0778
# Epoch [49/5000], Loss: 0.2317, R-squared: 0.1194,Validation_loss:0.1486, Validation R_squared:-0.0749
# Epoch [50/5000], Loss: 0.2313, R-squared: 0.1212,Validation_loss:0.1483, Validation R_squared:-0.0722
# Epoch [51/5000], Loss: 0.2308, R-squared: 0.1230,Validation_loss:0.1479, Validation R_squared:-0.0693
# Epoch [52/5000], Loss: 0.2304, R-squared: 0.1249,Validation_loss:0.1475, Validation R_squared:-0.0666
# Epoch [53/5000], Loss: 0.2300, R-squared: 0.1267,Validation_loss:0.1472, Validation R_squared:-0.0639
# Epoch [54/5000], Loss: 0.2295, R-squared: 0.1285,Validation_loss:0.1468, Validation R_squared:-0.0611
# Epoch [55/5000], Loss: 0.2291, R-squared: 0.1303,Validation_loss:0.1464, Validation R_squared:-0.0585
# Epoch [56/5000], Loss: 0.2287, R-squared: 0.1321,Validation_loss:0.1461, Validation R_squared:-0.0559
# Epoch [57/5000], Loss: 0.2282, R-squared: 0.1338,Validation_loss:0.1458, Validation R_squared:-0.0534
# Epoch [58/5000], Loss: 0.2278, R-squared: 0.1356,Validation_loss:0.1454, Validation R_squared:-0.0511
# Epoch [59/5000], Loss: 0.2274, R-squared: 0.1374,Validation_loss:0.1451, Validation R_squared:-0.0488
# Epoch [60/5000], Loss: 0.2269, R-squared: 0.1391,Validation_loss:0.1448, Validation R_squared:-0.0465
# Epoch [61/5000], Loss: 0.2265, R-squared: 0.1409,Validation_loss:0.1445, Validation R_squared:-0.0441
# Epoch [62/5000], Loss: 0.2261, R-squared: 0.1427,Validation_loss:0.1442, Validation R_squared:-0.0418
# Epoch [63/5000], Loss: 0.2257, R-squared: 0.1444,Validation_loss:0.1439, Validation R_squared:-0.0397
# Epoch [64/5000], Loss: 0.2253, R-squared: 0.1461,Validation_loss:0.1436, Validation R_squared:-0.0374
# Epoch [65/5000], Loss: 0.2248, R-squared: 0.1479,Validation_loss:0.1434, Validation R_squared:-0.0353
# Epoch [66/5000], Loss: 0.2244, R-squared: 0.1496,Validation_loss:0.1431, Validation R_squared:-0.0332
# Epoch [67/5000], Loss: 0.2240, R-squared: 0.1513,Validation_loss:0.1428, Validation R_squared:-0.0310
# Epoch [68/5000], Loss: 0.2236, R-squared: 0.1531,Validation_loss:0.1425, Validation R_squared:-0.0288
# Epoch [69/5000], Loss: 0.2232, R-squared: 0.1548,Validation_loss:0.1422, Validation R_squared:-0.0265
# Epoch [70/5000], Loss: 0.2228, R-squared: 0.1565,Validation_loss:0.1419, Validation R_squared:-0.0243
# Epoch [71/5000], Loss: 0.2224, R-squared: 0.1582,Validation_loss:0.1416, Validation R_squared:-0.0220
# Epoch [72/5000], Loss: 0.2219, R-squared: 0.1599,Validation_loss:0.1413, Validation R_squared:-0.0198
# Epoch [73/5000], Loss: 0.2215, R-squared: 0.1616,Validation_loss:0.1410, Validation R_squared:-0.0175
# Epoch [74/5000], Loss: 0.2211, R-squared: 0.1633,Validation_loss:0.1407, Validation R_squared:-0.0151
# Epoch [75/5000], Loss: 0.2207, R-squared: 0.1651,Validation_loss:0.1404, Validation R_squared:-0.0127
# Epoch [76/5000], Loss: 0.2203, R-squared: 0.1668,Validation_loss:0.1400, Validation R_squared:-0.0104
# Epoch [77/5000], Loss: 0.2199, R-squared: 0.1685,Validation_loss:0.1397, Validation R_squared:-0.0081
# Epoch [78/5000], Loss: 0.2195, R-squared: 0.1701,Validation_loss:0.1395, Validation R_squared:-0.0061
# Epoch [79/5000], Loss: 0.2191, R-squared: 0.1718,Validation_loss:0.1392, Validation R_squared:-0.0039
# Epoch [80/5000], Loss: 0.2187, R-squared: 0.1735,Validation_loss:0.1389, Validation R_squared:-0.0017
# Epoch [81/5000], Loss: 0.2183, R-squared: 0.1751,Validation_loss:0.1386, Validation R_squared:0.0003
# Epoch [82/5000], Loss: 0.2179, R-squared: 0.1768,Validation_loss:0.1383, Validation R_squared:0.0023
# Epoch [83/5000], Loss: 0.2175, R-squared: 0.1784,Validation_loss:0.1381, Validation R_squared:0.0044
# Epoch [84/5000], Loss: 0.2171, R-squared: 0.1801,Validation_loss:0.1378, Validation R_squared:0.0065
# Epoch [85/5000], Loss: 0.2167, R-squared: 0.1817,Validation_loss:0.1375, Validation R_squared:0.0085
# Epoch [86/5000], Loss: 0.2163, R-squared: 0.1833,Validation_loss:0.1373, Validation R_squared:0.0106
# Epoch [87/5000], Loss: 0.2159, R-squared: 0.1849,Validation_loss:0.1370, Validation R_squared:0.0124
# Epoch [88/5000], Loss: 0.2155, R-squared: 0.1865,Validation_loss:0.1367, Validation R_squared:0.0144
# Epoch [89/5000], Loss: 0.2151, R-squared: 0.1881,Validation_loss:0.1365, Validation R_squared:0.0163
# Epoch [90/5000], Loss: 0.2148, R-squared: 0.1897,Validation_loss:0.1362, Validation R_squared:0.0183
# Epoch [91/5000], Loss: 0.2144, R-squared: 0.1913,Validation_loss:0.1360, Validation R_squared:0.0202
# Epoch [92/5000], Loss: 0.2140, R-squared: 0.1929,Validation_loss:0.1357, Validation R_squared:0.0222
# Epoch [93/5000], Loss: 0.2136, R-squared: 0.1945,Validation_loss:0.1355, Validation R_squared:0.0242
# Epoch [94/5000], Loss: 0.2132, R-squared: 0.1961,Validation_loss:0.1352, Validation R_squared:0.0261
# Epoch [95/5000], Loss: 0.2129, R-squared: 0.1976,Validation_loss:0.1349, Validation R_squared:0.0280
# Epoch [96/5000], Loss: 0.2125, R-squared: 0.1992,Validation_loss:0.1347, Validation R_squared:0.0300
# Epoch [97/5000], Loss: 0.2121, R-squared: 0.2007,Validation_loss:0.1344, Validation R_squared:0.0320
# Epoch [98/5000], Loss: 0.2117, R-squared: 0.2023,Validation_loss:0.1342, Validation R_squared:0.0340
# Epoch [99/5000], Loss: 0.2113, R-squared: 0.2038,Validation_loss:0.1339, Validation R_squared:0.0359
# Epoch [100/5000], Loss: 0.2110, R-squared: 0.2054,Validation_loss:0.1337, Validation R_squared:0.0378
# Epoch [101/5000], Loss: 0.2106, R-squared: 0.2069,Validation_loss:0.1334, Validation R_squared:0.0398
# Epoch [102/5000], Loss: 0.2102, R-squared: 0.2085,Validation_loss:0.1331, Validation R_squared:0.0418
# Epoch [103/5000], Loss: 0.2099, R-squared: 0.2100,Validation_loss:0.1329, Validation R_squared:0.0438
# Epoch [104/5000], Loss: 0.2095, R-squared: 0.2115,Validation_loss:0.1326, Validation R_squared:0.0458
# Epoch [105/5000], Loss: 0.2091, R-squared: 0.2130,Validation_loss:0.1323, Validation R_squared:0.0478
# Epoch [106/5000], Loss: 0.2088, R-squared: 0.2145,Validation_loss:0.1321, Validation R_squared:0.0498
# Epoch [107/5000], Loss: 0.2084, R-squared: 0.2161,Validation_loss:0.1318, Validation R_squared:0.0518
# Epoch [108/5000], Loss: 0.2080, R-squared: 0.2176,Validation_loss:0.1316, Validation R_squared:0.0536
# Epoch [109/5000], Loss: 0.2077, R-squared: 0.2190,Validation_loss:0.1313, Validation R_squared:0.0554
# Epoch [110/5000], Loss: 0.2073, R-squared: 0.2205,Validation_loss:0.1311, Validation R_squared:0.0571
# Epoch [111/5000], Loss: 0.2069, R-squared: 0.2220,Validation_loss:0.1309, Validation R_squared:0.0589
# Epoch [112/5000], Loss: 0.2066, R-squared: 0.2235,Validation_loss:0.1306, Validation R_squared:0.0606
# Epoch [113/5000], Loss: 0.2062, R-squared: 0.2249,Validation_loss:0.1304, Validation R_squared:0.0622
# Epoch [114/5000], Loss: 0.2059, R-squared: 0.2264,Validation_loss:0.1302, Validation R_squared:0.0638
# Epoch [115/5000], Loss: 0.2055, R-squared: 0.2278,Validation_loss:0.1300, Validation R_squared:0.0654
# Epoch [116/5000], Loss: 0.2052, R-squared: 0.2293,Validation_loss:0.1298, Validation R_squared:0.0669
# Epoch [117/5000], Loss: 0.2048, R-squared: 0.2307,Validation_loss:0.1296, Validation R_squared:0.0684
# Epoch [118/5000], Loss: 0.2045, R-squared: 0.2322,Validation_loss:0.1294, Validation R_squared:0.0700
# Epoch [119/5000], Loss: 0.2041, R-squared: 0.2336,Validation_loss:0.1292, Validation R_squared:0.0714
# Epoch [120/5000], Loss: 0.2038, R-squared: 0.2351,Validation_loss:0.1290, Validation R_squared:0.0728
# Epoch [121/5000], Loss: 0.2034, R-squared: 0.2365,Validation_loss:0.1289, Validation R_squared:0.0742
# Epoch [122/5000], Loss: 0.2031, R-squared: 0.2379,Validation_loss:0.1287, Validation R_squared:0.0756
# Epoch [123/5000], Loss: 0.2028, R-squared: 0.2393,Validation_loss:0.1285, Validation R_squared:0.0768
# Epoch [124/5000], Loss: 0.2024, R-squared: 0.2407,Validation_loss:0.1284, Validation R_squared:0.0780
# Epoch [125/5000], Loss: 0.2021, R-squared: 0.2421,Validation_loss:0.1282, Validation R_squared:0.0792
# Epoch [126/5000], Loss: 0.2018, R-squared: 0.2435,Validation_loss:0.1280, Validation R_squared:0.0804
# Epoch [127/5000], Loss: 0.2014, R-squared: 0.2448,Validation_loss:0.1279, Validation R_squared:0.0816
# Epoch [128/5000], Loss: 0.2011, R-squared: 0.2462,Validation_loss:0.1277, Validation R_squared:0.0828
# Epoch [129/5000], Loss: 0.2007, R-squared: 0.2476,Validation_loss:0.1276, Validation R_squared:0.0839
# Epoch [130/5000], Loss: 0.2004, R-squared: 0.2490,Validation_loss:0.1275, Validation R_squared:0.0849
# Epoch [131/5000], Loss: 0.2001, R-squared: 0.2503,Validation_loss:0.1273, Validation R_squared:0.0860
# Epoch [132/5000], Loss: 0.1997, R-squared: 0.2517,Validation_loss:0.1272, Validation R_squared:0.0870
# Epoch [133/5000], Loss: 0.1994, R-squared: 0.2530,Validation_loss:0.1271, Validation R_squared:0.0880
# Epoch [134/5000], Loss: 0.1991, R-squared: 0.2544,Validation_loss:0.1269, Validation R_squared:0.0889
# Epoch [135/5000], Loss: 0.1988, R-squared: 0.2557,Validation_loss:0.1268, Validation R_squared:0.0898
# Epoch [136/5000], Loss: 0.1985, R-squared: 0.2570,Validation_loss:0.1267, Validation R_squared:0.0906
# Epoch [137/5000], Loss: 0.1981, R-squared: 0.2583,Validation_loss:0.1266, Validation R_squared:0.0914
# Epoch [138/5000], Loss: 0.1978, R-squared: 0.2596,Validation_loss:0.1265, Validation R_squared:0.0922
# Epoch [139/5000], Loss: 0.1975, R-squared: 0.2609,Validation_loss:0.1264, Validation R_squared:0.0930
# Epoch [140/5000], Loss: 0.1972, R-squared: 0.2622,Validation_loss:0.1263, Validation R_squared:0.0938
# Epoch [141/5000], Loss: 0.1969, R-squared: 0.2635,Validation_loss:0.1262, Validation R_squared:0.0945
# Epoch [142/5000], Loss: 0.1966, R-squared: 0.2648,Validation_loss:0.1261, Validation R_squared:0.0952
# Epoch [143/5000], Loss: 0.1962, R-squared: 0.2660,Validation_loss:0.1260, Validation R_squared:0.0959
# Epoch [144/5000], Loss: 0.1959, R-squared: 0.2673,Validation_loss:0.1259, Validation R_squared:0.0966
# Epoch [145/5000], Loss: 0.1956, R-squared: 0.2686,Validation_loss:0.1258, Validation R_squared:0.0972
# Epoch [146/5000], Loss: 0.1953, R-squared: 0.2699,Validation_loss:0.1257, Validation R_squared:0.0978
# Epoch [147/5000], Loss: 0.1950, R-squared: 0.2711,Validation_loss:0.1257, Validation R_squared:0.0984
# Epoch [148/5000], Loss: 0.1947, R-squared: 0.2724,Validation_loss:0.1256, Validation R_squared:0.0989
# Epoch [149/5000], Loss: 0.1944, R-squared: 0.2736,Validation_loss:0.1255, Validation R_squared:0.0994
# Epoch [150/5000], Loss: 0.1941, R-squared: 0.2749,Validation_loss:0.1255, Validation R_squared:0.0998
# Epoch [151/5000], Loss: 0.1938, R-squared: 0.2761,Validation_loss:0.1254, Validation R_squared:0.1001
# Epoch [152/5000], Loss: 0.1935, R-squared: 0.2773,Validation_loss:0.1253, Validation R_squared:0.1004
# Epoch [153/5000], Loss: 0.1932, R-squared: 0.2785,Validation_loss:0.1253, Validation R_squared:0.1008
# Epoch [154/5000], Loss: 0.1929, R-squared: 0.2797,Validation_loss:0.1252, Validation R_squared:0.1010
# Epoch [155/5000], Loss: 0.1926, R-squared: 0.2809,Validation_loss:0.1252, Validation R_squared:0.1013
# Epoch [156/5000], Loss: 0.1923, R-squared: 0.2821,Validation_loss:0.1252, Validation R_squared:0.1015
# Epoch [157/5000], Loss: 0.1920, R-squared: 0.2833,Validation_loss:0.1251, Validation R_squared:0.1017
# Epoch [158/5000], Loss: 0.1917, R-squared: 0.2845,Validation_loss:0.1251, Validation R_squared:0.1018
# Epoch [159/5000], Loss: 0.1914, R-squared: 0.2857,Validation_loss:0.1251, Validation R_squared:0.1020
# Epoch [160/5000], Loss: 0.1912, R-squared: 0.2869,Validation_loss:0.1250, Validation R_squared:0.1021
# Epoch [161/5000], Loss: 0.1909, R-squared: 0.2881,Validation_loss:0.1250, Validation R_squared:0.1022
# Epoch [162/5000], Loss: 0.1906, R-squared: 0.2892,Validation_loss:0.1250, Validation R_squared:0.1022
# Epoch [163/5000], Loss: 0.1903, R-squared: 0.2904,Validation_loss:0.1250, Validation R_squared:0.1024
# Epoch [164/5000], Loss: 0.1900, R-squared: 0.2916,Validation_loss:0.1249, Validation R_squared:0.1024
# Epoch [165/5000], Loss: 0.1897, R-squared: 0.2927,Validation_loss:0.1249, Validation R_squared:0.1025
# Epoch [166/5000], Loss: 0.1895, R-squared: 0.2939,Validation_loss:0.1249, Validation R_squared:0.1024
# Epoch [167/5000], Loss: 0.1892, R-squared: 0.2950,Validation_loss:0.1249, Validation R_squared:0.1026
# Epoch [168/5000], Loss: 0.1889, R-squared: 0.2961,Validation_loss:0.1248, Validation R_squared:0.1026
# Epoch [169/5000], Loss: 0.1886, R-squared: 0.2973,Validation_loss:0.1248, Validation R_squared:0.1026
# Epoch [170/5000], Loss: 0.1883, R-squared: 0.2984,Validation_loss:0.1248, Validation R_squared:0.1024
# Epoch [171/5000], Loss: 0.1881, R-squared: 0.2995,Validation_loss:0.1248, Validation R_squared:0.1024
# Epoch [172/5000], Loss: 0.1878, R-squared: 0.3006,Validation_loss:0.1248, Validation R_squared:0.1023
# Epoch [173/5000], Loss: 0.1875, R-squared: 0.3017,Validation_loss:0.1248, Validation R_squared:0.1022
# Epoch [174/5000], Loss: 0.1873, R-squared: 0.3028,Validation_loss:0.1248, Validation R_squared:0.1020
# Epoch [175/5000], Loss: 0.1870, R-squared: 0.3039,Validation_loss:0.1248, Validation R_squared:0.1018
# Epoch [176/5000], Loss: 0.1867, R-squared: 0.3050,Validation_loss:0.1248, Validation R_squared:0.1017
# Epoch [177/5000], Loss: 0.1865, R-squared: 0.3060,Validation_loss:0.1248, Validation R_squared:0.1014
# Epoch [178/5000], Loss: 0.1862, R-squared: 0.3071,Validation_loss:0.1248, Validation R_squared:0.1012
# Epoch [179/5000], Loss: 0.1860, R-squared: 0.3082,Validation_loss:0.1248, Validation R_squared:0.1011
# Epoch [180/5000], Loss: 0.1857, R-squared: 0.3092,Validation_loss:0.1248, Validation R_squared:0.1007
# Epoch [181/5000], Loss: 0.1854, R-squared: 0.3103,Validation_loss:0.1248, Validation R_squared:0.1005
# Epoch [182/5000], Loss: 0.1852, R-squared: 0.3113,Validation_loss:0.1249, Validation R_squared:0.1002
# Epoch [183/5000], Loss: 0.1849, R-squared: 0.3124,Validation_loss:0.1249, Validation R_squared:0.1000
# Epoch [184/5000], Loss: 0.1847, R-squared: 0.3134,Validation_loss:0.1249, Validation R_squared:0.0995
# Epoch [185/5000], Loss: 0.1844, R-squared: 0.3144,Validation_loss:0.1249, Validation R_squared:0.0993
# Epoch [186/5000], Loss: 0.1842, R-squared: 0.3154,Validation_loss:0.1249, Validation R_squared:0.0988
# Epoch [187/5000], Loss: 0.1839, R-squared: 0.3165,Validation_loss:0.1249, Validation R_squared:0.0986
# Epoch [188/5000], Loss: 0.1837, R-squared: 0.3175,Validation_loss:0.1250, Validation R_squared:0.0981
# Epoch [189/5000], Loss: 0.1834, R-squared: 0.3185,Validation_loss:0.1250, Validation R_squared:0.0979
# Epoch [190/5000], Loss: 0.1832, R-squared: 0.3195,Validation_loss:0.1250, Validation R_squared:0.0973
# Epoch [191/5000], Loss: 0.1829, R-squared: 0.3205,Validation_loss:0.1250, Validation R_squared:0.0969
# Epoch [192/5000], Loss: 0.1827, R-squared: 0.3215,Validation_loss:0.1251, Validation R_squared:0.0964
# Epoch [193/5000], Loss: 0.1825, R-squared: 0.3225,Validation_loss:0.1251, Validation R_squared:0.0960
# Epoch [194/5000], Loss: 0.1822, R-squared: 0.3234,Validation_loss:0.1251, Validation R_squared:0.0956
# Epoch [195/5000], Loss: 0.1820, R-squared: 0.3244,Validation_loss:0.1252, Validation R_squared:0.0951
# Epoch [196/5000], Loss: 0.1817, R-squared: 0.3254,Validation_loss:0.1252, Validation R_squared:0.0944
# Epoch [197/5000], Loss: 0.1815, R-squared: 0.3264,Validation_loss:0.1252, Validation R_squared:0.0941
# Epoch [198/5000], Loss: 0.1813, R-squared: 0.3273,Validation_loss:0.1253, Validation R_squared:0.0935
# Epoch [199/5000], Loss: 0.1810, R-squared: 0.3283,Validation_loss:0.1253, Validation R_squared:0.0930
# Epoch [200/5000], Loss: 0.1808, R-squared: 0.3292,Validation_loss:0.1254, Validation R_squared:0.0924
# Epoch [201/5000], Loss: 0.1806, R-squared: 0.3301,Validation_loss:0.1254, Validation R_squared:0.0918
# Epoch [202/5000], Loss: 0.1803, R-squared: 0.3311,Validation_loss:0.1255, Validation R_squared:0.0911
# Epoch [203/5000], Loss: 0.1801, R-squared: 0.3320,Validation_loss:0.1255, Validation R_squared:0.0907
# Epoch [204/5000], Loss: 0.1799, R-squared: 0.3329,Validation_loss:0.1256, Validation R_squared:0.0899
# Epoch [205/5000], Loss: 0.1797, R-squared: 0.3338,Validation_loss:0.1256, Validation R_squared:0.0892
# Epoch [206/5000], Loss: 0.1794, R-squared: 0.3347,Validation_loss:0.1256, Validation R_squared:0.0888
# Epoch [207/5000], Loss: 0.1792, R-squared: 0.3356,Validation_loss:0.1257, Validation R_squared:0.0879
# Epoch [208/5000], Loss: 0.1790, R-squared: 0.3365,Validation_loss:0.1258, Validation R_squared:0.0874
# Epoch [209/5000], Loss: 0.1788, R-squared: 0.3374,Validation_loss:0.1258, Validation R_squared:0.0865
# Epoch [210/5000], Loss: 0.1786, R-squared: 0.3383,Validation_loss:0.1259, Validation R_squared:0.0860
# Epoch [211/5000], Loss: 0.1783, R-squared: 0.3392,Validation_loss:0.1259, Validation R_squared:0.0853
# Epoch [212/5000], Loss: 0.1781, R-squared: 0.3401,Validation_loss:0.1260, Validation R_squared:0.0845
# Epoch [213/5000], Loss: 0.1779, R-squared: 0.3410,Validation_loss:0.1261, Validation R_squared:0.0836
# Epoch [214/5000], Loss: 0.1777, R-squared: 0.3418,Validation_loss:0.1261, Validation R_squared:0.0830
# Epoch [215/5000], Loss: 0.1775, R-squared: 0.3427,Validation_loss:0.1262, Validation R_squared:0.0821
# Epoch [216/5000], Loss: 0.1773, R-squared: 0.3436,Validation_loss:0.1263, Validation R_squared:0.0813
# Epoch [217/5000], Loss: 0.1771, R-squared: 0.3444,Validation_loss:0.1264, Validation R_squared:0.0804
# Epoch [218/5000], Loss: 0.1769, R-squared: 0.3453,Validation_loss:0.1265, Validation R_squared:0.0791
# Epoch [219/5000], Loss: 0.1766, R-squared: 0.3461,Validation_loss:0.1265, Validation R_squared:0.0786
# Epoch [220/5000], Loss: 0.1764, R-squared: 0.3469,Validation_loss:0.1266, Validation R_squared:0.0775
# Epoch [221/5000], Loss: 0.1762, R-squared: 0.3478,Validation_loss:0.1267, Validation R_squared:0.0765
# Epoch [222/5000], Loss: 0.1760, R-squared: 0.3486,Validation_loss:0.1268, Validation R_squared:0.0755
# Epoch [223/5000], Loss: 0.1758, R-squared: 0.3494,Validation_loss:0.1269, Validation R_squared:0.0745
# Epoch [224/5000], Loss: 0.1756, R-squared: 0.3502,Validation_loss:0.1270, Validation R_squared:0.0736
# Epoch [225/5000], Loss: 0.1754, R-squared: 0.3510,Validation_loss:0.1271, Validation R_squared:0.0724
# Epoch [226/5000], Loss: 0.1752, R-squared: 0.3518,Validation_loss:0.1272, Validation R_squared:0.0713
# Epoch [227/5000], Loss: 0.1750, R-squared: 0.3526,Validation_loss:0.1273, Validation R_squared:0.0701
# Epoch [228/5000], Loss: 0.1748, R-squared: 0.3534,Validation_loss:0.1274, Validation R_squared:0.0693
# Epoch [229/5000], Loss: 0.1746, R-squared: 0.3542,Validation_loss:0.1275, Validation R_squared:0.0681
# Epoch [230/5000], Loss: 0.1744, R-squared: 0.3550,Validation_loss:0.1277, Validation R_squared:0.0668
# Epoch [231/5000], Loss: 0.1743, R-squared: 0.3558,Validation_loss:0.1277, Validation R_squared:0.0659
# Epoch [232/5000], Loss: 0.1741, R-squared: 0.3566,Validation_loss:0.1279, Validation R_squared:0.0646
# Epoch [233/5000], Loss: 0.1739, R-squared: 0.3573,Validation_loss:0.1280, Validation R_squared:0.0635
# Epoch [234/5000], Loss: 0.1737, R-squared: 0.3581,Validation_loss:0.1281, Validation R_squared:0.0624
# Epoch [235/5000], Loss: 0.1735, R-squared: 0.3589,Validation_loss:0.1282, Validation R_squared:0.0610
# Epoch [236/5000], Loss: 0.1733, R-squared: 0.3596,Validation_loss:0.1283, Validation R_squared:0.0600
# Epoch [237/5000], Loss: 0.1731, R-squared: 0.3604,Validation_loss:0.1285, Validation R_squared:0.0584
# Epoch [238/5000], Loss: 0.1729, R-squared: 0.3612,Validation_loss:0.1286, Validation R_squared:0.0573
# Epoch [239/5000], Loss: 0.1727, R-squared: 0.3619,Validation_loss:0.1287, Validation R_squared:0.0564
# Epoch [240/5000], Loss: 0.1726, R-squared: 0.3627,Validation_loss:0.1288, Validation R_squared:0.0549
# Epoch [241/5000], Loss: 0.1724, R-squared: 0.3634,Validation_loss:0.1289, Validation R_squared:0.0535
# Epoch [242/5000], Loss: 0.1722, R-squared: 0.3641,Validation_loss:0.1291, Validation R_squared:0.0523
# Epoch [243/5000], Loss: 0.1720, R-squared: 0.3649,Validation_loss:0.1292, Validation R_squared:0.0509
# Epoch [244/5000], Loss: 0.1718, R-squared: 0.3656,Validation_loss:0.1293, Validation R_squared:0.0498
# Epoch [245/5000], Loss: 0.1717, R-squared: 0.3663,Validation_loss:0.1294, Validation R_squared:0.0483
# Epoch [246/5000], Loss: 0.1715, R-squared: 0.3670,Validation_loss:0.1295, Validation R_squared:0.0472
# Epoch [247/5000], Loss: 0.1713, R-squared: 0.3677,Validation_loss:0.1297, Validation R_squared:0.0459
# Epoch [248/5000], Loss: 0.1711, R-squared: 0.3684,Validation_loss:0.1298, Validation R_squared:0.0447
# Epoch [249/5000], Loss: 0.1710, R-squared: 0.3691,Validation_loss:0.1299, Validation R_squared:0.0433
# Epoch [250/5000], Loss: 0.1708, R-squared: 0.3698,Validation_loss:0.1300, Validation R_squared:0.0422
# Epoch [251/5000], Loss: 0.1706, R-squared: 0.3705,Validation_loss:0.1302, Validation R_squared:0.0406
# Epoch [252/5000], Loss: 0.1704, R-squared: 0.3712,Validation_loss:0.1303, Validation R_squared:0.0393
# Epoch [253/5000], Loss: 0.1703, R-squared: 0.3719,Validation_loss:0.1304, Validation R_squared:0.0379
# Epoch [254/5000], Loss: 0.1701, R-squared: 0.3725,Validation_loss:0.1306, Validation R_squared:0.0366
# Epoch [255/5000], Loss: 0.1699, R-squared: 0.3732,Validation_loss:0.1307, Validation R_squared:0.0351
# Epoch [256/5000], Loss: 0.1698, R-squared: 0.3739,Validation_loss:0.1308, Validation R_squared:0.0339
# Epoch [257/5000], Loss: 0.1696, R-squared: 0.3745,Validation_loss:0.1310, Validation R_squared:0.0321
# Epoch [258/5000], Loss: 0.1695, R-squared: 0.3752,Validation_loss:0.1311, Validation R_squared:0.0311
# Epoch [259/5000], Loss: 0.1693, R-squared: 0.3759,Validation_loss:0.1313, Validation R_squared:0.0294
# Epoch [260/5000], Loss: 0.1691, R-squared: 0.3765,Validation_loss:0.1314, Validation R_squared:0.0282
# Epoch [261/5000], Loss: 0.1690, R-squared: 0.3772,Validation_loss:0.1315, Validation R_squared:0.0266
# Epoch [262/5000], Loss: 0.1688, R-squared: 0.3778,Validation_loss:0.1316, Validation R_squared:0.0255
# Epoch [263/5000], Loss: 0.1686, R-squared: 0.3785,Validation_loss:0.1318, Validation R_squared:0.0242
# Epoch [264/5000], Loss: 0.1685, R-squared: 0.3791,Validation_loss:0.1319, Validation R_squared:0.0225
# Epoch [265/5000], Loss: 0.1683, R-squared: 0.3797,Validation_loss:0.1321, Validation R_squared:0.0213
# Epoch [266/5000], Loss: 0.1682, R-squared: 0.3804,Validation_loss:0.1322, Validation R_squared:0.0200
# Epoch [267/5000], Loss: 0.1680, R-squared: 0.3810,Validation_loss:0.1323, Validation R_squared:0.0185
# Epoch [268/5000], Loss: 0.1679, R-squared: 0.3816,Validation_loss:0.1325, Validation R_squared:0.0172
# Epoch [269/5000], Loss: 0.1677, R-squared: 0.3822,Validation_loss:0.1326, Validation R_squared:0.0156
# Epoch [270/5000], Loss: 0.1676, R-squared: 0.3828,Validation_loss:0.1327, Validation R_squared:0.0144
# Epoch [271/5000], Loss: 0.1674, R-squared: 0.3834,Validation_loss:0.1329, Validation R_squared:0.0129
# Epoch [272/5000], Loss: 0.1673, R-squared: 0.3840,Validation_loss:0.1330, Validation R_squared:0.0115
# Epoch [273/5000], Loss: 0.1671, R-squared: 0.3846,Validation_loss:0.1332, Validation R_squared:0.0101
# Epoch [274/5000], Loss: 0.1670, R-squared: 0.3852,Validation_loss:0.1333, Validation R_squared:0.0088
# Epoch [275/5000], Loss: 0.1668, R-squared: 0.3858,Validation_loss:0.1335, Validation R_squared:0.0070
# Epoch [276/5000], Loss: 0.1667, R-squared: 0.3864,Validation_loss:0.1336, Validation R_squared:0.0057
# Epoch [277/5000], Loss: 0.1665, R-squared: 0.3870,Validation_loss:0.1337, Validation R_squared:0.0045
# Epoch [278/5000], Loss: 0.1664, R-squared: 0.3876,Validation_loss:0.1339, Validation R_squared:0.0028
# Epoch [279/5000], Loss: 0.1662, R-squared: 0.3882,Validation_loss:0.1340, Validation R_squared:0.0013
# Epoch [280/5000], Loss: 0.1661, R-squared: 0.3888,Validation_loss:0.1341, Validation R_squared:0.0001
# Epoch [281/5000], Loss: 0.1660, R-squared: 0.3893,Validation_loss:0.1343, Validation R_squared:-0.0019
# Epoch [282/5000], Loss: 0.1658, R-squared: 0.3899,Validation_loss:0.1344, Validation R_squared:-0.0027
# Epoch [283/5000], Loss: 0.1657, R-squared: 0.3905,Validation_loss:0.1346, Validation R_squared:-0.0046
# Epoch [284/5000], Loss: 0.1655, R-squared: 0.3910,Validation_loss:0.1347, Validation R_squared:-0.0059
# Epoch [285/5000], Loss: 0.1654, R-squared: 0.3916,Validation_loss:0.1349, Validation R_squared:-0.0075
# Epoch [286/5000], Loss: 0.1653, R-squared: 0.3921,Validation_loss:0.1350, Validation R_squared:-0.0086
# Epoch [287/5000], Loss: 0.1651, R-squared: 0.3927,Validation_loss:0.1352, Validation R_squared:-0.0104
# Epoch [288/5000], Loss: 0.1650, R-squared: 0.3933,Validation_loss:0.1352, Validation R_squared:-0.0110
# Epoch [289/5000], Loss: 0.1648, R-squared: 0.3938,Validation_loss:0.1355, Validation R_squared:-0.0137
# Epoch [290/5000], Loss: 0.1647, R-squared: 0.3944,Validation_loss:0.1355, Validation R_squared:-0.0140
# Epoch [291/5000], Loss: 0.1646, R-squared: 0.3949,Validation_loss:0.1357, Validation R_squared:-0.0160
# Epoch [292/5000], Loss: 0.1644, R-squared: 0.3954,Validation_loss:0.1358, Validation R_squared:-0.0169
# Epoch [293/5000], Loss: 0.1643, R-squared: 0.3960,Validation_loss:0.1360, Validation R_squared:-0.0193
# Epoch [294/5000], Loss: 0.1642, R-squared: 0.3965,Validation_loss:0.1361, Validation R_squared:-0.0199
# Epoch [295/5000], Loss: 0.1640, R-squared: 0.3970,Validation_loss:0.1363, Validation R_squared:-0.0219
# Epoch [296/5000], Loss: 0.1639, R-squared: 0.3976,Validation_loss:0.1364, Validation R_squared:-0.0234
# Epoch [297/5000], Loss: 0.1638, R-squared: 0.3981,Validation_loss:0.1366, Validation R_squared:-0.0247
# Epoch [298/5000], Loss: 0.1636, R-squared: 0.3986,Validation_loss:0.1367, Validation R_squared:-0.0261
# Epoch [299/5000], Loss: 0.1635, R-squared: 0.3991,Validation_loss:0.1369, Validation R_squared:-0.0276
# Epoch [300/5000], Loss: 0.1634, R-squared: 0.3996,Validation_loss:0.1370, Validation R_squared:-0.0294
# Epoch [301/5000], Loss: 0.1633, R-squared: 0.4001,Validation_loss:0.1371, Validation R_squared:-0.0302
# Epoch [302/5000], Loss: 0.1631, R-squared: 0.4006,Validation_loss:0.1373, Validation R_squared:-0.0326
# Epoch [303/5000], Loss: 0.1630, R-squared: 0.4012,Validation_loss:0.1374, Validation R_squared:-0.0332
# Epoch [304/5000], Loss: 0.1629, R-squared: 0.4016,Validation_loss:0.1376, Validation R_squared:-0.0354
# Epoch [305/5000], Loss: 0.1628, R-squared: 0.4022,Validation_loss:0.1377, Validation R_squared:-0.0367
# Epoch [306/5000], Loss: 0.1626, R-squared: 0.4026,Validation_loss:0.1379, Validation R_squared:-0.0378
# Epoch [307/5000], Loss: 0.1625, R-squared: 0.4031,Validation_loss:0.1381, Validation R_squared:-0.0400
# Epoch [308/5000], Loss: 0.1624, R-squared: 0.4036,Validation_loss:0.1381, Validation R_squared:-0.0403
# Epoch [309/5000], Loss: 0.1623, R-squared: 0.4041,Validation_loss:0.1383, Validation R_squared:-0.0428
# Epoch [310/5000], Loss: 0.1622, R-squared: 0.4046,Validation_loss:0.1384, Validation R_squared:-0.0433
# Epoch [311/5000], Loss: 0.1620, R-squared: 0.4051,Validation_loss:0.1386, Validation R_squared:-0.0458
# Epoch [312/5000], Loss: 0.1619, R-squared: 0.4056,Validation_loss:0.1387, Validation R_squared:-0.0463
# Epoch [313/5000], Loss: 0.1618, R-squared: 0.4060,Validation_loss:0.1389, Validation R_squared:-0.0481
# Epoch [314/5000], Loss: 0.1617, R-squared: 0.4065,Validation_loss:0.1390, Validation R_squared:-0.0493
# Epoch [315/5000], Loss: 0.1616, R-squared: 0.4070,Validation_loss:0.1392, Validation R_squared:-0.0511
# Epoch [316/5000], Loss: 0.1614, R-squared: 0.4075,Validation_loss:0.1393, Validation R_squared:-0.0522
# Epoch [317/5000], Loss: 0.1613, R-squared: 0.4079,Validation_loss:0.1394, Validation R_squared:-0.0540
# Epoch [318/5000], Loss: 0.1612, R-squared: 0.4084,Validation_loss:0.1396, Validation R_squared:-0.0552
# Epoch [319/5000], Loss: 0.1611, R-squared: 0.4088,Validation_loss:0.1397, Validation R_squared:-0.0567
# Epoch [320/5000], Loss: 0.1610, R-squared: 0.4093,Validation_loss:0.1398, Validation R_squared:-0.0580
# Epoch [321/5000], Loss: 0.1609, R-squared: 0.4098,Validation_loss:0.1400, Validation R_squared:-0.0595
# Epoch [322/5000], Loss: 0.1608, R-squared: 0.4102,Validation_loss:0.1401, Validation R_squared:-0.0611
# Epoch [323/5000], Loss: 0.1606, R-squared: 0.4107,Validation_loss:0.1402, Validation R_squared:-0.0621
# Epoch [324/5000], Loss: 0.1605, R-squared: 0.4111,Validation_loss:0.1404, Validation R_squared:-0.0638
# Epoch [325/5000], Loss: 0.1604, R-squared: 0.4116,Validation_loss:0.1405, Validation R_squared:-0.0649
# Epoch [326/5000], Loss: 0.1603, R-squared: 0.4120,Validation_loss:0.1407, Validation R_squared:-0.0666
# Epoch [327/5000], Loss: 0.1602, R-squared: 0.4124,Validation_loss:0.1408, Validation R_squared:-0.0680
# Epoch [328/5000], Loss: 0.1601, R-squared: 0.4129,Validation_loss:0.1410, Validation R_squared:-0.0698
# Epoch [329/5000], Loss: 0.1600, R-squared: 0.4133,Validation_loss:0.1411, Validation R_squared:-0.0707
# Epoch [330/5000], Loss: 0.1599, R-squared: 0.4137,Validation_loss:0.1413, Validation R_squared:-0.0731
# Epoch [331/5000], Loss: 0.1598, R-squared: 0.4142,Validation_loss:0.1414, Validation R_squared:-0.0737
# Epoch [332/5000], Loss: 0.1597, R-squared: 0.4146,Validation_loss:0.1416, Validation R_squared:-0.0758
# Epoch [333/5000], Loss: 0.1596, R-squared: 0.4150,Validation_loss:0.1416, Validation R_squared:-0.0763
# Epoch [334/5000], Loss: 0.1594, R-squared: 0.4155,Validation_loss:0.1419, Validation R_squared:-0.0792
# Epoch [335/5000], Loss: 0.1593, R-squared: 0.4159,Validation_loss:0.1419, Validation R_squared:-0.0792
# Epoch [336/5000], Loss: 0.1592, R-squared: 0.4163,Validation_loss:0.1421, Validation R_squared:-0.0817
# Epoch [337/5000], Loss: 0.1591, R-squared: 0.4167,Validation_loss:0.1423, Validation R_squared:-0.0832
# Epoch [338/5000], Loss: 0.1590, R-squared: 0.4171,Validation_loss:0.1424, Validation R_squared:-0.0850
# Epoch [339/5000], Loss: 0.1589, R-squared: 0.4176,Validation_loss:0.1425, Validation R_squared:-0.0859
# Epoch [340/5000], Loss: 0.1588, R-squared: 0.4180,Validation_loss:0.1427, Validation R_squared:-0.0879
# Epoch [341/5000], Loss: 0.1587, R-squared: 0.4184,Validation_loss:0.1428, Validation R_squared:-0.0889
# Epoch [342/5000], Loss: 0.1586, R-squared: 0.4188,Validation_loss:0.1430, Validation R_squared:-0.0907
# Epoch [343/5000], Loss: 0.1585, R-squared: 0.4192,Validation_loss:0.1431, Validation R_squared:-0.0921
# Epoch [344/5000], Loss: 0.1584, R-squared: 0.4196,Validation_loss:0.1434, Validation R_squared:-0.0945
# Epoch [345/5000], Loss: 0.1583, R-squared: 0.4200,Validation_loss:0.1434, Validation R_squared:-0.0948
# Epoch [346/5000], Loss: 0.1582, R-squared: 0.4204,Validation_loss:0.1436, Validation R_squared:-0.0968
# Epoch [347/5000], Loss: 0.1581, R-squared: 0.4208,Validation_loss:0.1437, Validation R_squared:-0.0980
# Epoch [348/5000], Loss: 0.1580, R-squared: 0.4212,Validation_loss:0.1439, Validation R_squared:-0.0997
# Epoch [349/5000], Loss: 0.1579, R-squared: 0.4216,Validation_loss:0.1440, Validation R_squared:-0.1008
# Epoch [350/5000], Loss: 0.1578, R-squared: 0.4220,Validation_loss:0.1442, Validation R_squared:-0.1031
# Epoch [351/5000], Loss: 0.1577, R-squared: 0.4224,Validation_loss:0.1443, Validation R_squared:-0.1040
# Epoch [352/5000], Loss: 0.1576, R-squared: 0.4227,Validation_loss:0.1445, Validation R_squared:-0.1059
# Epoch [353/5000], Loss: 0.1575, R-squared: 0.4231,Validation_loss:0.1446, Validation R_squared:-0.1073
# Epoch [354/5000], Loss: 0.1574, R-squared: 0.4235,Validation_loss:0.1447, Validation R_squared:-0.1083
# Epoch [355/5000], Loss: 0.1573, R-squared: 0.4239,Validation_loss:0.1449, Validation R_squared:-0.1105
# Epoch [356/5000], Loss: 0.1572, R-squared: 0.4243,Validation_loss:0.1450, Validation R_squared:-0.1113
# Epoch [357/5000], Loss: 0.1571, R-squared: 0.4247,Validation_loss:0.1451, Validation R_squared:-0.1130
# Epoch [358/5000], Loss: 0.1571, R-squared: 0.4250,Validation_loss:0.1453, Validation R_squared:-0.1143
# Epoch [359/5000], Loss: 0.1570, R-squared: 0.4254,Validation_loss:0.1455, Validation R_squared:-0.1165
# Epoch [360/5000], Loss: 0.1569, R-squared: 0.4258,Validation_loss:0.1455, Validation R_squared:-0.1165
# Epoch [361/5000], Loss: 0.1568, R-squared: 0.4262,Validation_loss:0.1457, Validation R_squared:-0.1187
# Epoch [362/5000], Loss: 0.1567, R-squared: 0.4265,Validation_loss:0.1459, Validation R_squared:-0.1203
# Epoch [363/5000], Loss: 0.1566, R-squared: 0.4269,Validation_loss:0.1460, Validation R_squared:-0.1218
# Epoch [364/5000], Loss: 0.1565, R-squared: 0.4273,Validation_loss:0.1461, Validation R_squared:-0.1230
# Epoch [365/5000], Loss: 0.1564, R-squared: 0.4276,Validation_loss:0.1462, Validation R_squared:-0.1242
# Epoch [366/5000], Loss: 0.1563, R-squared: 0.4280,Validation_loss:0.1464, Validation R_squared:-0.1264
# Epoch [367/5000], Loss: 0.1562, R-squared: 0.4284,Validation_loss:0.1464, Validation R_squared:-0.1263
# Epoch [368/5000], Loss: 0.1561, R-squared: 0.4287,Validation_loss:0.1467, Validation R_squared:-0.1288
# Epoch [369/5000], Loss: 0.1560, R-squared: 0.4291,Validation_loss:0.1467, Validation R_squared:-0.1297
# Epoch [370/5000], Loss: 0.1559, R-squared: 0.4295,Validation_loss:0.1469, Validation R_squared:-0.1311
# Epoch [371/5000], Loss: 0.1559, R-squared: 0.4298,Validation_loss:0.1470, Validation R_squared:-0.1323
# Epoch [372/5000], Loss: 0.1558, R-squared: 0.4302,Validation_loss:0.1471, Validation R_squared:-0.1339
# Epoch [373/5000], Loss: 0.1557, R-squared: 0.4305,Validation_loss:0.1473, Validation R_squared:-0.1353
# Epoch [374/5000], Loss: 0.1556, R-squared: 0.4309,Validation_loss:0.1475, Validation R_squared:-0.1371
# Epoch [375/5000], Loss: 0.1555, R-squared: 0.4312,Validation_loss:0.1475, Validation R_squared:-0.1378
# Epoch [376/5000], Loss: 0.1554, R-squared: 0.4316,Validation_loss:0.1476, Validation R_squared:-0.1384
# Epoch [377/5000], Loss: 0.1553, R-squared: 0.4319,Validation_loss:0.1478, Validation R_squared:-0.1411
# Epoch [378/5000], Loss: 0.1552, R-squared: 0.4323,Validation_loss:0.1478, Validation R_squared:-0.1414
# Epoch [379/5000], Loss: 0.1552, R-squared: 0.4326,Validation_loss:0.1480, Validation R_squared:-0.1433
# Epoch [380/5000], Loss: 0.1551, R-squared: 0.4330,Validation_loss:0.1480, Validation R_squared:-0.1430
# Epoch [381/5000], Loss: 0.1550, R-squared: 0.4333,Validation_loss:0.1483, Validation R_squared:-0.1464
# Epoch [382/5000], Loss: 0.1549, R-squared: 0.4337,Validation_loss:0.1483, Validation R_squared:-0.1459
# Epoch [383/5000], Loss: 0.1548, R-squared: 0.4340,Validation_loss:0.1485, Validation R_squared:-0.1480
# Epoch [384/5000], Loss: 0.1547, R-squared: 0.4343,Validation_loss:0.1486, Validation R_squared:-0.1492
# Epoch [385/5000], Loss: 0.1546, R-squared: 0.4347,Validation_loss:0.1488, Validation R_squared:-0.1511
# Epoch [386/5000], Loss: 0.1546, R-squared: 0.4350,Validation_loss:0.1487, Validation R_squared:-0.1502
# Epoch [387/5000], Loss: 0.1545, R-squared: 0.4353,Validation_loss:0.1490, Validation R_squared:-0.1537
# Epoch [388/5000], Loss: 0.1544, R-squared: 0.4357,Validation_loss:0.1490, Validation R_squared:-0.1538
# Epoch [389/5000], Loss: 0.1543, R-squared: 0.4360,Validation_loss:0.1493, Validation R_squared:-0.1560
# Epoch [390/5000], Loss: 0.1542, R-squared: 0.4364,Validation_loss:0.1491, Validation R_squared:-0.1546
# Epoch [391/5000], Loss: 0.1541, R-squared: 0.4367,Validation_loss:0.1495, Validation R_squared:-0.1590
# Epoch [392/5000], Loss: 0.1541, R-squared: 0.4370,Validation_loss:0.1493, Validation R_squared:-0.1571
# Epoch [393/5000], Loss: 0.1540, R-squared: 0.4373,Validation_loss:0.1497, Validation R_squared:-0.1611
# Epoch [394/5000], Loss: 0.1539, R-squared: 0.4377,Validation_loss:0.1496, Validation R_squared:-0.1599
# Epoch [395/5000], Loss: 0.1538, R-squared: 0.4380,Validation_loss:0.1499, Validation R_squared:-0.1631
# Epoch [396/5000], Loss: 0.1537, R-squared: 0.4383,Validation_loss:0.1498, Validation R_squared:-0.1622
# Epoch [397/5000], Loss: 0.1536, R-squared: 0.4386,Validation_loss:0.1501, Validation R_squared:-0.1653
# Epoch [398/5000], Loss: 0.1536, R-squared: 0.4390,Validation_loss:0.1501, Validation R_squared:-0.1648
# Epoch [399/5000], Loss: 0.1535, R-squared: 0.4393,Validation_loss:0.1503, Validation R_squared:-0.1669
# Epoch [400/5000], Loss: 0.1534, R-squared: 0.4396,Validation_loss:0.1504, Validation R_squared:-0.1678
# Epoch [401/5000], Loss: 0.1533, R-squared: 0.4399,Validation_loss:0.1504, Validation R_squared:-0.1683
# Epoch [402/5000], Loss: 0.1532, R-squared: 0.4402,Validation_loss:0.1506, Validation R_squared:-0.1703
# Epoch [403/5000], Loss: 0.1532, R-squared: 0.4406,Validation_loss:0.1506, Validation R_squared:-0.1703
# Epoch [404/5000], Loss: 0.1531, R-squared: 0.4408,Validation_loss:0.1509, Validation R_squared:-0.1729
# Epoch [405/5000], Loss: 0.1530, R-squared: 0.4412,Validation_loss:0.1508, Validation R_squared:-0.1722
# Epoch [406/5000], Loss: 0.1529, R-squared: 0.4415,Validation_loss:0.1510, Validation R_squared:-0.1749
# Epoch [407/5000], Loss: 0.1528, R-squared: 0.4418,Validation_loss:0.1511, Validation R_squared:-0.1755
# Epoch [408/5000], Loss: 0.1528, R-squared: 0.4421,Validation_loss:0.1511, Validation R_squared:-0.1761
# Epoch [409/5000], Loss: 0.1527, R-squared: 0.4424,Validation_loss:0.1512, Validation R_squared:-0.1771
# Epoch [410/5000], Loss: 0.1526, R-squared: 0.4427,Validation_loss:0.1514, Validation R_squared:-0.1783
# Epoch [411/5000], Loss: 0.1525, R-squared: 0.4430,Validation_loss:0.1514, Validation R_squared:-0.1792
# Epoch [412/5000], Loss: 0.1525, R-squared: 0.4433,Validation_loss:0.1516, Validation R_squared:-0.1807
# Epoch [413/5000], Loss: 0.1524, R-squared: 0.4437,Validation_loss:0.1516, Validation R_squared:-0.1814
# Epoch [414/5000], Loss: 0.1523, R-squared: 0.4440,Validation_loss:0.1518, Validation R_squared:-0.1829
# Epoch [415/5000], Loss: 0.1522, R-squared: 0.4443,Validation_loss:0.1518, Validation R_squared:-0.1834
# Epoch [416/5000], Loss: 0.1521, R-squared: 0.4446,Validation_loss:0.1520, Validation R_squared:-0.1851
# Epoch [417/5000], Loss: 0.1521, R-squared: 0.4449,Validation_loss:0.1520, Validation R_squared:-0.1851
# Epoch [418/5000], Loss: 0.1520, R-squared: 0.4452,Validation_loss:0.1523, Validation R_squared:-0.1881
# Epoch [419/5000], Loss: 0.1519, R-squared: 0.4455,Validation_loss:0.1522, Validation R_squared:-0.1873
# Epoch [420/5000], Loss: 0.1518, R-squared: 0.4457,Validation_loss:0.1525, Validation R_squared:-0.1903
# Epoch [421/5000], Loss: 0.1518, R-squared: 0.4461,Validation_loss:0.1524, Validation R_squared:-0.1895
# Epoch [422/5000], Loss: 0.1517, R-squared: 0.4463,Validation_loss:0.1528, Validation R_squared:-0.1932
# Epoch [423/5000], Loss: 0.1516, R-squared: 0.4467,Validation_loss:0.1525, Validation R_squared:-0.1910
# Epoch [424/5000], Loss: 0.1515, R-squared: 0.4469,Validation_loss:0.1530, Validation R_squared:-0.1957
# Epoch [425/5000], Loss: 0.1515, R-squared: 0.4473,Validation_loss:0.1527, Validation R_squared:-0.1931
# Epoch [426/5000], Loss: 0.1514, R-squared: 0.4475,Validation_loss:0.1532, Validation R_squared:-0.1975
# Epoch [427/5000], Loss: 0.1513, R-squared: 0.4478,Validation_loss:0.1531, Validation R_squared:-0.1966
# Epoch [428/5000], Loss: 0.1512, R-squared: 0.4481,Validation_loss:0.1533, Validation R_squared:-0.1986
# Epoch [429/5000], Loss: 0.1512, R-squared: 0.4484,Validation_loss:0.1533, Validation R_squared:-0.1986
# Epoch [430/5000], Loss: 0.1511, R-squared: 0.4487,Validation_loss:0.1534, Validation R_squared:-0.2001
# Epoch [431/5000], Loss: 0.1510, R-squared: 0.4490,Validation_loss:0.1535, Validation R_squared:-0.2013
# Epoch [432/5000], Loss: 0.1509, R-squared: 0.4493,Validation_loss:0.1536, Validation R_squared:-0.2018
# Epoch [433/5000], Loss: 0.1509, R-squared: 0.4496,Validation_loss:0.1536, Validation R_squared:-0.2019
# Epoch [434/5000], Loss: 0.1508, R-squared: 0.4498,Validation_loss:0.1539, Validation R_squared:-0.2054
# Epoch [435/5000], Loss: 0.1507, R-squared: 0.4502,Validation_loss:0.1537, Validation R_squared:-0.2031
# Epoch [436/5000], Loss: 0.1507, R-squared: 0.4504,Validation_loss:0.1541, Validation R_squared:-0.2072
# Epoch [437/5000], Loss: 0.1506, R-squared: 0.4507,Validation_loss:0.1539, Validation R_squared:-0.2051
# Epoch [438/5000], Loss: 0.1505, R-squared: 0.4510,Validation_loss:0.1544, Validation R_squared:-0.2100
# Epoch [439/5000], Loss: 0.1504, R-squared: 0.4513,Validation_loss:0.1540, Validation R_squared:-0.2068
# Epoch [440/5000], Loss: 0.1504, R-squared: 0.4515,Validation_loss:0.1545, Validation R_squared:-0.2114
# Epoch [441/5000], Loss: 0.1503, R-squared: 0.4519,Validation_loss:0.1542, Validation R_squared:-0.2086
# Epoch [442/5000], Loss: 0.1502, R-squared: 0.4521,Validation_loss:0.1547, Validation R_squared:-0.2138
# Epoch [443/5000], Loss: 0.1502, R-squared: 0.4524,Validation_loss:0.1544, Validation R_squared:-0.2104
# Epoch [444/5000], Loss: 0.1501, R-squared: 0.4526,Validation_loss:0.1549, Validation R_squared:-0.2156
# Epoch [445/5000], Loss: 0.1500, R-squared: 0.4530,Validation_loss:0.1546, Validation R_squared:-0.2128
# Epoch [446/5000], Loss: 0.1499, R-squared: 0.4532,Validation_loss:0.1551, Validation R_squared:-0.2173
# Epoch [447/5000], Loss: 0.1499, R-squared: 0.4535,Validation_loss:0.1547, Validation R_squared:-0.2143
# Epoch [448/5000], Loss: 0.1498, R-squared: 0.4538,Validation_loss:0.1553, Validation R_squared:-0.2196
# Epoch [449/5000], Loss: 0.1497, R-squared: 0.4541,Validation_loss:0.1550, Validation R_squared:-0.2167
# Epoch [450/5000], Loss: 0.1497, R-squared: 0.4543,Validation_loss:0.1553, Validation R_squared:-0.2197
# Epoch [451/5000], Loss: 0.1496, R-squared: 0.4546,Validation_loss:0.1553, Validation R_squared:-0.2198
# Epoch [452/5000], Loss: 0.1495, R-squared: 0.4549,Validation_loss:0.1554, Validation R_squared:-0.2212
# Epoch [453/5000], Loss: 0.1495, R-squared: 0.4551,Validation_loss:0.1555, Validation R_squared:-0.2220
# Epoch [454/5000], Loss: 0.1494, R-squared: 0.4554,Validation_loss:0.1556, Validation R_squared:-0.2235
# Epoch [455/5000], Loss: 0.1493, R-squared: 0.4557,Validation_loss:0.1556, Validation R_squared:-0.2232
# Epoch [456/5000], Loss: 0.1492, R-squared: 0.4560,Validation_loss:0.1558, Validation R_squared:-0.2253
# Epoch [457/5000], Loss: 0.1492, R-squared: 0.4562,Validation_loss:0.1557, Validation R_squared:-0.2251
# Epoch [458/5000], Loss: 0.1491, R-squared: 0.4565,Validation_loss:0.1559, Validation R_squared:-0.2267
# Epoch [459/5000], Loss: 0.1490, R-squared: 0.4568,Validation_loss:0.1559, Validation R_squared:-0.2269
# Epoch [460/5000], Loss: 0.1490, R-squared: 0.4570,Validation_loss:0.1561, Validation R_squared:-0.2289
# Epoch [461/5000], Loss: 0.1489, R-squared: 0.4573,Validation_loss:0.1561, Validation R_squared:-0.2292
# Epoch [462/5000], Loss: 0.1488, R-squared: 0.4576,Validation_loss:0.1562, Validation R_squared:-0.2298
# Epoch [463/5000], Loss: 0.1488, R-squared: 0.4578,Validation_loss:0.1564, Validation R_squared:-0.2322
# Epoch [464/5000], Loss: 0.1487, R-squared: 0.4581,Validation_loss:0.1563, Validation R_squared:-0.2311
# Epoch [465/5000], Loss: 0.1486, R-squared: 0.4584,Validation_loss:0.1566, Validation R_squared:-0.2337
# Epoch [466/5000], Loss: 0.1486, R-squared: 0.4586,Validation_loss:0.1564, Validation R_squared:-0.2326
# Epoch [467/5000], Loss: 0.1485, R-squared: 0.4589,Validation_loss:0.1569, Validation R_squared:-0.2368
# Epoch [468/5000], Loss: 0.1484, R-squared: 0.4592,Validation_loss:0.1565, Validation R_squared:-0.2334
# ...
# Epoch [4848/5000], Loss: 0.0814, R-squared: 0.7165,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4849/5000], Loss: 0.0814, R-squared: 0.7165,Validation_loss:0.1855, Validation R_squared:-0.6068
# Epoch [4850/5000], Loss: 0.0814, R-squared: 0.7165,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4851/5000], Loss: 0.0814, R-squared: 0.7165,Validation_loss:0.1855, Validation R_squared:-0.6068
# Epoch [4852/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4853/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6067
# Epoch [4854/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4855/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4856/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4857/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4858/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6068
# Epoch [4859/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6070
# Epoch [4860/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4861/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4862/5000], Loss: 0.0814, R-squared: 0.7166,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4863/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4864/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4865/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6070
# Epoch [4866/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4867/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4868/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4869/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4870/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4871/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4872/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4873/5000], Loss: 0.0814, R-squared: 0.7167,Validation_loss:0.1855, Validation R_squared:-0.6069
# Epoch [4874/5000], Loss: 0.0814, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4875/5000], Loss: 0.0814, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6068
# Epoch [4876/5000], Loss: 0.0814, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4877/5000], Loss: 0.0814, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6070
# Epoch [4878/5000], Loss: 0.0814, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4879/5000], Loss: 0.0814, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4880/5000], Loss: 0.0813, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4881/5000], Loss: 0.0813, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6070
# Epoch [4882/5000], Loss: 0.0813, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4883/5000], Loss: 0.0813, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4884/5000], Loss: 0.0813, R-squared: 0.7168,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4885/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4886/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4887/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4888/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4889/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6070
# Epoch [4890/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4891/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4892/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4893/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4894/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4895/5000], Loss: 0.0813, R-squared: 0.7169,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4896/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4897/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4898/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4899/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4900/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4901/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4902/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4903/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4904/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1856, Validation R_squared:-0.6075
# Epoch [4905/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4906/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4907/5000], Loss: 0.0813, R-squared: 0.7170,Validation_loss:0.1855, Validation R_squared:-0.6072
# Epoch [4908/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4909/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1855, Validation R_squared:-0.6071
# Epoch [4910/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4911/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1855, Validation R_squared:-0.6073
# Epoch [4912/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4913/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4914/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4915/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4916/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4917/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4918/5000], Loss: 0.0813, R-squared: 0.7171,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4919/5000], Loss: 0.0813, R-squared: 0.7172,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4920/5000], Loss: 0.0813, R-squared: 0.7172,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4921/5000], Loss: 0.0813, R-squared: 0.7172,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4922/5000], Loss: 0.0812, R-squared: 0.7172,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4923/5000], Loss: 0.0812, R-squared: 0.7172,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4924/5000], Loss: 0.0812, R-squared: 0.7172,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4925/5000], Loss: 0.0812, R-squared: 0.7172,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4926/5000], Loss: 0.0812, R-squared: 0.7172,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4927/5000], Loss: 0.0812, R-squared: 0.7172,Validation_loss:0.1855, Validation R_squared:-0.6074
# Epoch [4928/5000], Loss: 0.0812, R-squared: 0.7172,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4929/5000], Loss: 0.0812, R-squared: 0.7172,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4930/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1855, Validation R_squared:-0.6076
# Epoch [4931/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4932/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4933/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4934/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4935/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1855, Validation R_squared:-0.6075
# Epoch [4936/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4937/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4938/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4939/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4940/5000], Loss: 0.0812, R-squared: 0.7173,Validation_loss:0.1856, Validation R_squared:-0.6079
# Epoch [4941/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4942/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4943/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4944/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4945/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4946/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4947/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6079
# Epoch [4948/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4949/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6079
# Epoch [4950/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4951/5000], Loss: 0.0812, R-squared: 0.7174,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4952/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6076
# Epoch [4953/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6080
# Epoch [4954/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4955/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6080
# Epoch [4956/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4957/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6080
# Epoch [4958/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6077
# Epoch [4959/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6079
# Epoch [4960/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4961/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4962/5000], Loss: 0.0812, R-squared: 0.7175,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4963/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6081
# Epoch [4964/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4965/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6081
# Epoch [4966/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4967/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6079
# Epoch [4968/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6080
# Epoch [4969/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6079
# Epoch [4970/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6081
# Epoch [4971/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6078
# Epoch [4972/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6080
# Epoch [4973/5000], Loss: 0.0811, R-squared: 0.7176,Validation_loss:0.1856, Validation R_squared:-0.6080
# Epoch [4974/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6081
# Epoch [4975/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6081
# Epoch [4976/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6080
# Epoch [4977/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4978/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6079
# Epoch [4979/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4980/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4981/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6080
# Epoch [4982/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4983/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4984/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4985/5000], Loss: 0.0811, R-squared: 0.7177,Validation_loss:0.1856, Validation R_squared:-0.6079
# Epoch [4986/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6083
# Epoch [4987/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6084
# Epoch [4988/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6081
# Epoch [4989/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6084
# Epoch [4990/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6081
# Epoch [4991/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6084
# Epoch [4992/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4993/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6084
# Epoch [4994/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4995/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6084
# Epoch [4996/5000], Loss: 0.0811, R-squared: 0.7178,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [4997/5000], Loss: 0.0811, R-squared: 0.7179,Validation_loss:0.1856, Validation R_squared:-0.6084
# Epoch [4998/5000], Loss: 0.0811, R-squared: 0.7179,Validation_loss:0.1856, Validation R_squared:-0.6084
# Epoch [4999/5000], Loss: 0.0811, R-squared: 0.7179,Validation_loss:0.1856, Validation R_squared:-0.6082
# Epoch [5000/5000], Loss: 0.0811, R-squared: 0.7179,Validation_loss:0.1856, Validation R_squared:-0.6084

# %% [markdown]
# ## Plots

# %%
# Create a scatter plot of actual vs. predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', label='Actual vs. Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.grid(True)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', label='Perfect Prediction')
plt.legend()

# Display the plot
plt.show()

# %%
# Create a plot for the loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(num_epochs), losses, label='Test', color='green')
plt.plot(range(num_epochs), val_losses, label='Validation', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.grid(True)

# Create a plot for R-squared
plt.subplot(1, 2, 2)
plt.plot(range(num_epochs), r2_values, label='Test', color='green')
plt.plot(range(num_epochs), r2_validation, label='Validation', color='orange')
plt.xlabel('Epoch')
plt.ylabel('R-squared')
plt.title('R-squared Over Epochs')
plt.legend()
plt.grid(True)

# Display Plot
plt.show()

# %% [markdown]
# ## Gradient

# %%
#extract grad
parameter_importance = model.fc1.weight.grad

# %%
# Convert the parameter_importance tensor to a NumPy array
parameter_importance_img = parameter_importance.detach().numpy()
# Normalize the values to [0, 1]
min_val = parameter_importance_img.min()
max_val = parameter_importance_img.max()

parameter_importance_img = (parameter_importance_img - min_val) / (max_val - min_val)
parameter_importance_img = np.floor(parameter_importance_img*255)

# %% [markdown]
# Display

# %%
# Create a heatmap
plt.figure(figsize=(10, 2))
plt.imshow(parameter_importance_img, cmap='viridis', aspect='auto')
plt.colorbar()
plt.title('Parameter Importance Heatmap')
plt.xlabel('Input Dimension')
plt.ylabel('Gradients')
plt.show()

# %%
data_row=0
# Plot heatmap
plt.figure(figsize=(10, 2))
plt.imshow(parameter_importance_img[0+data_row:3+data_row,:], cmap='viridis', aspect='auto')
plt.colorbar()
plt.title('Parameter Importance Heatmap')
plt.xlabel('Input Dimension')
plt.ylabel('Gradients')
plt.show()
