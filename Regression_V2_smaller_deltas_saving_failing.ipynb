# %% [markdown]
# <a href="https://colab.research.google.com/github/Justworkname/6367_project/blob/main/Regression_V2_smaller_deltas_saving_failing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression Model V2_smaller_deltas_testing_save_failed

# %% [markdown]
# ## Import

# %%
# !pip install -q torchinfo

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torch.optim as optim
from torchvision import datasets, transforms
from torchinfo import summary
import numpy as np
import pandas as pd
import os
from PIL import Image
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import torch.optim.lr_scheduler as lr_scheduler

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# this creates a link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# '10 19 2023 meeting.gslides'
# '6 16 2023 Meeting.gslides'
#  6367
#  6367_project
# '6367 Project presentation.gslides'
# '7 12 2023 meeting.gslides'
#  7340
# '8 17 2023 meeting.gslides'
# '8 30 2023 meeting.gslides'
# '9 06 2023 meeting - Bar chart 1.gsheet'
# '9 06 2023 meeting - Column chart 1 (1).gsheet'
# '9 06 2023 meeting - Column chart 1 (2).gsheet'
# '9 06 2023 meeting - Column chart 1.gsheet'
# '9 06 2023 meeting.gslides'
# '9 20 2023 meeting.gslides'
# '9 28 2023 meeting.gslides'
# 'AI in Breast Cancer in Medical Imaging.gslides'
#  AI_MB
#  AI_MB_3D
# 'Colab Notebooks'
#  customTF2
#  Data_Vision_Transformer
#  fakeImages
#  Grad_documents
# 'Invited Lecture 2.gdoc'
# 'Invited Lecture 5.gdoc'
# 'Invited lecture 6.gdoc'
# 'Invited Lecture 7.gdoc'
#  Invited_lecture_oct_10.gdoc
# 'Invited Lecture October 3rd.gdoc'
# 'Invited Lecture September 19th.gdoc'
# 'My Drive'
# 'Presentation Evaluation sep 19.gdoc'
# 'QE Key points.gdoc'
# 'Regression testing.gdoc'
# 'Regression testing multiple deltas.gdoc'
#  Seminar
#  Ultrasound_Images
#  Undergrad_documents
# 'Veterinary Clinic Tumor Estimation Conclusion.gslides'
# 'Wild Magic.gsheet'

# %% [markdown]
# ## Hyperparameters

# %%
num_epochs=5000
input_dim = 54
output_dim = 1
hidden_dim = 3721
dropout=0.01

# %% [markdown]
# ## Load

# %%
# Load the CSV file into a DataFrame
csv_file_path = '/content/gdrive/MyDrive/6367_project/data_v2.csv'
df = pd.read_csv(csv_file_path)
df.fillna(0,inplace=True)
df = df.loc[(df != 0).all(axis=1)] # filter if want

train_patients = ['3', '4', '5', '6', '8', '9','10', '11','13','14','16','19','20','21','23','25']
test_patients = ['6']

df['Patient #'] = df['Patient #'].astype(str)

df_train=df[df['Patient #'].isin(train_patients)]
df_test=df[df['Patient #'].isin(test_patients)]

# Convert to desired data shape
y_train = df_train['Delta Plq Area'] #change with desired prediction
X_train = df_train.drop(columns=['Delta Plq Area','Patient #','Total FU Plq Area','VHIVUS FU img ind','CC FU Area','CC FU Circum Cov.','CC FU max thick',
                     'NC FU Area','NC FU max thick','FI FU Area','FI FU Circum Cov.','FI FU max thick','FF FU Area','FF FU Circum Cov.','FF FU max thick',
                     'VHIVUS BL img ind','BL Pat FRS','BL Pat LDL','BL Pat FFR','BL Pat EEMV','BL Pat BMI','BL Pat BUR']) #data to exclude

y_test = df_test['Delta Plq Area'] #change with desired prediction
X_test = df_test.drop(columns=['Delta Plq Area','Patient #','Total FU Plq Area','VHIVUS FU img ind','CC FU Area','CC FU Circum Cov.','CC FU max thick',
                     'NC FU Area','NC FU max thick','FI FU Area','FI FU Circum Cov.','FI FU max thick','FF FU Area','FF FU Circum Cov.','FF FU max thick',
                     'VHIVUS BL img ind','BL Pat FRS','BL Pat LDL','BL Pat FFR','BL Pat EEMV','BL Pat BMI','BL Pat BUR'])

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.float32)
y_train = y_train.view(-1)
y_test = y_test.view(-1)

# %% [markdown]
# ## Model

# %%
class RegressionModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout):
        super(RegressionModel, self).__init__()

        # Define the layers
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, 100)
        self.relu = nn.ReLU()
        self.fc3 = nn.Linear(100, output_dim)
        #self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        # Forward pass
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        #x = self.dropout(x)
        x = self.fc3(x)
        return x

# %%
model = RegressionModel(input_dim, hidden_dim, output_dim,dropout)

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# RegressionModel                          --
# ├─Linear: 1-1                            204,655
# ├─ReLU: 1-2                              --
# ├─Linear: 1-3                            372,200
# ├─Linear: 1-4                            101
# =================================================================
# Total params: 576,956
# Trainable params: 576,956
# Non-trainable params: 0
# =================================================================

# %%
# Mean Squared Error loss
criterion = nn.SmoothL1Loss()
# Apply optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)
# Learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)

# %% [markdown]
# ## Training

# %%
# List for Loss and R squared
losses = []
val_losses = []
r2_values = []
r2_validation = []

# Training loop
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_train)
    outputs = outputs.squeeze(dim=1)

    # Compute the loss
    ## Could consider Huber Loss
    loss = criterion(outputs, y_train)

    # Backpropagation and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Learning rate annealing
    scheduler.step()

    # Calculate R-squared
    y_pred = outputs.detach().numpy()
    r2 = r2_score(y_train.numpy(), y_pred)

    # Store loss and R-squared values for this epoch
    losses.append(loss.item())
    r2_values.append(r2)

    # Testing predictions
    y_pred = model(X_test).detach().numpy()
    # Calculate R-squared accuracy on the test data
    r2_test = r2_score(y_test.numpy(), y_pred)
    r2_validation.append(r2_test)
    val_out = model(X_test)
    val_out = val_out.squeeze(dim=1)
    val_loss = criterion(val_out,y_test)
    val_losses.append(val_loss.item())

    print('Epoch [{}/{}], Loss: {:.4f}, R-squared: {:.4f},Validation_loss:{:,.4f}, Validation R_squared:{:,.4f}'.format(epoch+1, num_epochs, loss.item(), r2,val_loss.item(),r2_test))
# Out:
# Epoch [1/5000], Loss: 0.2720, R-squared: -0.0615,Validation_loss:0.1462, Validation R_squared:-0.9380
# Epoch [2/5000], Loss: 0.2665, R-squared: -0.0384,Validation_loss:0.1434, Validation R_squared:-0.9016
# Epoch [3/5000], Loss: 0.2620, R-squared: -0.0198,Validation_loss:0.1415, Validation R_squared:-0.8777
# Epoch [4/5000], Loss: 0.2584, R-squared: -0.0045,Validation_loss:0.1404, Validation R_squared:-0.8630
# Epoch [5/5000], Loss: 0.2553, R-squared: 0.0083,Validation_loss:0.1396, Validation R_squared:-0.8547
# Epoch [6/5000], Loss: 0.2528, R-squared: 0.0190,Validation_loss:0.1393, Validation R_squared:-0.8516
# Epoch [7/5000], Loss: 0.2506, R-squared: 0.0280,Validation_loss:0.1391, Validation R_squared:-0.8514
# Epoch [8/5000], Loss: 0.2488, R-squared: 0.0356,Validation_loss:0.1392, Validation R_squared:-0.8537
# Epoch [9/5000], Loss: 0.2472, R-squared: 0.0422,Validation_loss:0.1393, Validation R_squared:-0.8573
# Epoch [10/5000], Loss: 0.2459, R-squared: 0.0479,Validation_loss:0.1397, Validation R_squared:-0.8632
# Epoch [11/5000], Loss: 0.2446, R-squared: 0.0530,Validation_loss:0.1400, Validation R_squared:-0.8696
# Epoch [12/5000], Loss: 0.2436, R-squared: 0.0574,Validation_loss:0.1404, Validation R_squared:-0.8759
# Epoch [13/5000], Loss: 0.2426, R-squared: 0.0614,Validation_loss:0.1407, Validation R_squared:-0.8819
# Epoch [14/5000], Loss: 0.2418, R-squared: 0.0650,Validation_loss:0.1411, Validation R_squared:-0.8879
# Epoch [15/5000], Loss: 0.2409, R-squared: 0.0684,Validation_loss:0.1414, Validation R_squared:-0.8926
# Epoch [16/5000], Loss: 0.2402, R-squared: 0.0715,Validation_loss:0.1416, Validation R_squared:-0.8974
# Epoch [17/5000], Loss: 0.2395, R-squared: 0.0745,Validation_loss:0.1419, Validation R_squared:-0.9019
# Epoch [18/5000], Loss: 0.2388, R-squared: 0.0773,Validation_loss:0.1421, Validation R_squared:-0.9057
# Epoch [19/5000], Loss: 0.2382, R-squared: 0.0800,Validation_loss:0.1424, Validation R_squared:-0.9097
# Epoch [20/5000], Loss: 0.2375, R-squared: 0.0825,Validation_loss:0.1425, Validation R_squared:-0.9130
# Epoch [21/5000], Loss: 0.2369, R-squared: 0.0850,Validation_loss:0.1427, Validation R_squared:-0.9156
# Epoch [22/5000], Loss: 0.2364, R-squared: 0.0875,Validation_loss:0.1428, Validation R_squared:-0.9172
# Epoch [23/5000], Loss: 0.2358, R-squared: 0.0898,Validation_loss:0.1428, Validation R_squared:-0.9183
# Epoch [24/5000], Loss: 0.2353, R-squared: 0.0920,Validation_loss:0.1429, Validation R_squared:-0.9197
# Epoch [25/5000], Loss: 0.2347, R-squared: 0.0943,Validation_loss:0.1429, Validation R_squared:-0.9207
# Epoch [26/5000], Loss: 0.2342, R-squared: 0.0964,Validation_loss:0.1429, Validation R_squared:-0.9209
# Epoch [27/5000], Loss: 0.2337, R-squared: 0.0985,Validation_loss:0.1428, Validation R_squared:-0.9206
# Epoch [28/5000], Loss: 0.2332, R-squared: 0.1006,Validation_loss:0.1428, Validation R_squared:-0.9199
# Epoch [29/5000], Loss: 0.2327, R-squared: 0.1026,Validation_loss:0.1427, Validation R_squared:-0.9189
# Epoch [30/5000], Loss: 0.2323, R-squared: 0.1045,Validation_loss:0.1426, Validation R_squared:-0.9176
# Epoch [31/5000], Loss: 0.2318, R-squared: 0.1064,Validation_loss:0.1424, Validation R_squared:-0.9158
# Epoch [32/5000], Loss: 0.2314, R-squared: 0.1082,Validation_loss:0.1422, Validation R_squared:-0.9137
# Epoch [33/5000], Loss: 0.2309, R-squared: 0.1101,Validation_loss:0.1420, Validation R_squared:-0.9103
# Epoch [34/5000], Loss: 0.2305, R-squared: 0.1119,Validation_loss:0.1417, Validation R_squared:-0.9066
# Epoch [35/5000], Loss: 0.2301, R-squared: 0.1137,Validation_loss:0.1414, Validation R_squared:-0.9024
# Epoch [36/5000], Loss: 0.2296, R-squared: 0.1155,Validation_loss:0.1411, Validation R_squared:-0.8987
# Epoch [37/5000], Loss: 0.2292, R-squared: 0.1173,Validation_loss:0.1408, Validation R_squared:-0.8948
# Epoch [38/5000], Loss: 0.2288, R-squared: 0.1191,Validation_loss:0.1405, Validation R_squared:-0.8906
# Epoch [39/5000], Loss: 0.2283, R-squared: 0.1208,Validation_loss:0.1402, Validation R_squared:-0.8864
# Epoch [40/5000], Loss: 0.2279, R-squared: 0.1226,Validation_loss:0.1399, Validation R_squared:-0.8824
# Epoch [41/5000], Loss: 0.2275, R-squared: 0.1243,Validation_loss:0.1396, Validation R_squared:-0.8784
# Epoch [42/5000], Loss: 0.2271, R-squared: 0.1260,Validation_loss:0.1393, Validation R_squared:-0.8734
# Epoch [43/5000], Loss: 0.2267, R-squared: 0.1277,Validation_loss:0.1389, Validation R_squared:-0.8685
# Epoch [44/5000], Loss: 0.2263, R-squared: 0.1294,Validation_loss:0.1386, Validation R_squared:-0.8637
# Epoch [45/5000], Loss: 0.2259, R-squared: 0.1310,Validation_loss:0.1382, Validation R_squared:-0.8588
# Epoch [46/5000], Loss: 0.2255, R-squared: 0.1326,Validation_loss:0.1378, Validation R_squared:-0.8532
# Epoch [47/5000], Loss: 0.2251, R-squared: 0.1343,Validation_loss:0.1374, Validation R_squared:-0.8478
# Epoch [48/5000], Loss: 0.2248, R-squared: 0.1359,Validation_loss:0.1370, Validation R_squared:-0.8423
# Epoch [49/5000], Loss: 0.2244, R-squared: 0.1374,Validation_loss:0.1366, Validation R_squared:-0.8368
# Epoch [50/5000], Loss: 0.2240, R-squared: 0.1390,Validation_loss:0.1362, Validation R_squared:-0.8308
# Epoch [51/5000], Loss: 0.2236, R-squared: 0.1405,Validation_loss:0.1358, Validation R_squared:-0.8248
# Epoch [52/5000], Loss: 0.2233, R-squared: 0.1421,Validation_loss:0.1353, Validation R_squared:-0.8181
# Epoch [53/5000], Loss: 0.2229, R-squared: 0.1436,Validation_loss:0.1348, Validation R_squared:-0.8114
# Epoch [54/5000], Loss: 0.2225, R-squared: 0.1451,Validation_loss:0.1343, Validation R_squared:-0.8044
# Epoch [55/5000], Loss: 0.2222, R-squared: 0.1466,Validation_loss:0.1338, Validation R_squared:-0.7974
# Epoch [56/5000], Loss: 0.2218, R-squared: 0.1481,Validation_loss:0.1333, Validation R_squared:-0.7900
# Epoch [57/5000], Loss: 0.2215, R-squared: 0.1496,Validation_loss:0.1328, Validation R_squared:-0.7826
# Epoch [58/5000], Loss: 0.2211, R-squared: 0.1511,Validation_loss:0.1323, Validation R_squared:-0.7757
# Epoch [59/5000], Loss: 0.2207, R-squared: 0.1526,Validation_loss:0.1318, Validation R_squared:-0.7682
# Epoch [60/5000], Loss: 0.2204, R-squared: 0.1540,Validation_loss:0.1313, Validation R_squared:-0.7612
# Epoch [61/5000], Loss: 0.2200, R-squared: 0.1555,Validation_loss:0.1307, Validation R_squared:-0.7534
# Epoch [62/5000], Loss: 0.2197, R-squared: 0.1570,Validation_loss:0.1302, Validation R_squared:-0.7463
# Epoch [63/5000], Loss: 0.2193, R-squared: 0.1584,Validation_loss:0.1297, Validation R_squared:-0.7383
# Epoch [64/5000], Loss: 0.2190, R-squared: 0.1599,Validation_loss:0.1291, Validation R_squared:-0.7310
# Epoch [65/5000], Loss: 0.2186, R-squared: 0.1613,Validation_loss:0.1287, Validation R_squared:-0.7240
# Epoch [66/5000], Loss: 0.2183, R-squared: 0.1628,Validation_loss:0.1282, Validation R_squared:-0.7172
# Epoch [67/5000], Loss: 0.2179, R-squared: 0.1642,Validation_loss:0.1277, Validation R_squared:-0.7101
# Epoch [68/5000], Loss: 0.2176, R-squared: 0.1657,Validation_loss:0.1272, Validation R_squared:-0.7030
# Epoch [69/5000], Loss: 0.2172, R-squared: 0.1671,Validation_loss:0.1267, Validation R_squared:-0.6962
# Epoch [70/5000], Loss: 0.2169, R-squared: 0.1685,Validation_loss:0.1262, Validation R_squared:-0.6889
# Epoch [71/5000], Loss: 0.2166, R-squared: 0.1699,Validation_loss:0.1256, Validation R_squared:-0.6814
# Epoch [72/5000], Loss: 0.2162, R-squared: 0.1714,Validation_loss:0.1251, Validation R_squared:-0.6735
# Epoch [73/5000], Loss: 0.2159, R-squared: 0.1728,Validation_loss:0.1246, Validation R_squared:-0.6664
# Epoch [74/5000], Loss: 0.2155, R-squared: 0.1742,Validation_loss:0.1240, Validation R_squared:-0.6588
# Epoch [75/5000], Loss: 0.2152, R-squared: 0.1756,Validation_loss:0.1235, Validation R_squared:-0.6516
# Epoch [76/5000], Loss: 0.2149, R-squared: 0.1770,Validation_loss:0.1230, Validation R_squared:-0.6442
# Epoch [77/5000], Loss: 0.2145, R-squared: 0.1784,Validation_loss:0.1225, Validation R_squared:-0.6371
# Epoch [78/5000], Loss: 0.2142, R-squared: 0.1798,Validation_loss:0.1220, Validation R_squared:-0.6293
# Epoch [79/5000], Loss: 0.2139, R-squared: 0.1812,Validation_loss:0.1214, Validation R_squared:-0.6218
# Epoch [80/5000], Loss: 0.2135, R-squared: 0.1826,Validation_loss:0.1208, Validation R_squared:-0.6127
# Epoch [81/5000], Loss: 0.2132, R-squared: 0.1839,Validation_loss:0.1202, Validation R_squared:-0.6049
# Epoch [82/5000], Loss: 0.2129, R-squared: 0.1853,Validation_loss:0.1197, Validation R_squared:-0.5969
# Epoch [83/5000], Loss: 0.2125, R-squared: 0.1867,Validation_loss:0.1191, Validation R_squared:-0.5892
# Epoch [84/5000], Loss: 0.2122, R-squared: 0.1880,Validation_loss:0.1186, Validation R_squared:-0.5815
# Epoch [85/5000], Loss: 0.2119, R-squared: 0.1894,Validation_loss:0.1180, Validation R_squared:-0.5737
# Epoch [86/5000], Loss: 0.2115, R-squared: 0.1908,Validation_loss:0.1175, Validation R_squared:-0.5658
# Epoch [87/5000], Loss: 0.2112, R-squared: 0.1921,Validation_loss:0.1169, Validation R_squared:-0.5581
# Epoch [88/5000], Loss: 0.2109, R-squared: 0.1935,Validation_loss:0.1163, Validation R_squared:-0.5500
# Epoch [89/5000], Loss: 0.2106, R-squared: 0.1948,Validation_loss:0.1158, Validation R_squared:-0.5419
# Epoch [90/5000], Loss: 0.2102, R-squared: 0.1961,Validation_loss:0.1152, Validation R_squared:-0.5340
# Epoch [91/5000], Loss: 0.2099, R-squared: 0.1974,Validation_loss:0.1147, Validation R_squared:-0.5268
# Epoch [92/5000], Loss: 0.2096, R-squared: 0.1988,Validation_loss:0.1141, Validation R_squared:-0.5189
# Epoch [93/5000], Loss: 0.2093, R-squared: 0.2001,Validation_loss:0.1136, Validation R_squared:-0.5116
# Epoch [94/5000], Loss: 0.2090, R-squared: 0.2014,Validation_loss:0.1130, Validation R_squared:-0.5038
# Epoch [95/5000], Loss: 0.2087, R-squared: 0.2027,Validation_loss:0.1125, Validation R_squared:-0.4964
# Epoch [96/5000], Loss: 0.2083, R-squared: 0.2040,Validation_loss:0.1119, Validation R_squared:-0.4877
# Epoch [97/5000], Loss: 0.2080, R-squared: 0.2054,Validation_loss:0.1113, Validation R_squared:-0.4798
# Epoch [98/5000], Loss: 0.2077, R-squared: 0.2067,Validation_loss:0.1107, Validation R_squared:-0.4709
# Epoch [99/5000], Loss: 0.2074, R-squared: 0.2080,Validation_loss:0.1101, Validation R_squared:-0.4631
# Epoch [100/5000], Loss: 0.2071, R-squared: 0.2093,Validation_loss:0.1095, Validation R_squared:-0.4547
# Epoch [101/5000], Loss: 0.2068, R-squared: 0.2106,Validation_loss:0.1090, Validation R_squared:-0.4468
# Epoch [102/5000], Loss: 0.2064, R-squared: 0.2119,Validation_loss:0.1084, Validation R_squared:-0.4390
# Epoch [103/5000], Loss: 0.2061, R-squared: 0.2132,Validation_loss:0.1078, Validation R_squared:-0.4312
# Epoch [104/5000], Loss: 0.2058, R-squared: 0.2144,Validation_loss:0.1073, Validation R_squared:-0.4239
# Epoch [105/5000], Loss: 0.2055, R-squared: 0.2157,Validation_loss:0.1067, Validation R_squared:-0.4162
# Epoch [106/5000], Loss: 0.2052, R-squared: 0.2170,Validation_loss:0.1062, Validation R_squared:-0.4088
# Epoch [107/5000], Loss: 0.2049, R-squared: 0.2183,Validation_loss:0.1056, Validation R_squared:-0.4007
# Epoch [108/5000], Loss: 0.2046, R-squared: 0.2196,Validation_loss:0.1051, Validation R_squared:-0.3936
# Epoch [109/5000], Loss: 0.2043, R-squared: 0.2208,Validation_loss:0.1045, Validation R_squared:-0.3859
# Epoch [110/5000], Loss: 0.2040, R-squared: 0.2221,Validation_loss:0.1040, Validation R_squared:-0.3787
# Epoch [111/5000], Loss: 0.2037, R-squared: 0.2233,Validation_loss:0.1035, Validation R_squared:-0.3711
# Epoch [112/5000], Loss: 0.2034, R-squared: 0.2246,Validation_loss:0.1029, Validation R_squared:-0.3635
# Epoch [113/5000], Loss: 0.2031, R-squared: 0.2259,Validation_loss:0.1024, Validation R_squared:-0.3563
# Epoch [114/5000], Loss: 0.2028, R-squared: 0.2271,Validation_loss:0.1019, Validation R_squared:-0.3492
# Epoch [115/5000], Loss: 0.2025, R-squared: 0.2284,Validation_loss:0.1014, Validation R_squared:-0.3419
# Epoch [116/5000], Loss: 0.2022, R-squared: 0.2296,Validation_loss:0.1008, Validation R_squared:-0.3347
# Epoch [117/5000], Loss: 0.2019, R-squared: 0.2308,Validation_loss:0.1003, Validation R_squared:-0.3275
# Epoch [118/5000], Loss: 0.2016, R-squared: 0.2321,Validation_loss:0.0998, Validation R_squared:-0.3207
# Epoch [119/5000], Loss: 0.2013, R-squared: 0.2333,Validation_loss:0.0993, Validation R_squared:-0.3138
# Epoch [120/5000], Loss: 0.2010, R-squared: 0.2345,Validation_loss:0.0988, Validation R_squared:-0.3066
# Epoch [121/5000], Loss: 0.2007, R-squared: 0.2357,Validation_loss:0.0983, Validation R_squared:-0.2996
# Epoch [122/5000], Loss: 0.2004, R-squared: 0.2370,Validation_loss:0.0978, Validation R_squared:-0.2927
# Epoch [123/5000], Loss: 0.2001, R-squared: 0.2382,Validation_loss:0.0973, Validation R_squared:-0.2857
# Epoch [124/5000], Loss: 0.1998, R-squared: 0.2394,Validation_loss:0.0968, Validation R_squared:-0.2789
# Epoch [125/5000], Loss: 0.1995, R-squared: 0.2406,Validation_loss:0.0963, Validation R_squared:-0.2722
# Epoch [126/5000], Loss: 0.1992, R-squared: 0.2418,Validation_loss:0.0958, Validation R_squared:-0.2657
# Epoch [127/5000], Loss: 0.1989, R-squared: 0.2430,Validation_loss:0.0953, Validation R_squared:-0.2591
# Epoch [128/5000], Loss: 0.1986, R-squared: 0.2442,Validation_loss:0.0949, Validation R_squared:-0.2530
# Epoch [129/5000], Loss: 0.1983, R-squared: 0.2454,Validation_loss:0.0944, Validation R_squared:-0.2469
# Epoch [130/5000], Loss: 0.1980, R-squared: 0.2466,Validation_loss:0.0940, Validation R_squared:-0.2405
# Epoch [131/5000], Loss: 0.1977, R-squared: 0.2478,Validation_loss:0.0935, Validation R_squared:-0.2339
# Epoch [132/5000], Loss: 0.1975, R-squared: 0.2490,Validation_loss:0.0930, Validation R_squared:-0.2279
# Epoch [133/5000], Loss: 0.1972, R-squared: 0.2502,Validation_loss:0.0926, Validation R_squared:-0.2217
# Epoch [134/5000], Loss: 0.1969, R-squared: 0.2514,Validation_loss:0.0921, Validation R_squared:-0.2155
# Epoch [135/5000], Loss: 0.1966, R-squared: 0.2526,Validation_loss:0.0917, Validation R_squared:-0.2097
# Epoch [136/5000], Loss: 0.1963, R-squared: 0.2537,Validation_loss:0.0912, Validation R_squared:-0.2035
# Epoch [137/5000], Loss: 0.1960, R-squared: 0.2549,Validation_loss:0.0908, Validation R_squared:-0.1976
# Epoch [138/5000], Loss: 0.1957, R-squared: 0.2561,Validation_loss:0.0904, Validation R_squared:-0.1919
# Epoch [139/5000], Loss: 0.1955, R-squared: 0.2573,Validation_loss:0.0899, Validation R_squared:-0.1857
# Epoch [140/5000], Loss: 0.1952, R-squared: 0.2584,Validation_loss:0.0895, Validation R_squared:-0.1800
# Epoch [141/5000], Loss: 0.1949, R-squared: 0.2596,Validation_loss:0.0891, Validation R_squared:-0.1742
# Epoch [142/5000], Loss: 0.1946, R-squared: 0.2607,Validation_loss:0.0886, Validation R_squared:-0.1683
# Epoch [143/5000], Loss: 0.1943, R-squared: 0.2619,Validation_loss:0.0882, Validation R_squared:-0.1628
# Epoch [144/5000], Loss: 0.1940, R-squared: 0.2630,Validation_loss:0.0878, Validation R_squared:-0.1571
# Epoch [145/5000], Loss: 0.1938, R-squared: 0.2642,Validation_loss:0.0874, Validation R_squared:-0.1513
# Epoch [146/5000], Loss: 0.1935, R-squared: 0.2653,Validation_loss:0.0870, Validation R_squared:-0.1453
# Epoch [147/5000], Loss: 0.1932, R-squared: 0.2665,Validation_loss:0.0865, Validation R_squared:-0.1397
# Epoch [148/5000], Loss: 0.1929, R-squared: 0.2676,Validation_loss:0.0861, Validation R_squared:-0.1341
# Epoch [149/5000], Loss: 0.1927, R-squared: 0.2687,Validation_loss:0.0857, Validation R_squared:-0.1285
# Epoch [150/5000], Loss: 0.1924, R-squared: 0.2699,Validation_loss:0.0853, Validation R_squared:-0.1229
# Epoch [151/5000], Loss: 0.1921, R-squared: 0.2710,Validation_loss:0.0849, Validation R_squared:-0.1175
# Epoch [152/5000], Loss: 0.1918, R-squared: 0.2721,Validation_loss:0.0845, Validation R_squared:-0.1120
# Epoch [153/5000], Loss: 0.1916, R-squared: 0.2732,Validation_loss:0.0841, Validation R_squared:-0.1067
# Epoch [154/5000], Loss: 0.1913, R-squared: 0.2743,Validation_loss:0.0837, Validation R_squared:-0.1009
# Epoch [155/5000], Loss: 0.1910, R-squared: 0.2754,Validation_loss:0.0833, Validation R_squared:-0.0956
# Epoch [156/5000], Loss: 0.1908, R-squared: 0.2765,Validation_loss:0.0829, Validation R_squared:-0.0900
# Epoch [157/5000], Loss: 0.1905, R-squared: 0.2776,Validation_loss:0.0825, Validation R_squared:-0.0847
# Epoch [158/5000], Loss: 0.1902, R-squared: 0.2787,Validation_loss:0.0820, Validation R_squared:-0.0789
# Epoch [159/5000], Loss: 0.1900, R-squared: 0.2798,Validation_loss:0.0817, Validation R_squared:-0.0738
# Epoch [160/5000], Loss: 0.1897, R-squared: 0.2809,Validation_loss:0.0813, Validation R_squared:-0.0685
# Epoch [161/5000], Loss: 0.1894, R-squared: 0.2820,Validation_loss:0.0809, Validation R_squared:-0.0633
# Epoch [162/5000], Loss: 0.1892, R-squared: 0.2830,Validation_loss:0.0804, Validation R_squared:-0.0574
# Epoch [163/5000], Loss: 0.1889, R-squared: 0.2841,Validation_loss:0.0800, Validation R_squared:-0.0520
# Epoch [164/5000], Loss: 0.1886, R-squared: 0.2851,Validation_loss:0.0797, Validation R_squared:-0.0473
# Epoch [165/5000], Loss: 0.1884, R-squared: 0.2862,Validation_loss:0.0793, Validation R_squared:-0.0422
# Epoch [166/5000], Loss: 0.1881, R-squared: 0.2872,Validation_loss:0.0789, Validation R_squared:-0.0373
# Epoch [167/5000], Loss: 0.1879, R-squared: 0.2883,Validation_loss:0.0786, Validation R_squared:-0.0326
# Epoch [168/5000], Loss: 0.1876, R-squared: 0.2893,Validation_loss:0.0782, Validation R_squared:-0.0273
# Epoch [169/5000], Loss: 0.1874, R-squared: 0.2904,Validation_loss:0.0779, Validation R_squared:-0.0229
# Epoch [170/5000], Loss: 0.1871, R-squared: 0.2914,Validation_loss:0.0775, Validation R_squared:-0.0179
# Epoch [171/5000], Loss: 0.1869, R-squared: 0.2924,Validation_loss:0.0771, Validation R_squared:-0.0129
# Epoch [172/5000], Loss: 0.1866, R-squared: 0.2935,Validation_loss:0.0768, Validation R_squared:-0.0082
# Epoch [173/5000], Loss: 0.1864, R-squared: 0.2945,Validation_loss:0.0764, Validation R_squared:-0.0034
# Epoch [174/5000], Loss: 0.1861, R-squared: 0.2955,Validation_loss:0.0761, Validation R_squared:0.0011
# Epoch [175/5000], Loss: 0.1859, R-squared: 0.2965,Validation_loss:0.0757, Validation R_squared:0.0058
# Epoch [176/5000], Loss: 0.1856, R-squared: 0.2975,Validation_loss:0.0754, Validation R_squared:0.0102
# Epoch [177/5000], Loss: 0.1854, R-squared: 0.2985,Validation_loss:0.0750, Validation R_squared:0.0149
# Epoch [178/5000], Loss: 0.1851, R-squared: 0.2995,Validation_loss:0.0747, Validation R_squared:0.0198
# Epoch [179/5000], Loss: 0.1849, R-squared: 0.3005,Validation_loss:0.0743, Validation R_squared:0.0245
# Epoch [180/5000], Loss: 0.1847, R-squared: 0.3015,Validation_loss:0.0740, Validation R_squared:0.0289
# Epoch [181/5000], Loss: 0.1844, R-squared: 0.3025,Validation_loss:0.0736, Validation R_squared:0.0338
# Epoch [182/5000], Loss: 0.1842, R-squared: 0.3034,Validation_loss:0.0733, Validation R_squared:0.0384
# Epoch [183/5000], Loss: 0.1839, R-squared: 0.3044,Validation_loss:0.0729, Validation R_squared:0.0428
# Epoch [184/5000], Loss: 0.1837, R-squared: 0.3054,Validation_loss:0.0726, Validation R_squared:0.0476
# Epoch [185/5000], Loss: 0.1835, R-squared: 0.3064,Validation_loss:0.0723, Validation R_squared:0.0517
# Epoch [186/5000], Loss: 0.1832, R-squared: 0.3073,Validation_loss:0.0719, Validation R_squared:0.0565
# Epoch [187/5000], Loss: 0.1830, R-squared: 0.3083,Validation_loss:0.0716, Validation R_squared:0.0603
# Epoch [188/5000], Loss: 0.1828, R-squared: 0.3092,Validation_loss:0.0712, Validation R_squared:0.0650
# Epoch [189/5000], Loss: 0.1825, R-squared: 0.3102,Validation_loss:0.0709, Validation R_squared:0.0692
# Epoch [190/5000], Loss: 0.1823, R-squared: 0.3111,Validation_loss:0.0706, Validation R_squared:0.0736
# Epoch [191/5000], Loss: 0.1821, R-squared: 0.3121,Validation_loss:0.0703, Validation R_squared:0.0778
# Epoch [192/5000], Loss: 0.1819, R-squared: 0.3130,Validation_loss:0.0700, Validation R_squared:0.0820
# Epoch [193/5000], Loss: 0.1816, R-squared: 0.3139,Validation_loss:0.0697, Validation R_squared:0.0860
# Epoch [194/5000], Loss: 0.1814, R-squared: 0.3149,Validation_loss:0.0693, Validation R_squared:0.0903
# Epoch [195/5000], Loss: 0.1812, R-squared: 0.3158,Validation_loss:0.0690, Validation R_squared:0.0940
# Epoch [196/5000], Loss: 0.1809, R-squared: 0.3167,Validation_loss:0.0687, Validation R_squared:0.0982
# Epoch [197/5000], Loss: 0.1807, R-squared: 0.3176,Validation_loss:0.0684, Validation R_squared:0.1021
# Epoch [198/5000], Loss: 0.1805, R-squared: 0.3186,Validation_loss:0.0681, Validation R_squared:0.1061
# Epoch [199/5000], Loss: 0.1803, R-squared: 0.3195,Validation_loss:0.0678, Validation R_squared:0.1097
# Epoch [200/5000], Loss: 0.1801, R-squared: 0.3204,Validation_loss:0.0675, Validation R_squared:0.1139
# Epoch [201/5000], Loss: 0.1798, R-squared: 0.3213,Validation_loss:0.0672, Validation R_squared:0.1177
# Epoch [202/5000], Loss: 0.1796, R-squared: 0.3222,Validation_loss:0.0669, Validation R_squared:0.1222
# Epoch [203/5000], Loss: 0.1794, R-squared: 0.3230,Validation_loss:0.0666, Validation R_squared:0.1255
# Epoch [204/5000], Loss: 0.1792, R-squared: 0.3239,Validation_loss:0.0664, Validation R_squared:0.1293
# Epoch [205/5000], Loss: 0.1790, R-squared: 0.3248,Validation_loss:0.0661, Validation R_squared:0.1325
# Epoch [206/5000], Loss: 0.1788, R-squared: 0.3257,Validation_loss:0.0658, Validation R_squared:0.1365
# Epoch [207/5000], Loss: 0.1786, R-squared: 0.3266,Validation_loss:0.0655, Validation R_squared:0.1400
# Epoch [208/5000], Loss: 0.1783, R-squared: 0.3274,Validation_loss:0.0653, Validation R_squared:0.1438
# Epoch [209/5000], Loss: 0.1781, R-squared: 0.3283,Validation_loss:0.0650, Validation R_squared:0.1472
# Epoch [210/5000], Loss: 0.1779, R-squared: 0.3292,Validation_loss:0.0647, Validation R_squared:0.1511
# Epoch [211/5000], Loss: 0.1777, R-squared: 0.3300,Validation_loss:0.0644, Validation R_squared:0.1544
# Epoch [212/5000], Loss: 0.1775, R-squared: 0.3309,Validation_loss:0.0642, Validation R_squared:0.1576
# Epoch [213/5000], Loss: 0.1773, R-squared: 0.3317,Validation_loss:0.0639, Validation R_squared:0.1611
# Epoch [214/5000], Loss: 0.1771, R-squared: 0.3326,Validation_loss:0.0636, Validation R_squared:0.1649
# Epoch [215/5000], Loss: 0.1769, R-squared: 0.3334,Validation_loss:0.0634, Validation R_squared:0.1682
# Epoch [216/5000], Loss: 0.1767, R-squared: 0.3343,Validation_loss:0.0631, Validation R_squared:0.1717
# Epoch [217/5000], Loss: 0.1765, R-squared: 0.3351,Validation_loss:0.0629, Validation R_squared:0.1751
# Epoch [218/5000], Loss: 0.1763, R-squared: 0.3359,Validation_loss:0.0626, Validation R_squared:0.1786
# Epoch [219/5000], Loss: 0.1761, R-squared: 0.3367,Validation_loss:0.0623, Validation R_squared:0.1819
# Epoch [220/5000], Loss: 0.1759, R-squared: 0.3376,Validation_loss:0.0621, Validation R_squared:0.1852
# Epoch [221/5000], Loss: 0.1757, R-squared: 0.3384,Validation_loss:0.0619, Validation R_squared:0.1882
# Epoch [222/5000], Loss: 0.1755, R-squared: 0.3392,Validation_loss:0.0616, Validation R_squared:0.1917
# Epoch [223/5000], Loss: 0.1753, R-squared: 0.3400,Validation_loss:0.0614, Validation R_squared:0.1947
# Epoch [224/5000], Loss: 0.1751, R-squared: 0.3408,Validation_loss:0.0611, Validation R_squared:0.1978
# Epoch [225/5000], Loss: 0.1749, R-squared: 0.3416,Validation_loss:0.0609, Validation R_squared:0.2013
# Epoch [226/5000], Loss: 0.1747, R-squared: 0.3424,Validation_loss:0.0607, Validation R_squared:0.2038
# Epoch [227/5000], Loss: 0.1745, R-squared: 0.3432,Validation_loss:0.0604, Validation R_squared:0.2069
# Epoch [228/5000], Loss: 0.1743, R-squared: 0.3440,Validation_loss:0.0602, Validation R_squared:0.2098
# Epoch [229/5000], Loss: 0.1741, R-squared: 0.3447,Validation_loss:0.0600, Validation R_squared:0.2127
# Epoch [230/5000], Loss: 0.1739, R-squared: 0.3455,Validation_loss:0.0598, Validation R_squared:0.2159
# Epoch [231/5000], Loss: 0.1737, R-squared: 0.3463,Validation_loss:0.0595, Validation R_squared:0.2188
# Epoch [232/5000], Loss: 0.1736, R-squared: 0.3470,Validation_loss:0.0593, Validation R_squared:0.2220
# Epoch [233/5000], Loss: 0.1734, R-squared: 0.3478,Validation_loss:0.0591, Validation R_squared:0.2248
# Epoch [234/5000], Loss: 0.1732, R-squared: 0.3486,Validation_loss:0.0589, Validation R_squared:0.2276
# Epoch [235/5000], Loss: 0.1730, R-squared: 0.3493,Validation_loss:0.0586, Validation R_squared:0.2308
# Epoch [236/5000], Loss: 0.1728, R-squared: 0.3501,Validation_loss:0.0584, Validation R_squared:0.2335
# Epoch [237/5000], Loss: 0.1726, R-squared: 0.3508,Validation_loss:0.0582, Validation R_squared:0.2364
# Epoch [238/5000], Loss: 0.1725, R-squared: 0.3516,Validation_loss:0.0580, Validation R_squared:0.2389
# Epoch [239/5000], Loss: 0.1723, R-squared: 0.3523,Validation_loss:0.0578, Validation R_squared:0.2420
# Epoch [240/5000], Loss: 0.1721, R-squared: 0.3530,Validation_loss:0.0576, Validation R_squared:0.2446
# Epoch [241/5000], Loss: 0.1719, R-squared: 0.3538,Validation_loss:0.0574, Validation R_squared:0.2473
# Epoch [242/5000], Loss: 0.1717, R-squared: 0.3545,Validation_loss:0.0572, Validation R_squared:0.2497
# Epoch [243/5000], Loss: 0.1716, R-squared: 0.3552,Validation_loss:0.0570, Validation R_squared:0.2524
# Epoch [244/5000], Loss: 0.1714, R-squared: 0.3559,Validation_loss:0.0568, Validation R_squared:0.2548
# Epoch [245/5000], Loss: 0.1712, R-squared: 0.3566,Validation_loss:0.0566, Validation R_squared:0.2576
# Epoch [246/5000], Loss: 0.1710, R-squared: 0.3573,Validation_loss:0.0564, Validation R_squared:0.2602
# Epoch [247/5000], Loss: 0.1709, R-squared: 0.3581,Validation_loss:0.0562, Validation R_squared:0.2625
# Epoch [248/5000], Loss: 0.1707, R-squared: 0.3588,Validation_loss:0.0560, Validation R_squared:0.2652
# Epoch [249/5000], Loss: 0.1705, R-squared: 0.3595,Validation_loss:0.0558, Validation R_squared:0.2677
# Epoch [250/5000], Loss: 0.1704, R-squared: 0.3601,Validation_loss:0.0556, Validation R_squared:0.2704
# Epoch [251/5000], Loss: 0.1702, R-squared: 0.3608,Validation_loss:0.0554, Validation R_squared:0.2728
# Epoch [252/5000], Loss: 0.1700, R-squared: 0.3615,Validation_loss:0.0552, Validation R_squared:0.2752
# Epoch [253/5000], Loss: 0.1699, R-squared: 0.3622,Validation_loss:0.0551, Validation R_squared:0.2776
# Epoch [254/5000], Loss: 0.1697, R-squared: 0.3629,Validation_loss:0.0549, Validation R_squared:0.2801
# Epoch [255/5000], Loss: 0.1695, R-squared: 0.3636,Validation_loss:0.0547, Validation R_squared:0.2821
# Epoch [256/5000], Loss: 0.1694, R-squared: 0.3642,Validation_loss:0.0545, Validation R_squared:0.2846
# Epoch [257/5000], Loss: 0.1692, R-squared: 0.3649,Validation_loss:0.0543, Validation R_squared:0.2868
# Epoch [258/5000], Loss: 0.1690, R-squared: 0.3656,Validation_loss:0.0542, Validation R_squared:0.2892
# Epoch [259/5000], Loss: 0.1689, R-squared: 0.3662,Validation_loss:0.0540, Validation R_squared:0.2914
# Epoch [260/5000], Loss: 0.1687, R-squared: 0.3669,Validation_loss:0.0538, Validation R_squared:0.2938
# Epoch [261/5000], Loss: 0.1685, R-squared: 0.3676,Validation_loss:0.0537, Validation R_squared:0.2957
# Epoch [262/5000], Loss: 0.1684, R-squared: 0.3682,Validation_loss:0.0535, Validation R_squared:0.2981
# Epoch [263/5000], Loss: 0.1682, R-squared: 0.3689,Validation_loss:0.0533, Validation R_squared:0.3001
# Epoch [264/5000], Loss: 0.1681, R-squared: 0.3695,Validation_loss:0.0532, Validation R_squared:0.3024
# Epoch [265/5000], Loss: 0.1679, R-squared: 0.3701,Validation_loss:0.0530, Validation R_squared:0.3042
# Epoch [266/5000], Loss: 0.1678, R-squared: 0.3708,Validation_loss:0.0529, Validation R_squared:0.3064
# Epoch [267/5000], Loss: 0.1676, R-squared: 0.3714,Validation_loss:0.0527, Validation R_squared:0.3084
# Epoch [268/5000], Loss: 0.1675, R-squared: 0.3720,Validation_loss:0.0525, Validation R_squared:0.3107
# Epoch [269/5000], Loss: 0.1673, R-squared: 0.3727,Validation_loss:0.0524, Validation R_squared:0.3126
# Epoch [270/5000], Loss: 0.1671, R-squared: 0.3733,Validation_loss:0.0522, Validation R_squared:0.3146
# Epoch [271/5000], Loss: 0.1670, R-squared: 0.3739,Validation_loss:0.0521, Validation R_squared:0.3166
# Epoch [272/5000], Loss: 0.1668, R-squared: 0.3745,Validation_loss:0.0519, Validation R_squared:0.3186
# Epoch [273/5000], Loss: 0.1667, R-squared: 0.3751,Validation_loss:0.0518, Validation R_squared:0.3206
# Epoch [274/5000], Loss: 0.1666, R-squared: 0.3757,Validation_loss:0.0516, Validation R_squared:0.3226
# Epoch [275/5000], Loss: 0.1664, R-squared: 0.3763,Validation_loss:0.0515, Validation R_squared:0.3243
# Epoch [276/5000], Loss: 0.1663, R-squared: 0.3769,Validation_loss:0.0513, Validation R_squared:0.3265
# Epoch [277/5000], Loss: 0.1661, R-squared: 0.3775,Validation_loss:0.0512, Validation R_squared:0.3282
# Epoch [278/5000], Loss: 0.1660, R-squared: 0.3781,Validation_loss:0.0511, Validation R_squared:0.3298
# Epoch [279/5000], Loss: 0.1658, R-squared: 0.3787,Validation_loss:0.0509, Validation R_squared:0.3320
# Epoch [280/5000], Loss: 0.1657, R-squared: 0.3793,Validation_loss:0.0508, Validation R_squared:0.3336
# Epoch [281/5000], Loss: 0.1655, R-squared: 0.3799,Validation_loss:0.0507, Validation R_squared:0.3354
# Epoch [282/5000], Loss: 0.1654, R-squared: 0.3804,Validation_loss:0.0505, Validation R_squared:0.3373
# Epoch [283/5000], Loss: 0.1653, R-squared: 0.3810,Validation_loss:0.0504, Validation R_squared:0.3390
# Epoch [284/5000], Loss: 0.1651, R-squared: 0.3816,Validation_loss:0.0502, Validation R_squared:0.3412
# Epoch [285/5000], Loss: 0.1650, R-squared: 0.3821,Validation_loss:0.0501, Validation R_squared:0.3423
# Epoch [286/5000], Loss: 0.1648, R-squared: 0.3827,Validation_loss:0.0499, Validation R_squared:0.3446
# Epoch [287/5000], Loss: 0.1647, R-squared: 0.3833,Validation_loss:0.0498, Validation R_squared:0.3461
# Epoch [288/5000], Loss: 0.1646, R-squared: 0.3838,Validation_loss:0.0497, Validation R_squared:0.3482
# Epoch [289/5000], Loss: 0.1644, R-squared: 0.3844,Validation_loss:0.0496, Validation R_squared:0.3494
# Epoch [290/5000], Loss: 0.1643, R-squared: 0.3849,Validation_loss:0.0494, Validation R_squared:0.3514
# Epoch [291/5000], Loss: 0.1642, R-squared: 0.3855,Validation_loss:0.0493, Validation R_squared:0.3529
# Epoch [292/5000], Loss: 0.1640, R-squared: 0.3860,Validation_loss:0.0492, Validation R_squared:0.3544
# Epoch [293/5000], Loss: 0.1639, R-squared: 0.3866,Validation_loss:0.0491, Validation R_squared:0.3560
# Epoch [294/5000], Loss: 0.1638, R-squared: 0.3871,Validation_loss:0.0490, Validation R_squared:0.3575
# Epoch [295/5000], Loss: 0.1636, R-squared: 0.3877,Validation_loss:0.0489, Validation R_squared:0.3590
# Epoch [296/5000], Loss: 0.1635, R-squared: 0.3882,Validation_loss:0.0487, Validation R_squared:0.3607
# Epoch [297/5000], Loss: 0.1634, R-squared: 0.3887,Validation_loss:0.0486, Validation R_squared:0.3622
# Epoch [298/5000], Loss: 0.1632, R-squared: 0.3893,Validation_loss:0.0485, Validation R_squared:0.3637
# Epoch [299/5000], Loss: 0.1631, R-squared: 0.3898,Validation_loss:0.0484, Validation R_squared:0.3652
# Epoch [300/5000], Loss: 0.1630, R-squared: 0.3903,Validation_loss:0.0483, Validation R_squared:0.3667
# Epoch [301/5000], Loss: 0.1629, R-squared: 0.3908,Validation_loss:0.0481, Validation R_squared:0.3683
# Epoch [302/5000], Loss: 0.1627, R-squared: 0.3913,Validation_loss:0.0480, Validation R_squared:0.3695
# Epoch [303/5000], Loss: 0.1626, R-squared: 0.3919,Validation_loss:0.0479, Validation R_squared:0.3712
# Epoch [304/5000], Loss: 0.1625, R-squared: 0.3924,Validation_loss:0.0478, Validation R_squared:0.3724
# Epoch [305/5000], Loss: 0.1624, R-squared: 0.3929,Validation_loss:0.0477, Validation R_squared:0.3740
# Epoch [306/5000], Loss: 0.1622, R-squared: 0.3934,Validation_loss:0.0476, Validation R_squared:0.3750
# Epoch [307/5000], Loss: 0.1621, R-squared: 0.3939,Validation_loss:0.0475, Validation R_squared:0.3764
# Epoch [308/5000], Loss: 0.1620, R-squared: 0.3944,Validation_loss:0.0474, Validation R_squared:0.3779
# Epoch [309/5000], Loss: 0.1619, R-squared: 0.3949,Validation_loss:0.0473, Validation R_squared:0.3790
# Epoch [310/5000], Loss: 0.1617, R-squared: 0.3954,Validation_loss:0.0472, Validation R_squared:0.3805
# Epoch [311/5000], Loss: 0.1616, R-squared: 0.3959,Validation_loss:0.0471, Validation R_squared:0.3817
# Epoch [312/5000], Loss: 0.1615, R-squared: 0.3964,Validation_loss:0.0470, Validation R_squared:0.3830
# Epoch [313/5000], Loss: 0.1614, R-squared: 0.3969,Validation_loss:0.0469, Validation R_squared:0.3842
# Epoch [314/5000], Loss: 0.1613, R-squared: 0.3974,Validation_loss:0.0468, Validation R_squared:0.3859
# Epoch [315/5000], Loss: 0.1612, R-squared: 0.3978,Validation_loss:0.0467, Validation R_squared:0.3866
# Epoch [316/5000], Loss: 0.1610, R-squared: 0.3983,Validation_loss:0.0466, Validation R_squared:0.3884
# Epoch [317/5000], Loss: 0.1609, R-squared: 0.3988,Validation_loss:0.0465, Validation R_squared:0.3894
# Epoch [318/5000], Loss: 0.1608, R-squared: 0.3993,Validation_loss:0.0464, Validation R_squared:0.3907
# Epoch [319/5000], Loss: 0.1607, R-squared: 0.3997,Validation_loss:0.0463, Validation R_squared:0.3919
# Epoch [320/5000], Loss: 0.1606, R-squared: 0.4002,Validation_loss:0.0463, Validation R_squared:0.3930
# Epoch [321/5000], Loss: 0.1605, R-squared: 0.4007,Validation_loss:0.0462, Validation R_squared:0.3942
# Epoch [322/5000], Loss: 0.1603, R-squared: 0.4011,Validation_loss:0.0460, Validation R_squared:0.3959
# Epoch [323/5000], Loss: 0.1602, R-squared: 0.4016,Validation_loss:0.0460, Validation R_squared:0.3966
# Epoch [324/5000], Loss: 0.1601, R-squared: 0.4020,Validation_loss:0.0459, Validation R_squared:0.3978
# Epoch [325/5000], Loss: 0.1600, R-squared: 0.4025,Validation_loss:0.0458, Validation R_squared:0.3994
# Epoch [326/5000], Loss: 0.1599, R-squared: 0.4029,Validation_loss:0.0457, Validation R_squared:0.4005
# Epoch [327/5000], Loss: 0.1598, R-squared: 0.4034,Validation_loss:0.0456, Validation R_squared:0.4015
# Epoch [328/5000], Loss: 0.1597, R-squared: 0.4038,Validation_loss:0.0455, Validation R_squared:0.4026
# Epoch [329/5000], Loss: 0.1596, R-squared: 0.4042,Validation_loss:0.0454, Validation R_squared:0.4040
# Epoch [330/5000], Loss: 0.1595, R-squared: 0.4047,Validation_loss:0.0453, Validation R_squared:0.4050
# Epoch [331/5000], Loss: 0.1594, R-squared: 0.4051,Validation_loss:0.0453, Validation R_squared:0.4060
# Epoch [332/5000], Loss: 0.1593, R-squared: 0.4055,Validation_loss:0.0452, Validation R_squared:0.4070
# Epoch [333/5000], Loss: 0.1592, R-squared: 0.4060,Validation_loss:0.0451, Validation R_squared:0.4085
# Epoch [334/5000], Loss: 0.1591, R-squared: 0.4064,Validation_loss:0.0450, Validation R_squared:0.4094
# Epoch [335/5000], Loss: 0.1590, R-squared: 0.4068,Validation_loss:0.0449, Validation R_squared:0.4104
# Epoch [336/5000], Loss: 0.1589, R-squared: 0.4072,Validation_loss:0.0449, Validation R_squared:0.4114
# Epoch [337/5000], Loss: 0.1587, R-squared: 0.4076,Validation_loss:0.0448, Validation R_squared:0.4126
# Epoch [338/5000], Loss: 0.1586, R-squared: 0.4080,Validation_loss:0.0447, Validation R_squared:0.4135
# Epoch [339/5000], Loss: 0.1585, R-squared: 0.4084,Validation_loss:0.0446, Validation R_squared:0.4145
# Epoch [340/5000], Loss: 0.1584, R-squared: 0.4089,Validation_loss:0.0445, Validation R_squared:0.4158
# Epoch [341/5000], Loss: 0.1583, R-squared: 0.4092,Validation_loss:0.0445, Validation R_squared:0.4166
# Epoch [342/5000], Loss: 0.1582, R-squared: 0.4097,Validation_loss:0.0444, Validation R_squared:0.4176
# Epoch [343/5000], Loss: 0.1581, R-squared: 0.4101,Validation_loss:0.0443, Validation R_squared:0.4184
# Epoch [344/5000], Loss: 0.1580, R-squared: 0.4105,Validation_loss:0.0442, Validation R_squared:0.4196
# Epoch [345/5000], Loss: 0.1580, R-squared: 0.4109,Validation_loss:0.0441, Validation R_squared:0.4207
# Epoch [346/5000], Loss: 0.1579, R-squared: 0.4113,Validation_loss:0.0441, Validation R_squared:0.4213
# Epoch [347/5000], Loss: 0.1578, R-squared: 0.4117,Validation_loss:0.0440, Validation R_squared:0.4225
# Epoch [348/5000], Loss: 0.1577, R-squared: 0.4120,Validation_loss:0.0440, Validation R_squared:0.4232
# Epoch [349/5000], Loss: 0.1576, R-squared: 0.4124,Validation_loss:0.0439, Validation R_squared:0.4245
# Epoch [350/5000], Loss: 0.1575, R-squared: 0.4128,Validation_loss:0.0438, Validation R_squared:0.4249
# Epoch [351/5000], Loss: 0.1574, R-squared: 0.4132,Validation_loss:0.0437, Validation R_squared:0.4260
# Epoch [352/5000], Loss: 0.1573, R-squared: 0.4136,Validation_loss:0.0437, Validation R_squared:0.4271
# Epoch [353/5000], Loss: 0.1572, R-squared: 0.4140,Validation_loss:0.0436, Validation R_squared:0.4276
# Epoch [354/5000], Loss: 0.1571, R-squared: 0.4143,Validation_loss:0.0435, Validation R_squared:0.4288
# Epoch [355/5000], Loss: 0.1570, R-squared: 0.4147,Validation_loss:0.0435, Validation R_squared:0.4294
# Epoch [356/5000], Loss: 0.1569, R-squared: 0.4151,Validation_loss:0.0434, Validation R_squared:0.4304
# Epoch [357/5000], Loss: 0.1568, R-squared: 0.4155,Validation_loss:0.0433, Validation R_squared:0.4312
# Epoch [358/5000], Loss: 0.1567, R-squared: 0.4159,Validation_loss:0.0433, Validation R_squared:0.4318
# Epoch [359/5000], Loss: 0.1566, R-squared: 0.4162,Validation_loss:0.0432, Validation R_squared:0.4329
# Epoch [360/5000], Loss: 0.1565, R-squared: 0.4166,Validation_loss:0.0432, Validation R_squared:0.4333
# Epoch [361/5000], Loss: 0.1564, R-squared: 0.4170,Validation_loss:0.0431, Validation R_squared:0.4343
# Epoch [362/5000], Loss: 0.1564, R-squared: 0.4173,Validation_loss:0.0431, Validation R_squared:0.4349
# Epoch [363/5000], Loss: 0.1563, R-squared: 0.4177,Validation_loss:0.0430, Validation R_squared:0.4359
# Epoch [364/5000], Loss: 0.1562, R-squared: 0.4181,Validation_loss:0.0429, Validation R_squared:0.4367
# Epoch [365/5000], Loss: 0.1561, R-squared: 0.4184,Validation_loss:0.0429, Validation R_squared:0.4371
# Epoch [366/5000], Loss: 0.1560, R-squared: 0.4188,Validation_loss:0.0428, Validation R_squared:0.4379
# Epoch [367/5000], Loss: 0.1559, R-squared: 0.4191,Validation_loss:0.0427, Validation R_squared:0.4391
# Epoch [368/5000], Loss: 0.1558, R-squared: 0.4195,Validation_loss:0.0427, Validation R_squared:0.4391
# Epoch [369/5000], Loss: 0.1557, R-squared: 0.4199,Validation_loss:0.0426, Validation R_squared:0.4406
# Epoch [370/5000], Loss: 0.1556, R-squared: 0.4202,Validation_loss:0.0426, Validation R_squared:0.4405
# Epoch [371/5000], Loss: 0.1556, R-squared: 0.4206,Validation_loss:0.0425, Validation R_squared:0.4418
# Epoch [372/5000], Loss: 0.1555, R-squared: 0.4209,Validation_loss:0.0425, Validation R_squared:0.4423
# Epoch [373/5000], Loss: 0.1554, R-squared: 0.4213,Validation_loss:0.0424, Validation R_squared:0.4431
# Epoch [374/5000], Loss: 0.1553, R-squared: 0.4216,Validation_loss:0.0424, Validation R_squared:0.4438
# Epoch [375/5000], Loss: 0.1552, R-squared: 0.4220,Validation_loss:0.0423, Validation R_squared:0.4445
# Epoch [376/5000], Loss: 0.1551, R-squared: 0.4223,Validation_loss:0.0423, Validation R_squared:0.4450
# Epoch [377/5000], Loss: 0.1550, R-squared: 0.4227,Validation_loss:0.0422, Validation R_squared:0.4461
# Epoch [378/5000], Loss: 0.1550, R-squared: 0.4230,Validation_loss:0.0422, Validation R_squared:0.4463
# Epoch [379/5000], Loss: 0.1549, R-squared: 0.4233,Validation_loss:0.0421, Validation R_squared:0.4472
# Epoch [380/5000], Loss: 0.1548, R-squared: 0.4237,Validation_loss:0.0421, Validation R_squared:0.4479
# Epoch [381/5000], Loss: 0.1547, R-squared: 0.4240,Validation_loss:0.0420, Validation R_squared:0.4486
# Epoch [382/5000], Loss: 0.1546, R-squared: 0.4243,Validation_loss:0.0420, Validation R_squared:0.4491
# Epoch [383/5000], Loss: 0.1545, R-squared: 0.4247,Validation_loss:0.0419, Validation R_squared:0.4500
# Epoch [384/5000], Loss: 0.1545, R-squared: 0.4250,Validation_loss:0.0419, Validation R_squared:0.4503
# Epoch [385/5000], Loss: 0.1544, R-squared: 0.4253,Validation_loss:0.0418, Validation R_squared:0.4514
# Epoch [386/5000], Loss: 0.1543, R-squared: 0.4257,Validation_loss:0.0418, Validation R_squared:0.4516
# Epoch [387/5000], Loss: 0.1542, R-squared: 0.4260,Validation_loss:0.0417, Validation R_squared:0.4524
# Epoch [388/5000], Loss: 0.1541, R-squared: 0.4263,Validation_loss:0.0417, Validation R_squared:0.4531
# Epoch [389/5000], Loss: 0.1541, R-squared: 0.4267,Validation_loss:0.0416, Validation R_squared:0.4536
# Epoch [390/5000], Loss: 0.1540, R-squared: 0.4270,Validation_loss:0.0416, Validation R_squared:0.4542
# Epoch [391/5000], Loss: 0.1539, R-squared: 0.4273,Validation_loss:0.0415, Validation R_squared:0.4550
# Epoch [392/5000], Loss: 0.1538, R-squared: 0.4276,Validation_loss:0.0415, Validation R_squared:0.4555
# Epoch [393/5000], Loss: 0.1537, R-squared: 0.4280,Validation_loss:0.0415, Validation R_squared:0.4560
# Epoch [394/5000], Loss: 0.1537, R-squared: 0.4283,Validation_loss:0.0414, Validation R_squared:0.4569
# Epoch [395/5000], Loss: 0.1536, R-squared: 0.4286,Validation_loss:0.0414, Validation R_squared:0.4570
# Epoch [396/5000], Loss: 0.1535, R-squared: 0.4289,Validation_loss:0.0413, Validation R_squared:0.4576
# Epoch [397/5000], Loss: 0.1534, R-squared: 0.4292,Validation_loss:0.0413, Validation R_squared:0.4583
# Epoch [398/5000], Loss: 0.1533, R-squared: 0.4295,Validation_loss:0.0412, Validation R_squared:0.4589
# Epoch [399/5000], Loss: 0.1533, R-squared: 0.4299,Validation_loss:0.0412, Validation R_squared:0.4593
# Epoch [400/5000], Loss: 0.1532, R-squared: 0.4302,Validation_loss:0.0411, Validation R_squared:0.4602
# Epoch [401/5000], Loss: 0.1531, R-squared: 0.4305,Validation_loss:0.0411, Validation R_squared:0.4602
# Epoch [402/5000], Loss: 0.1530, R-squared: 0.4308,Validation_loss:0.0410, Validation R_squared:0.4614
# Epoch [403/5000], Loss: 0.1530, R-squared: 0.4311,Validation_loss:0.0411, Validation R_squared:0.4613
# Epoch [404/5000], Loss: 0.1529, R-squared: 0.4314,Validation_loss:0.0410, Validation R_squared:0.4625
# Epoch [405/5000], Loss: 0.1528, R-squared: 0.4317,Validation_loss:0.0410, Validation R_squared:0.4626
# Epoch [406/5000], Loss: 0.1527, R-squared: 0.4320,Validation_loss:0.0409, Validation R_squared:0.4633
# Epoch [407/5000], Loss: 0.1527, R-squared: 0.4323,Validation_loss:0.0409, Validation R_squared:0.4638
# Epoch [408/5000], Loss: 0.1526, R-squared: 0.4326,Validation_loss:0.0408, Validation R_squared:0.4644
# Epoch [409/5000], Loss: 0.1525, R-squared: 0.4329,Validation_loss:0.0408, Validation R_squared:0.4650
# Epoch [410/5000], Loss: 0.1524, R-squared: 0.4332,Validation_loss:0.0407, Validation R_squared:0.4654
# Epoch [411/5000], Loss: 0.1524, R-squared: 0.4335,Validation_loss:0.0407, Validation R_squared:0.4663
# Epoch [412/5000], Loss: 0.1523, R-squared: 0.4338,Validation_loss:0.0407, Validation R_squared:0.4665
# Epoch [413/5000], Loss: 0.1522, R-squared: 0.4342,Validation_loss:0.0406, Validation R_squared:0.4673
# Epoch [414/5000], Loss: 0.1521, R-squared: 0.4344,Validation_loss:0.0406, Validation R_squared:0.4676
# Epoch [415/5000], Loss: 0.1521, R-squared: 0.4347,Validation_loss:0.0405, Validation R_squared:0.4682
# Epoch [416/5000], Loss: 0.1520, R-squared: 0.4350,Validation_loss:0.0405, Validation R_squared:0.4688
# Epoch [417/5000], Loss: 0.1519, R-squared: 0.4353,Validation_loss:0.0405, Validation R_squared:0.4690
# Epoch [418/5000], Loss: 0.1518, R-squared: 0.4356,Validation_loss:0.0404, Validation R_squared:0.4699
# Epoch [419/5000], Loss: 0.1518, R-squared: 0.4359,Validation_loss:0.0404, Validation R_squared:0.4701
# Epoch [420/5000], Loss: 0.1517, R-squared: 0.4362,Validation_loss:0.0403, Validation R_squared:0.4708
# Epoch [421/5000], Loss: 0.1516, R-squared: 0.4365,Validation_loss:0.0403, Validation R_squared:0.4712
# Epoch [422/5000], Loss: 0.1516, R-squared: 0.4368,Validation_loss:0.0403, Validation R_squared:0.4718
# Epoch [423/5000], Loss: 0.1515, R-squared: 0.4371,Validation_loss:0.0402, Validation R_squared:0.4723
# Epoch [424/5000], Loss: 0.1514, R-squared: 0.4374,Validation_loss:0.0402, Validation R_squared:0.4728
# Epoch [425/5000], Loss: 0.1513, R-squared: 0.4377,Validation_loss:0.0401, Validation R_squared:0.4733
# Epoch [426/5000], Loss: 0.1513, R-squared: 0.4380,Validation_loss:0.0401, Validation R_squared:0.4736
# Epoch [427/5000], Loss: 0.1512, R-squared: 0.4382,Validation_loss:0.0401, Validation R_squared:0.4742
# Epoch [428/5000], Loss: 0.1511, R-squared: 0.4385,Validation_loss:0.0400, Validation R_squared:0.4747
# Epoch [429/5000], Loss: 0.1511, R-squared: 0.4388,Validation_loss:0.0400, Validation R_squared:0.4752
# Epoch [430/5000], Loss: 0.1510, R-squared: 0.4391,Validation_loss:0.0400, Validation R_squared:0.4754
# Epoch [431/5000], Loss: 0.1509, R-squared: 0.4394,Validation_loss:0.0399, Validation R_squared:0.4766
# Epoch [432/5000], Loss: 0.1508, R-squared: 0.4396,Validation_loss:0.0399, Validation R_squared:0.4761
# Epoch [433/5000], Loss: 0.1508, R-squared: 0.4399,Validation_loss:0.0399, Validation R_squared:0.4771
# Epoch [434/5000], Loss: 0.1507, R-squared: 0.4402,Validation_loss:0.0398, Validation R_squared:0.4771
# Epoch [435/5000], Loss: 0.1506, R-squared: 0.4405,Validation_loss:0.0398, Validation R_squared:0.4781
# Epoch [436/5000], Loss: 0.1506, R-squared: 0.4408,Validation_loss:0.0398, Validation R_squared:0.4778
# Epoch [437/5000], Loss: 0.1505, R-squared: 0.4411,Validation_loss:0.0397, Validation R_squared:0.4788
# Epoch [438/5000], Loss: 0.1504, R-squared: 0.4413,Validation_loss:0.0397, Validation R_squared:0.4787
# Epoch [439/5000], Loss: 0.1504, R-squared: 0.4416,Validation_loss:0.0396, Validation R_squared:0.4799
# Epoch [440/5000], Loss: 0.1503, R-squared: 0.4419,Validation_loss:0.0397, Validation R_squared:0.4792
# Epoch [441/5000], Loss: 0.1502, R-squared: 0.4422,Validation_loss:0.0396, Validation R_squared:0.4805
# Epoch [442/5000], Loss: 0.1502, R-squared: 0.4424,Validation_loss:0.0396, Validation R_squared:0.4806
# Epoch [443/5000], Loss: 0.1501, R-squared: 0.4427,Validation_loss:0.0395, Validation R_squared:0.4812
# Epoch [444/5000], Loss: 0.1500, R-squared: 0.4430,Validation_loss:0.0395, Validation R_squared:0.4814
# Epoch [445/5000], Loss: 0.1500, R-squared: 0.4432,Validation_loss:0.0395, Validation R_squared:0.4821
# Epoch [446/5000], Loss: 0.1499, R-squared: 0.4435,Validation_loss:0.0395, Validation R_squared:0.4821
# Epoch [447/5000], Loss: 0.1498, R-squared: 0.4438,Validation_loss:0.0394, Validation R_squared:0.4830
# Epoch [448/5000], Loss: 0.1498, R-squared: 0.4440,Validation_loss:0.0394, Validation R_squared:0.4825
# Epoch [449/5000], Loss: 0.1497, R-squared: 0.4443,Validation_loss:0.0393, Validation R_squared:0.4839
# Epoch [450/5000], Loss: 0.1496, R-squared: 0.4446,Validation_loss:0.0394, Validation R_squared:0.4833
# Epoch [451/5000], Loss: 0.1496, R-squared: 0.4449,Validation_loss:0.0393, Validation R_squared:0.4845
# Epoch [452/5000], Loss: 0.1495, R-squared: 0.4451,Validation_loss:0.0393, Validation R_squared:0.4843
# Epoch [453/5000], Loss: 0.1494, R-squared: 0.4454,Validation_loss:0.0392, Validation R_squared:0.4852
# Epoch [454/5000], Loss: 0.1494, R-squared: 0.4456,Validation_loss:0.0393, Validation R_squared:0.4848
# Epoch [455/5000], Loss: 0.1493, R-squared: 0.4459,Validation_loss:0.0392, Validation R_squared:0.4863
# Epoch [456/5000], Loss: 0.1492, R-squared: 0.4461,Validation_loss:0.0392, Validation R_squared:0.4851
# Epoch [457/5000], Loss: 0.1492, R-squared: 0.4464,Validation_loss:0.0391, Validation R_squared:0.4867
# Epoch [458/5000], Loss: 0.1491, R-squared: 0.4467,Validation_loss:0.0392, Validation R_squared:0.4862
# Epoch [459/5000], Loss: 0.1490, R-squared: 0.4470,Validation_loss:0.0391, Validation R_squared:0.4871
# Epoch [460/5000], Loss: 0.1490, R-squared: 0.4472,Validation_loss:0.0391, Validation R_squared:0.4872
# Epoch [461/5000], Loss: 0.1489, R-squared: 0.4475,Validation_loss:0.0390, Validation R_squared:0.4877
# Epoch [462/5000], Loss: 0.1488, R-squared: 0.4477,Validation_loss:0.0390, Validation R_squared:0.4879
# Epoch [463/5000], Loss: 0.1488, R-squared: 0.4480,Validation_loss:0.0390, Validation R_squared:0.4883
# Epoch [464/5000], Loss: 0.1487, R-squared: 0.4482,Validation_loss:0.0390, Validation R_squared:0.4884
# Epoch [465/5000], Loss: 0.1486, R-squared: 0.4485,Validation_loss:0.0389, Validation R_squared:0.4891
# Epoch [466/5000], Loss: 0.1486, R-squared: 0.4487,Validation_loss:0.0389, Validation R_squared:0.4894
# Epoch [467/5000], Loss: 0.1485, R-squared: 0.4490,Validation_loss:0.0389, Validation R_squared:0.4896
# Epoch [468/5000], Loss: 0.1485, R-squared: 0.4493,Validation_loss:0.0388, Validation R_squared:0.4904
# Epoch [469/5000], Loss: 0.1484, R-squared: 0.4495,Validation_loss:0.0388, Validation R_squared:0.4903
# ...
# Epoch [4846/5000], Loss: 0.0863, R-squared: 0.6938,Validation_loss:0.0222, Validation R_squared:0.7092
# Epoch [4847/5000], Loss: 0.0863, R-squared: 0.6938,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4848/5000], Loss: 0.0863, R-squared: 0.6938,Validation_loss:0.0222, Validation R_squared:0.7092
# Epoch [4849/5000], Loss: 0.0863, R-squared: 0.6938,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4850/5000], Loss: 0.0863, R-squared: 0.6938,Validation_loss:0.0222, Validation R_squared:0.7092
# Epoch [4851/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4852/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4853/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4854/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4855/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4856/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4857/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4858/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4859/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4860/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4861/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4862/5000], Loss: 0.0863, R-squared: 0.6939,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4863/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4864/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4865/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4866/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4867/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0222, Validation R_squared:0.7093
# Epoch [4868/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4869/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4870/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4871/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4872/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4873/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4874/5000], Loss: 0.0863, R-squared: 0.6940,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4875/5000], Loss: 0.0863, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4876/5000], Loss: 0.0863, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4877/5000], Loss: 0.0863, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4878/5000], Loss: 0.0863, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4879/5000], Loss: 0.0863, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4880/5000], Loss: 0.0862, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4881/5000], Loss: 0.0862, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4882/5000], Loss: 0.0862, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4883/5000], Loss: 0.0862, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4884/5000], Loss: 0.0862, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4885/5000], Loss: 0.0862, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4886/5000], Loss: 0.0862, R-squared: 0.6941,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4887/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7094
# Epoch [4888/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4889/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4890/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4891/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4892/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4893/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4894/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4895/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4896/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4897/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4898/5000], Loss: 0.0862, R-squared: 0.6942,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4899/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4900/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4901/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4902/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4903/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7095
# Epoch [4904/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4905/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4906/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4907/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4908/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4909/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4910/5000], Loss: 0.0862, R-squared: 0.6943,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4911/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4912/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4913/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4914/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4915/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4916/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4917/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4918/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4919/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7096
# Epoch [4920/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4921/5000], Loss: 0.0862, R-squared: 0.6944,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4922/5000], Loss: 0.0862, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4923/5000], Loss: 0.0862, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4924/5000], Loss: 0.0862, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4925/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4926/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4927/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4928/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4929/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4930/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4931/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4932/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4933/5000], Loss: 0.0861, R-squared: 0.6945,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4934/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4935/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4936/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4937/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4938/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4939/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4940/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4941/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4942/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7097
# Epoch [4943/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4944/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4945/5000], Loss: 0.0861, R-squared: 0.6946,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4946/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4947/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4948/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4949/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4950/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4951/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4952/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4953/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4954/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4955/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4956/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4957/5000], Loss: 0.0861, R-squared: 0.6947,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4958/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4959/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7098
# Epoch [4960/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4961/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4962/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4963/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4964/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4965/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4966/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4967/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4968/5000], Loss: 0.0861, R-squared: 0.6948,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4969/5000], Loss: 0.0861, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4970/5000], Loss: 0.0861, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4971/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4972/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4973/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4974/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4975/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4976/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4977/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4978/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7099
# Epoch [4979/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4980/5000], Loss: 0.0860, R-squared: 0.6949,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4981/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4982/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4983/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4984/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4985/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4986/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4987/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4988/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4989/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4990/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4991/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4992/5000], Loss: 0.0860, R-squared: 0.6950,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4993/5000], Loss: 0.0860, R-squared: 0.6951,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4994/5000], Loss: 0.0860, R-squared: 0.6951,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4995/5000], Loss: 0.0860, R-squared: 0.6951,Validation_loss:0.0221, Validation R_squared:0.7101
# Epoch [4996/5000], Loss: 0.0860, R-squared: 0.6951,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4997/5000], Loss: 0.0860, R-squared: 0.6951,Validation_loss:0.0221, Validation R_squared:0.7101
# Epoch [4998/5000], Loss: 0.0860, R-squared: 0.6951,Validation_loss:0.0221, Validation R_squared:0.7100
# Epoch [4999/5000], Loss: 0.0860, R-squared: 0.6951,Validation_loss:0.0221, Validation R_squared:0.7101
# Epoch [5000/5000], Loss: 0.0860, R-squared: 0.6951,Validation_loss:0.0221, Validation R_squared:0.7101

# %% [markdown]
# ## Plots

# %%
# Create a scatter plot of actual vs. predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', label='Actual vs. Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.grid(True)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', label='Perfect Prediction')
plt.legend()

# Display the plot
plt.show()

# %%
# Create a plot for the loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(num_epochs), losses, label='Test', color='green')
plt.plot(range(num_epochs), val_losses, label='Validation', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.grid(True)

# Create a plot for R-squared
plt.subplot(1, 2, 2)
plt.plot(range(num_epochs), r2_values, label='Test', color='green')
plt.plot(range(num_epochs), r2_validation, label='Validation', color='orange')
plt.xlabel('Epoch')
plt.ylabel('R-squared')
plt.title('R-squared Over Epochs')
plt.legend()
plt.grid(True)

# Display Plot
plt.show()

# %% [markdown]
# ## Gradient

# %%
#extract grad
parameter_importance = model.fc1.weight.grad

# %%
# Convert the parameter_importance tensor to a NumPy array
parameter_importance_img = parameter_importance.detach().numpy()
# Normalize the values to [0, 1]
min_val = parameter_importance_img.min()
max_val = parameter_importance_img.max()

parameter_importance_img = (parameter_importance_img - min_val) / (max_val - min_val)
parameter_importance_img = np.floor(parameter_importance_img*255)

# %% [markdown]
# Display

# %%
# Create a heatmap
plt.figure(figsize=(10, 2))
plt.imshow(parameter_importance_img, cmap='viridis', aspect='auto')
plt.colorbar()
plt.title('Parameter Importance Heatmap')
plt.xlabel('Input Dimension')
plt.ylabel('Gradients')
plt.show()

# %%
data_row=0
# Plot heatmap
plt.figure(figsize=(10, 2))
plt.imshow(parameter_importance_img[0+data_row:3+data_row,:], cmap='viridis', aspect='auto')
plt.colorbar()
plt.title('Parameter Importance Heatmap')
plt.xlabel('Input Dimension')
plt.ylabel('Gradients')
plt.show()
